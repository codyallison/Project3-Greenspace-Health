# %%
## Import Dependencies
from pprint import pprint
import pandas as pd
import re

# %%
## Create the Dataframe and list the column names

df = pd.read_csv('../Resources/CountyHealthData.csv')
list(df.columns)
# Out:
# ['Year',
#  'StateAbbr',
#  'StateDesc',
#  'LocationName',
#  'DataSource',
#  'Category',
#  'Measure',
#  'Data_Value_Unit',
#  'Data_Value_Type',
#  'Data_Value',
#  'Data_Value_Footnote_Symbol',
#  'Data_Value_Footnote',
#  'Low_Confidence_Limit',
#  'High_Confidence_Limit',
#  'TotalPopulation',
#  'LocationID',
#  'CategoryID',
#  'MeasureId',
#  'DataValueTypeID',
#  'Short_Question_Text',
#  'Geolocation',
#  'States',
#  'Counties']

# %%
list(df['Short_Question_Text'].unique())
# Out:
# ['High Blood Pressure',
#  'Physical Inactivity',
#  'Binge Drinking',
#  'Arthritis',
#  'Annual Checkup',
#  'Chronic Kidney Disease',
#  'Cancer (except skin)',
#  'Mental Health',
#  'Cholesterol Screening',
#  'Cervical Cancer Screening',
#  'General Health',
#  'Core preventive services for older men',
#  'Stroke',
#  'COPD',
#  'Taking BP Medication',
#  'Current Smoking',
#  'Physical Health',
#  'Dental Visit',
#  'Sleep <7 hours',
#  'Current Asthma',
#  'Obesity',
#  'Depression',
#  'Colorectal Cancer Screening',
#  'Diabetes',
#  'All Teeth Lost',
#  'Mammography',
#  'Core preventive services for older women',
#  'Health Insurance',
#  'Coronary Heart Disease',
#  'High Cholesterol']

# %%
new_df = df.loc[df['Short_Question_Text'].isin(
                        ['High Blood Pressure', 
                         'Physical Inactivity'
                         'Binge Drinking',
                         'Mental Health',
                         'Current Smoking',
                         'Sleep <7 hours',
                         'Obesity',
                         
                         'High Cholesterol',
                        'Depression'])]

new_df = new_df.loc[new_df['Year'] == 2019]
new_df
# Out:
#         Year StateAbbr StateDesc LocationName DataSource         Category  \
# 0       2019        WY   Wyoming        Crook      BRFSS  Health Outcomes
# 24      2019        WY   Wyoming       Carbon      BRFSS  Health Outcomes
# 28      2019        WY   Wyoming       Platte      BRFSS  Health Outcomes
# 76      2019        WY   Wyoming     Niobrara      BRFSS  Health Outcomes
# 78      2019        WY   Wyoming       Weston      BRFSS  Health Outcomes
# ...      ...       ...       ...          ...        ...              ...
# 188352  2019        AL   Alabama       Monroe      BRFSS  Health Outcomes
# 188356  2019        AL   Alabama      Russell      BRFSS  Health Outcomes
# 188359  2019        AL   Alabama       Mobile      BRFSS  Health Outcomes
# 188382  2019        AL   Alabama         Bibb      BRFSS  Health Outcomes
# 188393  2019        AL   Alabama   Lauderdale      BRFSS  Health Outcomes
#
#                                                   Measure Data_Value_Unit  \
# 0        High blood pressure among adults aged >=18 years               %
# 24       High blood pressure among adults aged >=18 years               %
# 28       High blood pressure among adults aged >=18 years               %
# 76      High cholesterol among adults aged >=18 years ...               %
# 78      High cholesterol among adults aged >=18 years ...               %
# ...                                                   ...             ...
# 188352  High cholesterol among adults aged >=18 years ...               %
# 188356  High cholesterol among adults aged >=18 years ...               %
# 188359   High blood pressure among adults aged >=18 years               %
# 188382   High blood pressure among adults aged >=18 years               %
# 188393  High cholesterol among adults aged >=18 years ...               %
#
#                 Data_Value_Type  Data_Value  ...  High_Confidence_Limit  \
# 0       Age-adjusted prevalence        27.0  ...                   28.2
# 24      Age-adjusted prevalence        29.6  ...                   30.6
# 28             Crude prevalence        36.4  ...                   37.7
# 76             Crude prevalence        31.0  ...                   32.3
# 78      Age-adjusted prevalence        25.7  ...                   26.6
# ...                         ...         ...  ...                    ...
# 188352         Crude prevalence        38.8  ...                   39.7
# 188356         Crude prevalence        34.7  ...                   35.5
# 188359  Age-adjusted prevalence        39.5  ...                   40.5
# 188382  Age-adjusted prevalence        41.3  ...                   42.4
# 188393         Crude prevalence        35.4  ...                   36.4
#
#         TotalPopulation  LocationID  CategoryID  MeasureId  DataValueTypeID  \
# 0                  7593       56011     HLTHOUT     BPHIGH        AgeAdjPrv
# 24                14711       56007     HLTHOUT     BPHIGH        AgeAdjPrv
# 28                 8578       56031     HLTHOUT     BPHIGH           CrdPrv
# 76                 2275       56027     HLTHOUT   HIGHCHOL           CrdPrv
# 78                 6743       56045     HLTHOUT   HIGHCHOL        AgeAdjPrv
# ...                 ...         ...         ...        ...              ...
# 188352            20459        1099     HLTHOUT   HIGHCHOL           CrdPrv
# 188356            58237        1113     HLTHOUT   HIGHCHOL           CrdPrv
# 188359           412716        1097     HLTHOUT     BPHIGH        AgeAdjPrv
# 188382            22136        1007     HLTHOUT     BPHIGH        AgeAdjPrv
# 188393            93368        1077     HLTHOUT   HIGHCHOL           CrdPrv
#
#         Short_Question_Text                      Geolocation States Counties
# 0       High Blood Pressure  POINT (-104.5672975 44.5892657)   14.0   3083.0
# 24      High Blood Pressure  POINT (-106.9331526 41.7035904)   14.0   3081.0
# 28      High Blood Pressure  POINT (-104.9539626 42.1315927)   14.0    892.0
# 76         High Cholesterol   POINT (-104.4683727 43.062159)   14.0   3121.0
# 78         High Cholesterol  POINT (-104.5700202 43.8462133)   14.0    894.0
# ...                     ...                              ...    ...      ...
# 188352     High Cholesterol   POINT (-87.3832656 31.5803324)   29.0   1592.0
# 188356     High Cholesterol   POINT (-85.1869798 32.2898113)   29.0   1634.0
# 188359  High Blood Pressure   POINT (-88.1965682 30.6845725)   29.0   1591.0
# 188382  High Blood Pressure   POINT (-87.1271475 33.0158929)   29.0     92.0
# 188393     High Cholesterol   POINT (-87.6509966 34.9041221)   29.0   1584.0
#
# [12484 rows x 23 columns]

# %%
## Clean the DataFrame and only show the columns we need

new_df = new_df[['Year',
 'StateAbbr',
 'LocationName',
 'Data_Value_Type',
 'Data_Value',
 'TotalPopulation',
 'CategoryID',
 'MeasureId',
 'DataValueTypeID',
 'Short_Question_Text',
 'Geolocation']]
new_df.dropna()
# Out:
#         Year StateAbbr LocationName          Data_Value_Type  Data_Value  \
# 0       2019        WY        Crook  Age-adjusted prevalence        27.0
# 24      2019        WY       Carbon  Age-adjusted prevalence        29.6
# 28      2019        WY       Platte         Crude prevalence        36.4
# 76      2019        WY     Niobrara         Crude prevalence        31.0
# 78      2019        WY       Weston  Age-adjusted prevalence        25.7
# ...      ...       ...          ...                      ...         ...
# 188352  2019        AL       Monroe         Crude prevalence        38.8
# 188356  2019        AL      Russell         Crude prevalence        34.7
# 188359  2019        AL       Mobile  Age-adjusted prevalence        39.5
# 188382  2019        AL         Bibb  Age-adjusted prevalence        41.3
# 188393  2019        AL   Lauderdale         Crude prevalence        35.4
#
#         TotalPopulation CategoryID MeasureId DataValueTypeID  \
# 0                  7593    HLTHOUT    BPHIGH       AgeAdjPrv
# 24                14711    HLTHOUT    BPHIGH       AgeAdjPrv
# 28                 8578    HLTHOUT    BPHIGH          CrdPrv
# 76                 2275    HLTHOUT  HIGHCHOL          CrdPrv
# 78                 6743    HLTHOUT  HIGHCHOL       AgeAdjPrv
# ...                 ...        ...       ...             ...
# 188352            20459    HLTHOUT  HIGHCHOL          CrdPrv
# 188356            58237    HLTHOUT  HIGHCHOL          CrdPrv
# 188359           412716    HLTHOUT    BPHIGH       AgeAdjPrv
# 188382            22136    HLTHOUT    BPHIGH       AgeAdjPrv
# 188393            93368    HLTHOUT  HIGHCHOL          CrdPrv
#
#         Short_Question_Text                      Geolocation
# 0       High Blood Pressure  POINT (-104.5672975 44.5892657)
# 24      High Blood Pressure  POINT (-106.9331526 41.7035904)
# 28      High Blood Pressure  POINT (-104.9539626 42.1315927)
# 76         High Cholesterol   POINT (-104.4683727 43.062159)
# 78         High Cholesterol  POINT (-104.5700202 43.8462133)
# ...                     ...                              ...
# 188352     High Cholesterol   POINT (-87.3832656 31.5803324)
# 188356     High Cholesterol   POINT (-85.1869798 32.2898113)
# 188359  High Blood Pressure   POINT (-88.1965682 30.6845725)
# 188382  High Blood Pressure   POINT (-87.1271475 33.0158929)
# 188393     High Cholesterol   POINT (-87.6509966 34.9041221)
#
# [12480 rows x 11 columns]

# %%
list(new_df['Short_Question_Text'].unique())
# Out:
# ['High Blood Pressure', 'High Cholesterol']

# %%
## Fix the format of the Geolocation column

## Create an empty list
lats = []
lons = []

## Iterate through the rows
for i in new_df['Geolocation']:
    ## Set each item to a string
    s = str(i)
    # get lon-lat from "POINT (lon lat)"
    loc = s[7:-1]
    ## Turn the returned string into a list
    l = loc.split(' ')
    ## Reverse the list
    
    try:
        lats.append(l[1])
        
    except:
        lats.append('')
        
    try:
        lons.append(l[0])
        
    except:
        lats.append('')
           
        
        
        
    ## Use a list comprehension to turn the string values in the list back in to floats
new_df['Lat'] = lats
new_df['Lon'] = lons
# Out:
# <ipython-input-7-0e07ecb30466>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Lat'] = lats
# <ipython-input-7-0e07ecb30466>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Lon'] = lons

# %%
## Show the DataFrame again with the new location values
final_df = new_df.drop(columns = ['CategoryID', 'MeasureId', 'Geolocation'])
final_df
# Out:
#         Year StateAbbr LocationName          Data_Value_Type  Data_Value  \
# 0       2019        WY        Crook  Age-adjusted prevalence        27.0
# 24      2019        WY       Carbon  Age-adjusted prevalence        29.6
# 28      2019        WY       Platte         Crude prevalence        36.4
# 76      2019        WY     Niobrara         Crude prevalence        31.0
# 78      2019        WY       Weston  Age-adjusted prevalence        25.7
# ...      ...       ...          ...                      ...         ...
# 188352  2019        AL       Monroe         Crude prevalence        38.8
# 188356  2019        AL      Russell         Crude prevalence        34.7
# 188359  2019        AL       Mobile  Age-adjusted prevalence        39.5
# 188382  2019        AL         Bibb  Age-adjusted prevalence        41.3
# 188393  2019        AL   Lauderdale         Crude prevalence        35.4
#
#         TotalPopulation DataValueTypeID  Short_Question_Text         Lat  \
# 0                  7593       AgeAdjPrv  High Blood Pressure  44.5892657
# 24                14711       AgeAdjPrv  High Blood Pressure  41.7035904
# 28                 8578          CrdPrv  High Blood Pressure  42.1315927
# 76                 2275          CrdPrv     High Cholesterol   43.062159
# 78                 6743       AgeAdjPrv     High Cholesterol  43.8462133
# ...                 ...             ...                  ...         ...
# 188352            20459          CrdPrv     High Cholesterol  31.5803324
# 188356            58237          CrdPrv     High Cholesterol  32.2898113
# 188359           412716       AgeAdjPrv  High Blood Pressure  30.6845725
# 188382            22136       AgeAdjPrv  High Blood Pressure  33.0158929
# 188393            93368          CrdPrv     High Cholesterol  34.9041221
#
#                  Lon
# 0       -104.5672975
# 24      -106.9331526
# 28      -104.9539626
# 76      -104.4683727
# 78      -104.5700202
# ...              ...
# 188352   -87.3832656
# 188356   -85.1869798
# 188359   -88.1965682
# 188382   -87.1271475
# 188393   -87.6509966
#
# [12484 rows x 10 columns]

# %%
## Changing column types
final_df['Lat'] = pd.to_numeric(final_df['Lat'])
final_df['Lon'] = pd.to_numeric(final_df['Lon'])

# %%
## Export it to a file

df.to_csv('../Resources/CleanedHealthCountyData.csv')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12484 entries, 0 to 188393
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 12484 non-null  int64
#  1   StateAbbr            12484 non-null  object
#  2   LocationName         12480 non-null  object
#  3   Data_Value_Type      12484 non-null  object
#  4   Data_Value           12484 non-null  float64
#  5   TotalPopulation      12484 non-null  int64
#  6   DataValueTypeID      12484 non-null  object
#  7   Short_Question_Text  12484 non-null  object
#  8   Lat                  12480 non-null  float64
#  9   Lon                  12480 non-null  float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 1.0+ MB

# %%
group = final_df.groupby(['LocationName', 'StateAbbr'])

data_list = []
for row in group:
    empty_dict = {

    }
    county = row[0][0]
    empty_dict['county'] = county
        
    state = row[0][1]
    empty_dict['state'] = state
        
    data = row[1]
    parameters = [x for x in data['Short_Question_Text']]
    data_types = [x for x in data['DataValueTypeID']]
    
    data_values = [x for x in data['Data_Value']]
    
    population = data['TotalPopulation'].head(1)
    empty_dict['population'] = int(population.values[0])
    
      
        
    lat = data['Lat'].head(1)
    
    lon = data['Lon'].head(1)
    empty_dict['location'] = [int(lat.values[0]),int(lon.values[0])]

    ##print(county, state, parameters, data_types, measurements, population, lat, lon)
    measurements = {}
    for i in range(4):
        m = parameters[i].replace(' ','')
        dt = data_types[i]
        m=m+dt
        measurements[m] = data_values[i]
        empty_dict['measurements'] = measurements

    data_list.append(empty_dict)
data_list
# Out:
# [{'county': 'Abbeville',
#   'state': 'SC',
#   'population': 24404,
#   'location': [34, -82],
#   'measurements': {'HighBloodPressureCrdPrv': 45.0,
#    'HighCholesterolAgeAdjPrv': 32.1,
#    'HighCholesterolCrdPrv': 39.5,
#    'HighBloodPressureAgeAdjPrv': 38.7}},
#  {'county': 'Acadia',
#   'state': 'LA',
#   'population': 61918,
#   'location': [30, -92],
#   'measurements': {'HighBloodPressureCrdPrv': 41.8,
#    'HighCholesterolAgeAdjPrv': 34.6,
#    'HighCholesterolCrdPrv': 39.5,
#    'HighBloodPressureAgeAdjPrv': 38.7}},
#  {'county': 'Accomack',
#   'state': 'VA',
#   'population': 32238,
#   'location': [37, -75],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 37.1,
#    'HighBloodPressureCrdPrv': 44.7,
#    'HighCholesterolAgeAdjPrv': 28.8,
#    'HighCholesterolCrdPrv': 36.5}},
#  {'county': 'Ada',
#   'state': 'ID',
#   'population': 494399,
#   'location': [43, -116],
#   'measurements': {'HighBloodPressureCrdPrv': 28.5,
#    'HighCholesterolAgeAdjPrv': 26.8,
#    'HighCholesterolCrdPrv': 30.0,
#    'HighBloodPressureAgeAdjPrv': 27.3}},
#  {'county': 'Adair',
#   'state': 'IA',
#   'population': 7059,
#   'location': [41, -94],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 30.0,
#    'HighBloodPressureCrdPrv': 37.0,
#    'HighCholesterolAgeAdjPrv': 29.0,
#    'HighCholesterolCrdPrv': 36.6}},
#  {'county': 'Adair',
#   'state': 'KY',
#   'population': 19555,
#   'location': [37, -85],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 40.4,
#    'HighCholesterolCrdPrv': 40.7,
#    'HighCholesterolAgeAdjPrv': 35.6,
#    'HighBloodPressureCrdPrv': 44.4}},
#  {'county': 'Adair',
#   'state': 'MO',
#   'population': 25399,
#   'location': [40, -92],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.8,
#    'HighCholesterolCrdPrv': 29.8,
#    'HighBloodPressureAgeAdjPrv': 30.7,
#    'HighBloodPressureCrdPrv': 27.8}},
#  {'county': 'Adair',
#   'state': 'OK',
#   'population': 21955,
#   'location': [35, -94],
#   'measurements': {'HighCholesterolCrdPrv': 39.1,
#    'HighBloodPressureAgeAdjPrv': 41.5,
#    'HighBloodPressureCrdPrv': 44.8,
#    'HighCholesterolAgeAdjPrv': 33.7}},
#  {'county': 'Adams',
#   'state': 'CO',
#   'population': 519883,
#   'location': [39, -104],
#   'measurements': {'HighCholesterolCrdPrv': 27.0,
#    'HighCholesterolAgeAdjPrv': 26.8,
#    'HighBloodPressureAgeAdjPrv': 25.0,
#    'HighBloodPressureCrdPrv': 23.3}},
#  {'county': 'Adams',
#   'state': 'IA',
#   'population': 3588,
#   'location': [41, -94],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 30.4,
#    'HighCholesterolCrdPrv': 37.3,
#    'HighCholesterolAgeAdjPrv': 28.6,
#    'HighBloodPressureCrdPrv': 38.6}},
#  {'county': 'Adams',
#   'state': 'ID',
#   'population': 4447,
#   'location': [44, -116],
#   'measurements': {'HighBloodPressureCrdPrv': 39.4,
#    'HighBloodPressureAgeAdjPrv': 28.2,
#    'HighCholesterolAgeAdjPrv': 26.7,
#    'HighCholesterolCrdPrv': 37.9}},
#  {'county': 'Adams',
#   'state': 'IL',
#   'population': 64783,
#   'location': [39, -91],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.1,
#    'HighCholesterolCrdPrv': 33.9,
#    'HighCholesterolAgeAdjPrv': 27.8,
#    'HighBloodPressureCrdPrv': 36.6}},
#  {'county': 'Adams',
#   'state': 'IN',
#   'population': 35839,
#   'location': [40, -84],
#   'measurements': {'HighBloodPressureCrdPrv': 37.0,
#    'HighCholesterolAgeAdjPrv': 29.6,
#    'HighCholesterolCrdPrv': 34.5,
#    'HighBloodPressureAgeAdjPrv': 33.7}},
#  {'county': 'Adams',
#   'state': 'MS',
#   'population': 30275,
#   'location': [31, -91],
#   'measurements': {'HighBloodPressureCrdPrv': 47.7,
#    'HighCholesterolAgeAdjPrv': 31.3,
#    'HighCholesterolCrdPrv': 36.5,
#    'HighBloodPressureAgeAdjPrv': 43.6}},
#  {'county': 'Adams',
#   'state': 'ND',
#   'population': 2188,
#   'location': [46, -102],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 28.9,
#    'HighCholesterolAgeAdjPrv': 26.8,
#    'HighCholesterolCrdPrv': 36.3,
#    'HighBloodPressureCrdPrv': 38.6}},
#  {'county': 'Adams',
#   'state': 'NE',
#   'population': 31321,
#   'location': [40, -98],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.2,
#    'HighBloodPressureCrdPrv': 31.8,
#    'HighBloodPressureAgeAdjPrv': 28.8,
#    'HighCholesterolCrdPrv': 34.2}},
#  {'county': 'Adams',
#   'state': 'OH',
#   'population': 27531,
#   'location': [38, -83],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.2,
#    'HighCholesterolCrdPrv': 37.2,
#    'HighBloodPressureAgeAdjPrv': 35.4,
#    'HighBloodPressureCrdPrv': 41.0}},
#  {'county': 'Adams',
#   'state': 'PA',
#   'population': 102742,
#   'location': [39, -77],
#   'measurements': {'HighCholesterolCrdPrv': 34.9,
#    'HighBloodPressureCrdPrv': 33.7,
#    'HighCholesterolAgeAdjPrv': 28.7,
#    'HighBloodPressureAgeAdjPrv': 28.6}},
#  {'county': 'Adams',
#   'state': 'WA',
#   'population': 20027,
#   'location': [47, -118],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.2,
#    'HighCholesterolCrdPrv': 30.2,
#    'HighBloodPressureAgeAdjPrv': 30.0,
#    'HighBloodPressureCrdPrv': 28.0}},
#  {'county': 'Adams',
#   'state': 'WI',
#   'population': 20498,
#   'location': [43, -89],
#   'measurements': {'HighCholesterolCrdPrv': 40.3,
#    'HighCholesterolAgeAdjPrv': 29.4,
#    'HighBloodPressureCrdPrv': 40.4,
#    'HighBloodPressureAgeAdjPrv': 30.3}},
#  {'county': 'Addison',
#   'state': 'VT',
#   'population': 36851,
#   'location': [44, -73],
#   'measurements': {'HighCholesterolAgeAdjPrv': 24.7,
#    'HighCholesterolCrdPrv': 30.0,
#    'HighBloodPressureAgeAdjPrv': 25.7,
#    'HighBloodPressureCrdPrv': 29.3}},
#  {'county': 'Aiken',
#   'state': 'SC',
#   'population': 172895,
#   'location': [33, -81],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 35.2,
#    'HighCholesterolCrdPrv': 35.9,
#    'HighCholesterolAgeAdjPrv': 30.0,
#    'HighBloodPressureCrdPrv': 40.0}},
#  {'county': 'Aitkin',
#   'state': 'MN',
#   'population': 15848,
#   'location': [46, -93],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 29.6,
#    'HighBloodPressureCrdPrv': 42.1,
#    'HighCholesterolAgeAdjPrv': 25.7,
#    'HighCholesterolCrdPrv': 37.0}},
#  {'county': 'Alachua',
#   'state': 'FL',
#   'population': 271218,
#   'location': [29, -82],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 30.9,
#    'HighCholesterolCrdPrv': 27.6,
#    'HighCholesterolAgeAdjPrv': 28.2,
#    'HighBloodPressureCrdPrv': 28.0}},
#  {'county': 'Alamance',
#   'state': 'NC',
#   'population': 171346,
#   'location': [36, -79],
#   'measurements': {'HighBloodPressureCrdPrv': 36.3,
#    'HighCholesterolCrdPrv': 34.4,
#    'HighCholesterolAgeAdjPrv': 30.6,
#    'HighBloodPressureAgeAdjPrv': 34.0}},
#  {'county': 'Alameda',
#   'state': 'CA',
#   'population': 1662323,
#   'location': [37, -121],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 25.5,
#    'HighCholesterolAgeAdjPrv': 27.1,
#    'HighCholesterolCrdPrv': 28.8,
#    'HighBloodPressureCrdPrv': 25.7}},
#  {'county': 'Alamosa',
#   'state': 'CO',
#   'population': 16180,
#   'location': [37, -105],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 28.0,
#    'HighCholesterolAgeAdjPrv': 26.5,
#    'HighBloodPressureCrdPrv': 26.6,
#    'HighCholesterolCrdPrv': 27.6}},
#  {'county': 'Albany',
#   'state': 'NY',
#   'population': 303654,
#   'location': [42, -73],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 26.1,
#    'HighBloodPressureCrdPrv': 27.3,
#    'HighCholesterolAgeAdjPrv': 28.4,
#    'HighCholesterolCrdPrv': 30.9}},
#  {'county': 'Albany',
#   'state': 'WY',
#   'population': 38950,
#   'location': [41, -105],
#   'measurements': {'HighCholesterolAgeAdjPrv': 25.8,
#    'HighBloodPressureAgeAdjPrv': 27.8,
#    'HighCholesterolCrdPrv': 23.7,
#    'HighBloodPressureCrdPrv': 22.8}},
#  {'county': 'Albemarle',
#   'state': 'VA',
#   'population': 110652,
#   'location': [38, -78],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 27.3,
#    'HighBloodPressureCrdPrv': 30.1,
#    'HighCholesterolAgeAdjPrv': 27.7,
#    'HighCholesterolCrdPrv': 31.4}},
#  {'county': 'Alcona',
#   'state': 'MI',
#   'population': 10505,
#   'location': [44, -83],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.7,
#    'HighCholesterolCrdPrv': 43.3,
#    'HighBloodPressureCrdPrv': 45.6,
#    'HighCholesterolAgeAdjPrv': 30.5}},
#  {'county': 'Alcorn',
#   'state': 'MS',
#   'population': 36889,
#   'location': [34, -88],
#   'measurements': {'HighCholesterolCrdPrv': 38.5,
#    'HighCholesterolAgeAdjPrv': 32.6,
#    'HighBloodPressureCrdPrv': 42.8,
#    'HighBloodPressureAgeAdjPrv': 38.3}},
#  {'county': 'Aleutians East',
#   'state': 'AK',
#   'population': 3401,
#   'location': [55, -161],
#   'measurements': {'HighCholesterolAgeAdjPrv': 28.4,
#    'HighCholesterolCrdPrv': 31.2,
#    'HighBloodPressureCrdPrv': 34.1,
#    'HighBloodPressureAgeAdjPrv': 34.3}},
#  {'county': 'Aleutians West',
#   'state': 'AK',
#   'population': 5680,
#   'location': [51, 178],
#   'measurements': {'HighBloodPressureCrdPrv': 30.3,
#    'HighCholesterolAgeAdjPrv': 28.2,
#    'HighCholesterolCrdPrv': 30.3,
#    'HighBloodPressureAgeAdjPrv': 31.5}},
#  {'county': 'Alexander',
#   'state': 'IL',
#   'population': 5497,
#   'location': [37, -89],
#   'measurements': {'HighBloodPressureCrdPrv': 45.7,
#    'HighBloodPressureAgeAdjPrv': 37.2,
#    'HighCholesterolCrdPrv': 37.9,
#    'HighCholesterolAgeAdjPrv': 29.3}},
#  {'county': 'Alexander',
#   'state': 'NC',
#   'population': 37441,
#   'location': [35, -81],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.2,
#    'HighCholesterolAgeAdjPrv': 30.4,
#    'HighBloodPressureCrdPrv': 36.4,
#    'HighCholesterolCrdPrv': 36.9}},
#  {'county': 'Alexandria',
#   'state': 'VA',
#   'population': 158726,
#   'location': [38, -77],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 30.8,
#    'HighCholesterolCrdPrv': 29.5,
#    'HighCholesterolAgeAdjPrv': 29.1,
#    'HighBloodPressureCrdPrv': 29.7}},
#  {'county': 'Alfalfa',
#   'state': 'OK',
#   'population': 5718,
#   'location': [36, -98],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 35.4,
#    'HighCholesterolCrdPrv': 37.9,
#    'HighCholesterolAgeAdjPrv': 31.5,
#    'HighBloodPressureCrdPrv': 40.8}},
#  {'county': 'Alger',
#   'state': 'MI',
#   'population': 9015,
#   'location': [46, -86],
#   'measurements': {'HighCholesterolCrdPrv': 38.3,
#    'HighBloodPressureAgeAdjPrv': 32.8,
#    'HighCholesterolAgeAdjPrv': 30.1,
#    'HighBloodPressureCrdPrv': 40.3}},
#  {'county': 'Allamakee',
#   'state': 'IA',
#   'population': 13642,
#   'location': [43, -91],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 29.5,
#    'HighCholesterolCrdPrv': 33.8,
#    'HighCholesterolAgeAdjPrv': 26.2,
#    'HighBloodPressureCrdPrv': 36.6}},
#  {'county': 'Allegan',
#   'state': 'MI',
#   'population': 118927,
#   'location': [42, -86],
#   'measurements': {'HighBloodPressureCrdPrv': 34.9,
#    'HighCholesterolAgeAdjPrv': 29.1,
#    'HighBloodPressureAgeAdjPrv': 31.1,
#    'HighCholesterolCrdPrv': 34.0}},
#  {'county': 'Allegany',
#   'state': 'MD',
#   'population': 70057,
#   'location': [39, -78],
#   'measurements': {'HighCholesterolAgeAdjPrv': 27.3,
#    'HighBloodPressureCrdPrv': 39.2,
#    'HighBloodPressureAgeAdjPrv': 35.8,
#    'HighCholesterolCrdPrv': 31.7}},
#  {'county': 'Allegany',
#   'state': 'NY',
#   'population': 45587,
#   'location': [42, -78],
#   'measurements': {'HighCholesterolCrdPrv': 33.6,
#    'HighBloodPressureCrdPrv': 32.3,
#    'HighBloodPressureAgeAdjPrv': 28.9,
#    'HighCholesterolAgeAdjPrv': 28.7}},
#  {'county': 'Alleghany',
#   'state': 'NC',
#   'population': 11194,
#   'location': [36, -81],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 33.1,
#    'HighCholesterolAgeAdjPrv': 31.6,
#    'HighBloodPressureCrdPrv': 42.2,
#    'HighCholesterolCrdPrv': 41.1}},
#  {'county': 'Alleghany',
#   'state': 'VA',
#   'population': 14701,
#   'location': [37, -80],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.5,
#    'HighBloodPressureCrdPrv': 42.6,
#    'HighCholesterolCrdPrv': 38.0,
#    'HighBloodPressureAgeAdjPrv': 34.1}},
#  {'county': 'Allegheny',
#   'state': 'PA',
#   'population': 1211358,
#   'location': [40, -79],
#   'measurements': {'HighCholesterolCrdPrv': 30.6,
#    'HighCholesterolAgeAdjPrv': 26.3,
#    'HighBloodPressureAgeAdjPrv': 28.5,
#    'HighBloodPressureCrdPrv': 31.9}},
#  {'county': 'Allen',
#   'state': 'IN',
#   'population': 382187,
#   'location': [41, -85],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.6,
#    'HighBloodPressureCrdPrv': 33.1,
#    'HighCholesterolAgeAdjPrv': 27.2,
#    'HighCholesterolCrdPrv': 30.3}},
#  {'county': 'Allen',
#   'state': 'KS',
#   'population': 12399,
#   'location': [37, -95],
#   'measurements': {'HighBloodPressureCrdPrv': 37.8,
#    'HighCholesterolAgeAdjPrv': 29.8,
#    'HighBloodPressureAgeAdjPrv': 32.6,
#    'HighCholesterolCrdPrv': 36.4}},
#  {'county': 'Allen',
#   'state': 'KY',
#   'population': 21303,
#   'location': [36, -86],
#   'measurements': {'HighCholesterolCrdPrv': 37.9,
#    'HighBloodPressureAgeAdjPrv': 39.3,
#    'HighBloodPressureCrdPrv': 43.9,
#    'HighCholesterolAgeAdjPrv': 32.5}},
#  {'county': 'Allen',
#   'state': 'LA',
#   'population': 25440,
#   'location': [30, -92],
#   'measurements': {'HighBloodPressureCrdPrv': 39.2,
#    'HighBloodPressureAgeAdjPrv': 37.4,
#    'HighCholesterolAgeAdjPrv': 32.1,
#    'HighCholesterolCrdPrv': 35.6}},
#  {'county': 'Allen',
#   'state': 'OH',
#   'population': 101980,
#   'location': [40, -84],
#   'measurements': {'HighCholesterolAgeAdjPrv': 26.7,
#    'HighCholesterolCrdPrv': 31.6,
#    'HighBloodPressureCrdPrv': 36.2,
#    'HighBloodPressureAgeAdjPrv': 32.7}},
#  {'county': 'Allendale',
#   'state': 'SC',
#   'population': 8331,
#   'location': [32, -81],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 46.5,
#    'HighCholesterolCrdPrv': 38.1,
#    'HighCholesterolAgeAdjPrv': 32.1,
#    'HighBloodPressureCrdPrv': 51.1}},
#  {'county': 'Alpena',
#   'state': 'MI',
#   'population': 28238,
#   'location': [44, -83],
#   'measurements': {'HighBloodPressureCrdPrv': 39.4,
#    'HighCholesterolAgeAdjPrv': 31.7,
#    'HighCholesterolCrdPrv': 40.0,
#    'HighBloodPressureAgeAdjPrv': 31.7}},
#  {'county': 'Alpine',
#   'state': 'CA',
#   'population': 1119,
#   'location': [38, -119],
#   'measurements': {'HighBloodPressureCrdPrv': 35.7,
#    'HighCholesterolAgeAdjPrv': 27.5,
#    'HighCholesterolCrdPrv': 35.4,
#    'HighBloodPressureAgeAdjPrv': 28.7}},
#  {'county': 'Amador',
#   'state': 'CA',
#   'population': 40083,
#   'location': [38, -120],
#   'measurements': {'HighCholesterolAgeAdjPrv': 27.4,
#    'HighBloodPressureCrdPrv': 34.4,
#    'HighBloodPressureAgeAdjPrv': 27.4,
#    'HighCholesterolCrdPrv': 35.2}},
#  {'county': 'Amelia',
#   'state': 'VA',
#   'population': 13014,
#   'location': [37, -77],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 35.1,
#    'HighBloodPressureCrdPrv': 41.8,
#    'HighCholesterolAgeAdjPrv': 30.9,
#    'HighCholesterolCrdPrv': 38.1}},
#  {'county': 'Amherst',
#   'state': 'VA',
#   'population': 31667,
#   'location': [37, -79],
#   'measurements': {'HighCholesterolCrdPrv': 35.7,
#    'HighCholesterolAgeAdjPrv': 29.0,
#    'HighBloodPressureCrdPrv': 40.3,
#    'HighBloodPressureAgeAdjPrv': 34.1}},
#  {'county': 'Amite',
#   'state': 'MS',
#   'population': 12205,
#   'location': [31, -90],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 42.2,
#    'HighBloodPressureCrdPrv': 50.7,
#    'HighCholesterolAgeAdjPrv': 32.9,
#    'HighCholesterolCrdPrv': 42.0}},
#  {'county': 'Anchorage',
#   'state': 'AK',
#   'population': 287095,
#   'location': [61, -149],
#   'measurements': {'HighBloodPressureCrdPrv': 28.8,
#    'HighCholesterolAgeAdjPrv': 27.8,
#    'HighBloodPressureAgeAdjPrv': 29.8,
#    'HighCholesterolCrdPrv': 29.4}},
#  {'county': 'Anderson',
#   'state': 'KS',
#   'population': 7949,
#   'location': [38, -95],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.2,
#    'HighBloodPressureAgeAdjPrv': 33.0,
#    'HighBloodPressureCrdPrv': 40.1,
#    'HighCholesterolCrdPrv': 37.0}},
#  {'county': 'Anderson',
#   'state': 'KY',
#   'population': 22833,
#   'location': [38, -84],
#   'measurements': {'HighCholesterolCrdPrv': 36.8,
#    'HighBloodPressureCrdPrv': 41.7,
#    'HighBloodPressureAgeAdjPrv': 37.6,
#    'HighCholesterolAgeAdjPrv': 31.9}},
#  {'county': 'Anderson',
#   'state': 'SC',
#   'population': 204353,
#   'location': [34, -82],
#   'measurements': {'HighCholesterolCrdPrv': 37.1,
#    'HighBloodPressureAgeAdjPrv': 35.8,
#    'HighBloodPressureCrdPrv': 40.1,
#    'HighCholesterolAgeAdjPrv': 31.4}},
#  {'county': 'Anderson',
#   'state': 'TN',
#   'population': 77558,
#   'location': [36, -84],
#   'measurements': {'HighBloodPressureCrdPrv': 42.1,
#    'HighBloodPressureAgeAdjPrv': 36.6,
#    'HighCholesterolAgeAdjPrv': 32.8,
#    'HighCholesterolCrdPrv': 39.3}},
#  {'county': 'Anderson',
#   'state': 'TX',
#   'population': 57805,
#   'location': [31, -95],
#   'measurements': {'HighBloodPressureCrdPrv': 37.7,
#    'HighCholesterolAgeAdjPrv': 31.7,
#    'HighCholesterolCrdPrv': 34.2,
#    'HighBloodPressureAgeAdjPrv': 37.4}},
#  {'county': 'Andrew',
#   'state': 'MO',
#   'population': 17586,
#   'location': [39, -94],
#   'measurements': {'HighCholesterolCrdPrv': 36.2,
#    'HighBloodPressureAgeAdjPrv': 28.6,
#    'HighBloodPressureCrdPrv': 33.7,
#    'HighCholesterolAgeAdjPrv': 29.7}},
#  {'county': 'Andrews',
#   'state': 'TX',
#   'population': 18879,
#   'location': [32, -102],
#   'measurements': {'HighCholesterolAgeAdjPrv': 31.3,
#    'HighBloodPressureAgeAdjPrv': 31.6,
#    'HighCholesterolCrdPrv': 31.6,
#    'HighBloodPressureCrdPrv': 29.3}},
#  {'county': 'Androscoggin',
#   'state': 'ME',
#   'population': 108547,
#   'location': [44, -70],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 29.8,
#    'HighBloodPressureCrdPrv': 33.8,
#    'HighCholesterolCrdPrv': 32.7,
#    'HighCholesterolAgeAdjPrv': 27.3}},
#  {'county': 'Angelina',
#   'state': 'TX',
#   'population': 86796,
#   'location': [31, -94],
#   'measurements': {'HighBloodPressureCrdPrv': 39.9,
#    'HighCholesterolAgeAdjPrv': 32.7,
#    'HighCholesterolCrdPrv': 36.7,
#    'HighBloodPressureAgeAdjPrv': 37.8}},
#  {'county': 'Anne Arundel',
#   'state': 'MD',
#   'population': 582777,
#   'location': [38, -76],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.3,
#    'HighCholesterolCrdPrv': 32.2,
#    'HighBloodPressureAgeAdjPrv': 31.0,
#    'HighBloodPressureCrdPrv': 32.7}},
#  {'county': 'Anoka',
#   'state': 'MN',
#   'population': 359921,
#   'location': [45, -93],
#   'measurements': {'HighCholesterolCrdPrv': 31.5,
#    'HighBloodPressureAgeAdjPrv': 28.2,
#    'HighCholesterolAgeAdjPrv': 27.6,
#    'HighBloodPressureCrdPrv': 30.4}},
#  {'county': 'Anson',
#   'state': 'NC',
#   'population': 24097,
#   'location': [34, -80],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.7,
#    'HighCholesterolCrdPrv': 35.8,
#    'HighBloodPressureAgeAdjPrv': 38.7,
#    'HighBloodPressureCrdPrv': 42.6}},
#  {'county': 'Antelope',
#   'state': 'NE',
#   'population': 6264,
#   'location': [42, -98],
#   'measurements': {'HighBloodPressureCrdPrv': 37.2,
#    'HighCholesterolAgeAdjPrv': 27.5,
#    'HighCholesterolCrdPrv': 35.8,
#    'HighBloodPressureAgeAdjPrv': 29.5}},
#  {'county': 'Antrim',
#   'state': 'MI',
#   'population': 23449,
#   'location': [45, -85],
#   'measurements': {'HighBloodPressureCrdPrv': 40.9,
#    'HighCholesterolAgeAdjPrv': 29.9,
#    'HighBloodPressureAgeAdjPrv': 30.9,
#    'HighCholesterolCrdPrv': 39.6}},
#  {'county': 'Apache',
#   'state': 'AZ',
#   'population': 71875,
#   'location': [35, -109],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 33.8,
#    'HighCholesterolAgeAdjPrv': 26.4,
#    'HighBloodPressureCrdPrv': 36.6,
#    'HighCholesterolCrdPrv': 31.0}},
#  {'county': 'Appanoose',
#   'state': 'IA',
#   'population': 12430,
#   'location': [40, -92],
#   'measurements': {'HighCholesterolCrdPrv': 37.1,
#    'HighBloodPressureAgeAdjPrv': 32.1,
#    'HighCholesterolAgeAdjPrv': 29.1,
#    'HighBloodPressureCrdPrv': 39.7}},
#  {'county': 'Appling',
#   'state': 'GA',
#   'population': 18325,
#   'location': [31, -82],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 37.8,
#    'HighBloodPressureCrdPrv': 41.5,
#    'HighCholesterolAgeAdjPrv': 31.8,
#    'HighCholesterolCrdPrv': 37.1}},
#  {'county': 'Appomattox',
#   'state': 'VA',
#   'population': 16043,
#   'location': [37, -78],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 33.8,
#    'HighCholesterolCrdPrv': 35.1,
#    'HighCholesterolAgeAdjPrv': 28.7,
#    'HighBloodPressureCrdPrv': 39.7}},
#  {'county': 'Aransas',
#   'state': 'TX',
#   'population': 23814,
#   'location': [28, -96],
#   'measurements': {'HighCholesterolCrdPrv': 41.4,
#    'HighBloodPressureCrdPrv': 42.7,
#    'HighBloodPressureAgeAdjPrv': 34.0,
#    'HighCholesterolAgeAdjPrv': 32.1}},
#  {'county': 'Arapahoe',
#   'state': 'CO',
#   'population': 657452,
#   'location': [39, -104],
#   'measurements': {'HighBloodPressureCrdPrv': 26.4,
#    'HighCholesterolCrdPrv': 27.6,
#    'HighCholesterolAgeAdjPrv': 25.9,
#    'HighBloodPressureAgeAdjPrv': 26.4}},
#  {'county': 'Archer',
#   'state': 'TX',
#   'population': 8730,
#   'location': [33, -98],
#   'measurements': {'HighCholesterolCrdPrv': 38.3,
#    'HighCholesterolAgeAdjPrv': 31.3,
#    'HighBloodPressureCrdPrv': 37.3,
#    'HighBloodPressureAgeAdjPrv': 31.7}},
#  {'county': 'Archuleta',
#   'state': 'CO',
#   'population': 14196,
#   'location': [37, -107],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 24.1,
#    'HighBloodPressureCrdPrv': 31.7,
#    'HighCholesterolAgeAdjPrv': 26.3,
#    'HighCholesterolCrdPrv': 34.9}},
#  {'county': 'Arenac',
#   'state': 'MI',
#   'population': 14953,
#   'location': [44, -83],
#   'measurements': {'HighCholesterolAgeAdjPrv': 31.0,
#    'HighCholesterolCrdPrv': 40.4,
#    'HighBloodPressureCrdPrv': 41.3,
#    'HighBloodPressureAgeAdjPrv': 32.2}},
#  {'county': 'Arkansas',
#   'state': 'AR',
#   'population': 17383,
#   'location': [34, -91],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 37.0,
#    'HighBloodPressureCrdPrv': 42.9,
#    'HighCholesterolAgeAdjPrv': 32.1,
#    'HighCholesterolCrdPrv': 39.0}},
#  {'county': 'Arlington',
#   'state': 'VA',
#   'population': 240119,
#   'location': [38, -77],
#   'measurements': {'HighCholesterolCrdPrv': 27.5,
#    'HighBloodPressureAgeAdjPrv': 25.0,
#    'HighCholesterolAgeAdjPrv': 28.3,
#    'HighBloodPressureCrdPrv': 22.8}},
#  {'county': 'Armstrong',
#   'state': 'PA',
#   'population': 64162,
#   'location': [40, -79],
#   'measurements': {'HighBloodPressureCrdPrv': 37.0,
#    'HighCholesterolAgeAdjPrv': 27.3,
#    'HighBloodPressureAgeAdjPrv': 29.8,
#    'HighCholesterolCrdPrv': 35.0}},
#  {'county': 'Armstrong',
#   'state': 'TX',
#   'population': 1869,
#   'location': [34, -101],
#   'measurements': {'HighCholesterolCrdPrv': 39.7,
#    'HighCholesterolAgeAdjPrv': 31.0,
#    'HighBloodPressureAgeAdjPrv': 30.9,
#    'HighBloodPressureCrdPrv': 39.1}},
#  {'county': 'Aroostook',
#   'state': 'ME',
#   'population': 66804,
#   'location': [46, -68],
#   'measurements': {'HighBloodPressureCrdPrv': 42.4,
#    'HighBloodPressureAgeAdjPrv': 34.1,
#    'HighCholesterolCrdPrv': 38.7,
#    'HighCholesterolAgeAdjPrv': 30.1}},
#  {'county': 'Arthur',
#   'state': 'NE',
#   'population': 466,
#   'location': [41, -101],
#   'measurements': {'HighCholesterolCrdPrv': 33.7,
#    'HighBloodPressureCrdPrv': 34.8,
#    'HighBloodPressureAgeAdjPrv': 30.4,
#    'HighCholesterolAgeAdjPrv': 28.0}},
#  {'county': 'Ascension',
#   'state': 'LA',
#   'population': 128665,
#   'location': [30, -90],
#   'measurements': {'HighCholesterolAgeAdjPrv': 32.4,
#    'HighCholesterolCrdPrv': 35.0,
#    'HighBloodPressureAgeAdjPrv': 34.9,
#    'HighBloodPressureCrdPrv': 35.7}},
#  {'county': 'Ashe',
#   'state': 'NC',
#   'population': 27166,
#   'location': [36, -81],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.7,
#    'HighBloodPressureCrdPrv': 40.0,
#    'HighCholesterolCrdPrv': 39.6,
#    'HighBloodPressureAgeAdjPrv': 31.5}},
#  {'county': 'Ashland',
#   'state': 'OH',
#   'population': 53362,
#   'location': [40, -82],
#   'measurements': {'HighCholesterolCrdPrv': 33.4,
#    'HighCholesterolAgeAdjPrv': 27.7,
#    'HighBloodPressureCrdPrv': 35.7,
#    'HighBloodPressureAgeAdjPrv': 31.4}},
#  {'county': 'Ashland',
#   'state': 'WI',
#   'population': 15415,
#   'location': [46, -90],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 30.5,
#    'HighBloodPressureCrdPrv': 35.9,
#    'HighCholesterolAgeAdjPrv': 28.9,
#    'HighCholesterolCrdPrv': 36.3}},
#  {'county': 'Ashley',
#   'state': 'AR',
#   'population': 19339,
#   'location': [33, -91],
#   'measurements': {'HighCholesterolCrdPrv': 39.6,
#    'HighBloodPressureAgeAdjPrv': 39.7,
#    'HighCholesterolAgeAdjPrv': 32.5,
#    'HighBloodPressureCrdPrv': 45.9}},
#  {'county': 'Ashtabula',
#   'state': 'OH',
#   'population': 96513,
#   'location': [41, -80],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.9,
#    'HighBloodPressureAgeAdjPrv': 33.4,
#    'HighBloodPressureCrdPrv': 38.7,
#    'HighCholesterolCrdPrv': 36.7}},
#  {'county': 'Asotin',
#   'state': 'WA',
#   'population': 22820,
#   'location': [46, -117],
#   'measurements': {'HighCholesterolAgeAdjPrv': 28.6,
#    'HighBloodPressureCrdPrv': 36.3,
#    'HighBloodPressureAgeAdjPrv': 29.3,
#    'HighCholesterolCrdPrv': 36.7}},
#  {'county': 'Assumption',
#   'state': 'LA',
#   'population': 21621,
#   'location': [29, -91],
#   'measurements': {'HighCholesterolCrdPrv': 37.9,
#    'HighBloodPressureAgeAdjPrv': 38.7,
#    'HighCholesterolAgeAdjPrv': 31.9,
#    'HighBloodPressureCrdPrv': 43.5}},
#  {'county': 'Atascosa',
#   'state': 'TX',
#   'population': 51724,
#   'location': [28, -98],
#   'measurements': {'HighCholesterolAgeAdjPrv': 31.8,
#    'HighBloodPressureCrdPrv': 33.7,
#    'HighCholesterolCrdPrv': 35.2,
#    'HighBloodPressureAgeAdjPrv': 32.4}},
#  {'county': 'Atchison',
#   'state': 'KS',
#   'population': 16015,
#   'location': [39, -95],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.0,
#    'HighCholesterolCrdPrv': 34.5,
#    'HighBloodPressureAgeAdjPrv': 32.3,
#    'HighBloodPressureCrdPrv': 34.8}},
#  {'county': 'Atchison',
#   'state': 'MO',
#   'population': 5096,
#   'location': [40, -95],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 29.5,
#    'HighCholesterolCrdPrv': 38.2,
#    'HighCholesterolAgeAdjPrv': 29.2,
#    'HighBloodPressureCrdPrv': 38.1}},
#  {'county': 'Athens',
#   'state': 'OH',
#   'population': 65481,
#   'location': [39, -82],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 34.2,
#    'HighCholesterolAgeAdjPrv': 27.2,
#    'HighCholesterolCrdPrv': 26.8,
#    'HighBloodPressureCrdPrv': 30.1}},
#  {'county': 'Atkinson',
#   'state': 'GA',
#   'population': 8393,
#   'location': [31, -82],
#   'measurements': {'HighCholesterolAgeAdjPrv': 31.7,
#    'HighBloodPressureAgeAdjPrv': 37.9,
#    'HighBloodPressureCrdPrv': 38.7,
#    'HighCholesterolCrdPrv': 34.7}},
#  {'county': 'Atoka',
#   'state': 'OK',
#   'population': 13912,
#   'location': [34, -96],
#   'measurements': {'HighCholesterolCrdPrv': 37.9,
#    'HighCholesterolAgeAdjPrv': 31.6,
#    'HighBloodPressureCrdPrv': 42.7,
#    'HighBloodPressureAgeAdjPrv': 37.9}},
#  {'county': 'Attala',
#   'state': 'MS',
#   'population': 18004,
#   'location': [33, -89],
#   'measurements': {'HighBloodPressureCrdPrv': 50.1,
#    'HighCholesterolAgeAdjPrv': 33.0,
#    'HighCholesterolCrdPrv': 39.4,
#    'HighBloodPressureAgeAdjPrv': 44.9}},
#  {'county': 'Audrain',
#   'state': 'MO',
#   'population': 24835,
#   'location': [39, -91],
#   'measurements': {'HighCholesterolCrdPrv': 36.2,
#    'HighBloodPressureAgeAdjPrv': 31.5,
#    'HighCholesterolAgeAdjPrv': 30.7,
#    'HighBloodPressureCrdPrv': 35.3}},
#  {'county': 'Audubon',
#   'state': 'IA',
#   'population': 5481,
#   'location': [41, -94],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 29.9,
#    'HighCholesterolCrdPrv': 36.8,
#    'HighCholesterolAgeAdjPrv': 28.2,
#    'HighBloodPressureCrdPrv': 38.2}},
#  {'county': 'Auglaize',
#   'state': 'OH',
#   'population': 45680,
#   'location': [40, -84],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.6,
#    'HighCholesterolCrdPrv': 32.5,
#    'HighBloodPressureCrdPrv': 36.7,
#    'HighCholesterolAgeAdjPrv': 26.6}},
#  {'county': 'Augusta',
#   'state': 'VA',
#   'population': 76544,
#   'location': [38, -79],
#   'measurements': {'HighBloodPressureCrdPrv': 37.7,
#    'HighCholesterolCrdPrv': 37.4,
#    'HighBloodPressureAgeAdjPrv': 31.8,
#    'HighCholesterolAgeAdjPrv': 30.5}},
#  {'county': 'Aurora',
#   'state': 'SD',
#   'population': 2730,
#   'location': [43, -98],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 26.2,
#    'HighCholesterolCrdPrv': 32.1,
#    'HighBloodPressureCrdPrv': 31.2,
#    'HighCholesterolAgeAdjPrv': 25.8}},
#  {'county': 'Austin',
#   'state': 'TX',
#   'population': 29972,
#   'location': [29, -96],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.5,
#    'HighCholesterolCrdPrv': 35.9,
#    'HighBloodPressureCrdPrv': 35.5,
#    'HighCholesterolAgeAdjPrv': 30.4}},
#  {'county': 'Autauga',
#   'state': 'AL',
#   'population': 56145,
#   'location': [32, -86],
#   'measurements': {'HighCholesterolCrdPrv': 36.4,
#    'HighBloodPressureAgeAdjPrv': 38.2,
#    'HighBloodPressureCrdPrv': 41.3,
#    'HighCholesterolAgeAdjPrv': 32.1}},
#  {'county': 'Avery',
#   'state': 'NC',
#   'population': 17571,
#   'location': [36, -81],
#   'measurements': {'HighCholesterolAgeAdjPrv': 31.3,
#    'HighBloodPressureCrdPrv': 37.6,
#    'HighBloodPressureAgeAdjPrv': 32.8,
#    'HighCholesterolCrdPrv': 37.4}},
#  {'county': 'Avoyelles',
#   'state': 'LA',
#   'population': 39966,
#   'location': [31, -91],
#   'measurements': {'HighCholesterolCrdPrv': 39.0,
#    'HighBloodPressureAgeAdjPrv': 40.2,
#    'HighCholesterolAgeAdjPrv': 34.0,
#    'HighBloodPressureCrdPrv': 43.6}},
#  {'county': 'Baca',
#   'state': 'CO',
#   'population': 3555,
#   'location': [37, -102],
#   'measurements': {'HighCholesterolCrdPrv': 34.9,
#    'HighCholesterolAgeAdjPrv': 27.4,
#    'HighBloodPressureCrdPrv': 35.5,
#    'HighBloodPressureAgeAdjPrv': 28.6}},
#  {'county': 'Bacon',
#   'state': 'GA',
#   'population': 11036,
#   'location': [31, -82],
#   'measurements': {'HighBloodPressureCrdPrv': 40.0,
#    'HighCholesterolAgeAdjPrv': 31.4,
#    'HighCholesterolCrdPrv': 36.0,
#    'HighBloodPressureAgeAdjPrv': 37.1}},
#  {'county': 'Bailey',
#   'state': 'TX',
#   'population': 6697,
#   'location': [34, -102],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.2,
#    'HighBloodPressureCrdPrv': 31.7,
#    'HighCholesterolAgeAdjPrv': 31.1,
#    'HighCholesterolCrdPrv': 33.7}},
#  {'county': 'Baker',
#   'state': 'FL',
#   'population': 29566,
#   'location': [30, -82],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 34.6,
#    'HighCholesterolCrdPrv': 32.5,
#    'HighBloodPressureCrdPrv': 36.2,
#    'HighCholesterolAgeAdjPrv': 29.1}},
#  {'county': 'Baker',
#   'state': 'GA',
#   'population': 2971,
#   'location': [31, -84],
#   'measurements': {'HighBloodPressureCrdPrv': 46.1,
#    'HighCholesterolAgeAdjPrv': 30.5,
#    'HighCholesterolCrdPrv': 38.1,
#    'HighBloodPressureAgeAdjPrv': 38.6}},
#  {'county': 'Baker',
#   'state': 'OR',
#   'population': 16284,
#   'location': [44, -117],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 29.3,
#    'HighBloodPressureCrdPrv': 37.5,
#    'HighCholesterolCrdPrv': 36.3,
#    'HighCholesterolAgeAdjPrv': 27.9}},
#  {'county': 'Baldwin',
#   'state': 'AL',
#   'population': 229287,
#   'location': [30, -87],
#   'measurements': {'HighBloodPressureCrdPrv': 39.2,
#    'HighBloodPressureAgeAdjPrv': 33.4,
#    'HighCholesterolAgeAdjPrv': 31.3,
#    'HighCholesterolCrdPrv': 37.9}},
#  {'county': 'Baldwin',
#   'state': 'GA',
#   'population': 45099,
#   'location': [33, -83],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 40.1,
#    'HighCholesterolAgeAdjPrv': 29.5,
#    'HighCholesterolCrdPrv': 31.9,
#    'HighBloodPressureCrdPrv': 39.9}},
#  {'county': 'Ballard',
#   'state': 'KY',
#   'population': 7769,
#   'location': [37, -89],
#   'measurements': {'HighBloodPressureCrdPrv': 46.9,
#    'HighCholesterolAgeAdjPrv': 32.9,
#    'HighCholesterolCrdPrv': 40.0,
#    'HighBloodPressureAgeAdjPrv': 39.9}},
#  {'county': 'Baltimore',
#   'state': 'MD',
#   'population': 826017,
#   'location': [39, -76],
#   'measurements': {'HighCholesterolCrdPrv': 33.1,
#    'HighBloodPressureCrdPrv': 35.5,
#    'HighCholesterolAgeAdjPrv': 29.2,
#    'HighBloodPressureAgeAdjPrv': 32.4}},
#  {'county': 'Baltimore City',
#   'state': 'MD',
#   'population': 586131,
#   'location': [39, -76],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.2,
#    'HighBloodPressureCrdPrv': 39.8,
#    'HighCholesterolCrdPrv': 30.9,
#    'HighBloodPressureAgeAdjPrv': 39.6}},
#  {'county': 'Bamberg',
#   'state': 'SC',
#   'population': 13906,
#   'location': [33, -81],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 41.9,
#    'HighCholesterolCrdPrv': 38.2,
#    'HighCholesterolAgeAdjPrv': 31.8,
#    'HighBloodPressureCrdPrv': 47.2}},
#  {'county': 'Bandera',
#   'state': 'TX',
#   'population': 23861,
#   'location': [29, -99],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.8,
#    'HighBloodPressureAgeAdjPrv': 31.8,
#    'HighBloodPressureCrdPrv': 41.3,
#    'HighCholesterolCrdPrv': 40.9}},
#  {'county': 'Banks',
#   'state': 'GA',
#   'population': 19352,
#   'location': [34, -83],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 34.4,
#    'HighBloodPressureCrdPrv': 38.4,
#    'HighCholesterolAgeAdjPrv': 31.3,
#    'HighCholesterolCrdPrv': 36.8}},
#  {'county': 'Banner',
#   'state': 'NE',
#   'population': 786,
#   'location': [41, -103],
#   'measurements': {'HighBloodPressureCrdPrv': 36.1,
#    'HighCholesterolAgeAdjPrv': 27.2,
#    'HighBloodPressureAgeAdjPrv': 28.5,
#    'HighCholesterolCrdPrv': 35.6}},
#  {'county': 'Bannock',
#   'state': 'ID',
#   'population': 88795,
#   'location': [42, -112],
#   'measurements': {'HighBloodPressureCrdPrv': 30.7,
#    'HighCholesterolAgeAdjPrv': 26.8,
#    'HighCholesterolCrdPrv': 29.6,
#    'HighBloodPressureAgeAdjPrv': 30.3}},
#  {'county': 'Baraga',
#   'state': 'MI',
#   'population': 8164,
#   'location': [46, -88],
#   'measurements': {'HighCholesterolCrdPrv': 37.4,
#    'HighBloodPressureAgeAdjPrv': 33.4,
#    'HighCholesterolAgeAdjPrv': 30.6,
#    'HighBloodPressureCrdPrv': 39.1}},
#  {'county': 'Barber',
#   'state': 'KS',
#   'population': 4358,
#   'location': [37, -98],
#   'measurements': {'HighCholesterolCrdPrv': 37.5,
#    'HighBloodPressureCrdPrv': 40.4,
#    'HighBloodPressureAgeAdjPrv': 32.6,
#    'HighCholesterolAgeAdjPrv': 28.9}},
#  {'county': 'Barbour',
#   'state': 'AL',
#   'population': 24589,
#   'location': [31, -85],
#   'measurements': {'HighBloodPressureCrdPrv': 49.6,
#    'HighBloodPressureAgeAdjPrv': 45.6,
#    'HighCholesterolAgeAdjPrv': 33.2,
#    'HighCholesterolCrdPrv': 38.6}},
#  {'county': 'Barbour',
#   'state': 'WV',
#   'population': 16444,
#   'location': [39, -79],
#   'measurements': {'HighBloodPressureCrdPrv': 41.7,
#    'HighBloodPressureAgeAdjPrv': 36.8,
#    'HighCholesterolCrdPrv': 36.7,
#    'HighCholesterolAgeAdjPrv': 30.7}},
#  {'county': 'Barnes',
#   'state': 'ND',
#   'population': 10402,
#   'location': [46, -98],
#   'measurements': {'HighCholesterolCrdPrv': 34.3,
#    'HighBloodPressureAgeAdjPrv': 28.6,
#    'HighBloodPressureCrdPrv': 34.6,
#    'HighCholesterolAgeAdjPrv': 27.3}},
#  {'county': 'Barnstable',
#   'state': 'MA',
#   'population': 213164,
#   'location': [41, -70],
#   'measurements': {'HighCholesterolCrdPrv': 35.5,
#    'HighCholesterolAgeAdjPrv': 26.1,
#    'HighBloodPressureAgeAdjPrv': 25.6,
#    'HighBloodPressureCrdPrv': 35.1}},
#  {'county': 'Barnwell',
#   'state': 'SC',
#   'population': 20805,
#   'location': [33, -81],
#   'measurements': {'HighCholesterolAgeAdjPrv': 32.7,
#    'HighCholesterolCrdPrv': 39.5,
#    'HighBloodPressureAgeAdjPrv': 42.3,
#    'HighBloodPressureCrdPrv': 47.6}},
#  {'county': 'Barren',
#   'state': 'KY',
#   'population': 44300,
#   'location': [36, -85],
#   'measurements': {'HighBloodPressureCrdPrv': 44.1,
#    'HighCholesterolAgeAdjPrv': 32.6,
#    'HighCholesterolCrdPrv': 37.9,
#    'HighBloodPressureAgeAdjPrv': 39.5}},
#  {'county': 'Barron',
#   'state': 'WI',
#   'population': 45090,
#   'location': [45, -91],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 29.1,
#    'HighBloodPressureCrdPrv': 35.8,
#    'HighCholesterolAgeAdjPrv': 28.4,
#    'HighCholesterolCrdPrv': 36.5}},
#  {'county': 'Barrow',
#   'state': 'GA',
#   'population': 85588,
#   'location': [33, -83],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.6,
#    'HighBloodPressureCrdPrv': 32.9,
#    'HighBloodPressureAgeAdjPrv': 32.5,
#    'HighCholesterolCrdPrv': 32.8}},
#  {'county': 'Barry',
#   'state': 'MI',
#   'population': 62061,
#   'location': [42, -85],
#   'measurements': {'HighCholesterolCrdPrv': 37.3,
#    'HighCholesterolAgeAdjPrv': 31.1,
#    'HighBloodPressureCrdPrv': 34.8,
#    'HighBloodPressureAgeAdjPrv': 29.8}},
#  {'county': 'Barry',
#   'state': 'MO',
#   'population': 35818,
#   'location': [36, -93],
#   'measurements': {'HighBloodPressureCrdPrv': 36.5,
#    'HighBloodPressureAgeAdjPrv': 30.8,
#    'HighCholesterolCrdPrv': 36.6,
#    'HighCholesterolAgeAdjPrv': 29.5}},
#  {'county': 'Bartholomew',
#   'state': 'IN',
#   'population': 84447,
#   'location': [39, -85],
#   'measurements': {'HighBloodPressureCrdPrv': 35.2,
#    'HighCholesterolAgeAdjPrv': 30.4,
#    'HighCholesterolCrdPrv': 34.2,
#    'HighBloodPressureAgeAdjPrv': 32.9}},
#  {'county': 'Barton',
#   'state': 'KS',
#   'population': 25658,
#   'location': [38, -98],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.4,
#    'HighBloodPressureCrdPrv': 37.2,
#    'HighBloodPressureAgeAdjPrv': 32.9,
#    'HighCholesterolCrdPrv': 36.2}},
#  {'county': 'Barton',
#   'state': 'MO',
#   'population': 11592,
#   'location': [37, -94],
#   'measurements': {'HighBloodPressureCrdPrv': 38.0,
#    'HighBloodPressureAgeAdjPrv': 31.7,
#    'HighCholesterolCrdPrv': 37.8,
#    'HighCholesterolAgeAdjPrv': 30.3}},
#  {'county': 'Bartow',
#   'state': 'GA',
#   'population': 109426,
#   'location': [34, -84],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.9,
#    'HighBloodPressureAgeAdjPrv': 34.2,
#    'HighBloodPressureCrdPrv': 36.1,
#    'HighCholesterolCrdPrv': 34.6}},
#  {'county': 'Bastrop',
#   'state': 'TX',
#   'population': 91601,
#   'location': [30, -97],
#   'measurements': {'HighBloodPressureCrdPrv': 33.2,
#    'HighBloodPressureAgeAdjPrv': 31.8,
#    'HighCholesterolAgeAdjPrv': 31.8,
#    'HighCholesterolCrdPrv': 35.4}},
#  {'county': 'Bates',
#   'state': 'MO',
#   'population': 16242,
#   'location': [38, -94],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.3,
#    'HighCholesterolCrdPrv': 37.2,
#    'HighBloodPressureAgeAdjPrv': 29.8,
#    'HighBloodPressureCrdPrv': 35.1}},
#  {'county': 'Bath',
#   'state': 'KY',
#   'population': 12481,
#   'location': [38, -83],
#   'measurements': {'HighCholesterolAgeAdjPrv': 33.4,
#    'HighBloodPressureCrdPrv': 43.7,
#    'HighBloodPressureAgeAdjPrv': 38.9,
#    'HighCholesterolCrdPrv': 39.0}},
#  {'county': 'Bath',
#   'state': 'VA',
#   'population': 4119,
#   'location': [38, -79],
#   'measurements': {'HighCholesterolCrdPrv': 39.9,
#    'HighBloodPressureAgeAdjPrv': 35.0,
#    'HighBloodPressureCrdPrv': 44.8,
#    'HighCholesterolAgeAdjPrv': 30.3}},
#  {'county': 'Baxter',
#   'state': 'AR',
#   'population': 42242,
#   'location': [36, -92],
#   'measurements': {'HighCholesterolCrdPrv': 42.1,
#    'HighCholesterolAgeAdjPrv': 31.4,
#    'HighBloodPressureCrdPrv': 43.6,
#    'HighBloodPressureAgeAdjPrv': 32.6}},
#  {'county': 'Bay',
#   'state': 'FL',
#   'population': 171322,
#   'location': [30, -85],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.6,
#    'HighCholesterolAgeAdjPrv': 28.2,
#    'HighBloodPressureCrdPrv': 35.7,
#    'HighCholesterolCrdPrv': 33.5}},
#  {'county': 'Bay',
#   'state': 'MI',
#   'population': 102387,
#   'location': [43, -83],
#   'measurements': {'HighCholesterolCrdPrv': 37.0,
#    'HighCholesterolAgeAdjPrv': 30.7,
#    'HighBloodPressureCrdPrv': 36.2,
#    'HighBloodPressureAgeAdjPrv': 30.8}},
#  {'county': 'Bayfield',
#   'state': 'WI',
#   'population': 15242,
#   'location': [46, -91],
#   'measurements': {'HighBloodPressureCrdPrv': 39.1,
#    'HighBloodPressureAgeAdjPrv': 29.1,
#    'HighCholesterolCrdPrv': 37.1,
#    'HighCholesterolAgeAdjPrv': 26.7}},
#  {'county': 'Baylor',
#   'state': 'TX',
#   'population': 3518,
#   'location': [33, -99],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.9,
#    'HighBloodPressureCrdPrv': 38.9,
#    'HighCholesterolCrdPrv': 38.5,
#    'HighBloodPressureAgeAdjPrv': 32.0}},
#  {'county': 'Beadle',
#   'state': 'SD',
#   'population': 18513,
#   'location': [44, -98],
#   'measurements': {'HighCholesterolAgeAdjPrv': 26.8,
#    'HighCholesterolCrdPrv': 32.2,
#    'HighBloodPressureCrdPrv': 32.3,
#    'HighBloodPressureAgeAdjPrv': 28.7}},
#  {'county': 'Bear Lake',
#   'state': 'ID',
#   'population': 6143,
#   'location': [42, -111],
#   'measurements': {'HighCholesterolAgeAdjPrv': 25.6,
#    'HighCholesterolCrdPrv': 32.5,
#    'HighBloodPressureAgeAdjPrv': 28.7,
#    'HighBloodPressureCrdPrv': 34.5}},
#  {'county': 'Beaufort',
#   'state': 'NC',
#   'population': 47073,
#   'location': [35, -76],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.9,
#    'HighBloodPressureCrdPrv': 41.8,
#    'HighCholesterolCrdPrv': 37.7,
#    'HighBloodPressureAgeAdjPrv': 34.4}},
#  {'county': 'Beaufort',
#   'state': 'SC',
#   'population': 195656,
#   'location': [32, -80],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.8,
#    'HighCholesterolAgeAdjPrv': 30.9,
#    'HighBloodPressureCrdPrv': 38.7,
#    'HighCholesterolCrdPrv': 38.7}},
#  {'county': 'Beauregard',
#   'state': 'LA',
#   'population': 37881,
#   'location': [30, -93],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 35.7,
#    'HighCholesterolCrdPrv': 37.2,
#    'HighCholesterolAgeAdjPrv': 33.0,
#    'HighBloodPressureCrdPrv': 38.3}},
#  {'county': 'Beaver',
#   'state': 'OK',
#   'population': 5207,
#   'location': [36, -100],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.1,
#    'HighCholesterolCrdPrv': 35.3,
#    'HighBloodPressureAgeAdjPrv': 34.2,
#    'HighBloodPressureCrdPrv': 38.2}},
#  {'county': 'Beaver',
#   'state': 'PA',
#   'population': 162575,
#   'location': [40, -80],
#   'measurements': {'HighCholesterolCrdPrv': 37.0,
#    'HighBloodPressureAgeAdjPrv': 30.0,
#    'HighBloodPressureCrdPrv': 36.2,
#    'HighCholesterolAgeAdjPrv': 29.9}},
#  {'county': 'Beaver',
#   'state': 'UT',
#   'population': 6761,
#   'location': [38, -113],
#   'measurements': {'HighBloodPressureCrdPrv': 29.6,
#    'HighCholesterolAgeAdjPrv': 28.0,
#    'HighCholesterolCrdPrv': 32.0,
#    'HighBloodPressureAgeAdjPrv': 28.0}},
#  {'county': 'Beaverhead',
#   'state': 'MT',
#   'population': 9483,
#   'location': [45, -112],
#   'measurements': {'HighCholesterolCrdPrv': 31.5,
#    'HighBloodPressureAgeAdjPrv': 26.1,
#    'HighBloodPressureCrdPrv': 30.0,
#    'HighCholesterolAgeAdjPrv': 25.9}},
#  {'county': 'Becker',
#   'state': 'MN',
#   'population': 34456,
#   'location': [46, -95],
#   'measurements': {'HighCholesterolCrdPrv': 34.5,
#    'HighBloodPressureAgeAdjPrv': 27.3,
#    'HighBloodPressureCrdPrv': 33.3,
#    'HighCholesterolAgeAdjPrv': 27.4}},
#  {'county': 'Beckham',
#   'state': 'OK',
#   'population': 21468,
#   'location': [35, -99],
#   'measurements': {'HighBloodPressureCrdPrv': 36.3,
#    'HighCholesterolAgeAdjPrv': 32.1,
#    'HighCholesterolCrdPrv': 34.6,
#    'HighBloodPressureAgeAdjPrv': 36.1}},
#  {'county': 'Bedford',
#   'state': 'PA',
#   'population': 47817,
#   'location': [39, -78],
#   'measurements': {'HighCholesterolCrdPrv': 36.5,
#    'HighBloodPressureAgeAdjPrv': 30.1,
#    'HighBloodPressureCrdPrv': 37.5,
#    'HighCholesterolAgeAdjPrv': 28.5}},
#  {'county': 'Bedford',
#   'state': 'TN',
#   'population': 50179,
#   'location': [35, -86],
#   'measurements': {'HighBloodPressureCrdPrv': 37.3,
#    'HighBloodPressureAgeAdjPrv': 35.8,
#    'HighCholesterolAgeAdjPrv': 30.2,
#    'HighCholesterolCrdPrv': 33.5}},
#  {'county': 'Bedford',
#   'state': 'VA',
#   'population': 79811,
#   'location': [37, -79],
#   'measurements': {'HighCholesterolCrdPrv': 36.4,
#    'HighBloodPressureAgeAdjPrv': 30.4,
#    'HighBloodPressureCrdPrv': 37.2,
#    'HighCholesterolAgeAdjPrv': 29.0}},
#  {'county': 'Bee',
#   'state': 'TX',
#   'population': 32513,
#   'location': [28, -97],
#   'measurements': {'HighCholesterolAgeAdjPrv': 32.0,
#    'HighBloodPressureCrdPrv': 33.3,
#    'HighBloodPressureAgeAdjPrv': 35.1,
#    'HighCholesterolCrdPrv': 33.0}},
#  {'county': 'Belknap',
#   'state': 'NH',
#   'population': 61551,
#   'location': [43, -71],
#   'measurements': {'HighCholesterolCrdPrv': 35.1,
#    'HighBloodPressureAgeAdjPrv': 28.3,
#    'HighCholesterolAgeAdjPrv': 27.4,
#    'HighBloodPressureCrdPrv': 35.2}},
#  {'county': 'Bell',
#   'state': 'KY',
#   'population': 25482,
#   'location': [36, -83],
#   'measurements': {'HighCholesterolAgeAdjPrv': 35.6,
#    'HighBloodPressureAgeAdjPrv': 44.7,
#    'HighBloodPressureCrdPrv': 50.1,
#    'HighCholesterolCrdPrv': 42.1}},
#  {'county': 'Bell',
#   'state': 'TX',
#   'population': 369927,
#   'location': [31, -97],
#   'measurements': {'HighBloodPressureCrdPrv': 30.9,
#    'HighCholesterolAgeAdjPrv': 29.8,
#    'HighBloodPressureAgeAdjPrv': 33.4,
#    'HighCholesterolCrdPrv': 29.7}},
#  {'county': 'Belmont',
#   'state': 'OH',
#   'population': 65932,
#   'location': [40, -80],
#   'measurements': {'HighCholesterolCrdPrv': 35.1,
#    'HighBloodPressureAgeAdjPrv': 30.4,
#    'HighBloodPressureCrdPrv': 36.0,
#    'HighCholesterolAgeAdjPrv': 28.3}},
#  {'county': 'Beltrami',
#   'state': 'MN',
#   'population': 47442,
#   'location': [47, -95],
#   'measurements': {'HighBloodPressureCrdPrv': 28.8,
#    'HighCholesterolCrdPrv': 30.1,
#    'HighBloodPressureAgeAdjPrv': 27.2,
#    'HighCholesterolAgeAdjPrv': 26.5}},
#  {'county': 'Ben Hill',
#   'state': 'GA',
#   'population': 16614,
#   'location': [31, -83],
#   'measurements': {'HighCholesterolCrdPrv': 36.1,
#    'HighBloodPressureAgeAdjPrv': 39.1,
#    'HighBloodPressureCrdPrv': 43.3,
#    'HighCholesterolAgeAdjPrv': 30.7}},
#  {'county': 'Benewah',
#   'state': 'ID',
#   'population': 9430,
#   'location': [47, -116],
#   'measurements': {'HighCholesterolCrdPrv': 35.5,
#    'HighBloodPressureAgeAdjPrv': 29.6,
#    'HighBloodPressureCrdPrv': 37.1,
#    'HighCholesterolAgeAdjPrv': 26.8}},
#  {'county': 'Bennett',
#   'state': 'SD',
#   'population': 3399,
#   'location': [43, -101],
#   'measurements': {'HighCholesterolAgeAdjPrv': 26.1,
#    'HighBloodPressureAgeAdjPrv': 34.9,
#    'HighCholesterolCrdPrv': 30.1,
#    'HighBloodPressureCrdPrv': 36.3}},
#  {'county': 'Bennington',
#   'state': 'VT',
#   'population': 35338,
#   'location': [43, -73],
#   'measurements': {'HighCholesterolAgeAdjPrv': 23.6,
#    'HighCholesterolCrdPrv': 30.5,
#    'HighBloodPressureAgeAdjPrv': 24.3,
#    'HighBloodPressureCrdPrv': 30.3}},
#  {'county': 'Benson',
#   'state': 'ND',
#   'population': 6762,
#   'location': [48, -99],
#   'measurements': {'HighCholesterolCrdPrv': 32.3,
#    'HighBloodPressureCrdPrv': 39.0,
#    'HighBloodPressureAgeAdjPrv': 35.8,
#    'HighCholesterolAgeAdjPrv': 27.0}},
#  {'county': 'Bent',
#   'state': 'CO',
#   'population': 5356,
#   'location': [37, -103],
#   'measurements': {'HighCholesterolAgeAdjPrv': 27.8,
#    'HighCholesterolCrdPrv': 31.4,
#    'HighBloodPressureCrdPrv': 33.3,
#    'HighBloodPressureAgeAdjPrv': 31.8}},
#  {'county': 'Benton',
#   'state': 'AR',
#   'population': 288774,
#   'location': [36, -94],
#   'measurements': {'HighCholesterolCrdPrv': 31.9,
#    'HighCholesterolAgeAdjPrv': 30.0,
#    'HighBloodPressureCrdPrv': 31.6,
#    'HighBloodPressureAgeAdjPrv': 31.5}},
#  {'county': 'Benton',
#   'state': 'IA',
#   'population': 25414,
#   'location': [42, -92],
#   'measurements': {'HighBloodPressureCrdPrv': 33.6,
#    'HighCholesterolAgeAdjPrv': 27.6,
#    'HighCholesterolCrdPrv': 34.2,
#    'HighBloodPressureAgeAdjPrv': 28.1}},
#  {'county': 'Benton',
#   'state': 'IN',
#   'population': 8741,
#   'location': [40, -87],
#   'measurements': {'HighBloodPressureCrdPrv': 37.7,
#    'HighBloodPressureAgeAdjPrv': 32.9,
#    'HighCholesterolAgeAdjPrv': 29.2,
#    'HighCholesterolCrdPrv': 35.1}},
#  {'county': 'Benton',
#   'state': 'MN',
#   'population': 40958,
#   'location': [45, -94],
#   'measurements': {'HighBloodPressureCrdPrv': 28.1,
#    'HighBloodPressureAgeAdjPrv': 26.7,
#    'HighCholesterolCrdPrv': 28.8,
#    'HighCholesterolAgeAdjPrv': 25.7}},
#  {'county': 'Benton',
#   'state': 'MO',
#   'population': 19627,
#   'location': [38, -93],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.9,
#    'HighBloodPressureAgeAdjPrv': 31.3,
#    'HighBloodPressureCrdPrv': 43.0,
#    'HighCholesterolCrdPrv': 42.7}},
#  {'county': 'Benton',
#   'state': 'MS',
#   'population': 8351,
#   'location': [34, -89],
#   'measurements': {'HighBloodPressureCrdPrv': 46.3,
#    'HighCholesterolCrdPrv': 39.3,
#    'HighBloodPressureAgeAdjPrv': 41.1,
#    'HighCholesterolAgeAdjPrv': 32.8}},
#  {'county': 'Benton',
#   'state': 'OR',
#   'population': 93239,
#   'location': [44, -123],
#   'measurements': {'HighCholesterolCrdPrv': 26.3,
#    'HighBloodPressureCrdPrv': 24.5,
#    'HighCholesterolAgeAdjPrv': 25.8,
#    'HighBloodPressureAgeAdjPrv': 25.8}},
#  {'county': 'Benton',
#   'state': 'TN',
#   'population': 16131,
#   'location': [36, -88],
#   'measurements': {'HighCholesterolAgeAdjPrv': 33.4,
#    'HighBloodPressureAgeAdjPrv': 37.7,
#    'HighBloodPressureCrdPrv': 45.9,
#    'HighCholesterolCrdPrv': 42.2}},
#  {'county': 'Benton',
#   'state': 'WA',
#   'population': 206426,
#   'location': [46, -119],
#   'measurements': {'HighBloodPressureCrdPrv': 29.1,
#    'HighCholesterolCrdPrv': 32.3,
#    'HighCholesterolAgeAdjPrv': 29.2,
#    'HighBloodPressureAgeAdjPrv': 28.2}},
#  {'county': 'Benzie',
#   'state': 'MI',
#   'population': 17852,
#   'location': [44, -86],
#   'measurements': {'HighBloodPressureCrdPrv': 38.3,
#    'HighCholesterolAgeAdjPrv': 29.5,
#    'HighCholesterolCrdPrv': 38.5,
#    'HighBloodPressureAgeAdjPrv': 29.4}},
#  {'county': 'Berkeley',
#   'state': 'SC',
#   'population': 235987,
#   'location': [33, -79],
#   'measurements': {'HighCholesterolAgeAdjPrv': 31.7,
#    'HighCholesterolCrdPrv': 34.7,
#    'HighBloodPressureCrdPrv': 36.2,
#    'HighBloodPressureAgeAdjPrv': 35.2}},
#  {'county': 'Berkeley',
#   'state': 'WV',
#   'population': 122125,
#   'location': [39, -78],
# ...
#    'HighCholesterolCrdPrv': 35.1,
#    'HighBloodPressureAgeAdjPrv': 30.7}},
#  {'county': 'Ford',
#   'state': 'KS',
#   'population': 33094,
#   'location': [37, -99],
#   'measurements': {'HighCholesterolCrdPrv': 30.5,
#    'HighCholesterolAgeAdjPrv': 30.1,
#    'HighBloodPressureCrdPrv': 31.0,
#    'HighBloodPressureAgeAdjPrv': 33.4}},
#  {'county': 'Forest',
#   'state': 'PA',
#   'population': 6965,
#   'location': [41, -79],
#   'measurements': {'HighBloodPressureCrdPrv': 38.3,
#    'HighCholesterolAgeAdjPrv': 29.1,
#    'HighCholesterolCrdPrv': 33.3,
#    'HighBloodPressureAgeAdjPrv': 36.1}},
#  {'county': 'Forest',
#   'state': 'WI',
#   'population': 8960,
#   'location': [45, -88],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.4,
#    'HighCholesterolCrdPrv': 37.2,
#    'HighCholesterolAgeAdjPrv': 28.6,
#    'HighBloodPressureCrdPrv': 38.5}},
#  {'county': 'Forrest',
#   'state': 'MS',
#   'population': 75009,
#   'location': [31, -89],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 41.2,
#    'HighBloodPressureCrdPrv': 40.2,
#    'HighCholesterolCrdPrv': 35.3,
#    'HighCholesterolAgeAdjPrv': 33.9}},
#  {'county': 'Forsyth',
#   'state': 'GA',
#   'population': 250847,
#   'location': [34, -84],
#   'measurements': {'HighCholesterolCrdPrv': 33.9,
#    'HighBloodPressureAgeAdjPrv': 26.9,
#    'HighCholesterolAgeAdjPrv': 30.8,
#    'HighBloodPressureCrdPrv': 28.3}},
#  {'county': 'Forsyth',
#   'state': 'NC',
#   'population': 383843,
#   'location': [36, -80],
#   'measurements': {'HighCholesterolCrdPrv': 33.1,
#    'HighBloodPressureAgeAdjPrv': 31.5,
#    'HighBloodPressureCrdPrv': 33.6,
#    'HighCholesterolAgeAdjPrv': 29.7}},
#  {'county': 'Fort Bend',
#   'state': 'TX',
#   'population': 839706,
#   'location': [29, -95],
#   'measurements': {'HighCholesterolCrdPrv': 34.2,
#    'HighBloodPressureCrdPrv': 31.9,
#    'HighCholesterolAgeAdjPrv': 32.0,
#    'HighBloodPressureAgeAdjPrv': 31.6}},
#  {'county': 'Foster',
#   'state': 'ND',
#   'population': 3165,
#   'location': [47, -98],
#   'measurements': {'HighCholesterolAgeAdjPrv': 27.2,
#    'HighBloodPressureAgeAdjPrv': 28.9,
#    'HighCholesterolCrdPrv': 34.9,
#    'HighBloodPressureCrdPrv': 36.0}},
#  {'county': 'Fountain',
#   'state': 'IN',
#   'population': 16511,
#   'location': [40, -87],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 32.3,
#    'HighCholesterolAgeAdjPrv': 30.3,
#    'HighBloodPressureCrdPrv': 38.1,
#    'HighCholesterolCrdPrv': 37.2}},
#  {'county': 'Franklin',
#   'state': 'AL',
#   'population': 31507,
#   'location': [34, -87],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 37.7,
#    'HighCholesterolAgeAdjPrv': 32.1,
#    'HighBloodPressureCrdPrv': 40.4,
#    'HighCholesterolCrdPrv': 36.2}},
#  {'county': 'Franklin',
#   'state': 'AR',
#   'population': 17897,
#   'location': [35, -93],
#   'measurements': {'HighCholesterolCrdPrv': 42.1,
#    'HighCholesterolAgeAdjPrv': 34.9,
#    'HighBloodPressureAgeAdjPrv': 36.6,
#    'HighBloodPressureCrdPrv': 42.1}},
#  {'county': 'Franklin',
#   'state': 'FL',
#   'population': 12201,
#   'location': [29, -84],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.8,
#    'HighCholesterolCrdPrv': 36.5,
#    'HighBloodPressureAgeAdjPrv': 35.2,
#    'HighBloodPressureCrdPrv': 40.6}},
#  {'county': 'Franklin',
#   'state': 'GA',
#   'population': 23504,
#   'location': [34, -83],
#   'measurements': {'HighBloodPressureCrdPrv': 38.9,
#    'HighBloodPressureAgeAdjPrv': 34.9,
#    'HighCholesterolCrdPrv': 36.8,
#    'HighCholesterolAgeAdjPrv': 31.3}},
#  {'county': 'Franklin',
#   'state': 'IA',
#   'population': 9971,
#   'location': [42, -93],
#   'measurements': {'HighBloodPressureCrdPrv': 36.4,
#    'HighCholesterolCrdPrv': 33.8,
#    'HighBloodPressureAgeAdjPrv': 30.6,
#    'HighCholesterolAgeAdjPrv': 27.3}},
#  {'county': 'Franklin',
#   'state': 'ID',
#   'population': 14215,
#   'location': [42, -111],
#   'measurements': {'HighCholesterolCrdPrv': 31.4,
#    'HighBloodPressureAgeAdjPrv': 27.3,
#    'HighBloodPressureCrdPrv': 29.5,
#    'HighCholesterolAgeAdjPrv': 27.0}},
#  {'county': 'Franklin',
#   'state': 'IL',
#   'population': 38060,
#   'location': [37, -88],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 32.9,
#    'HighBloodPressureCrdPrv': 39.0,
#    'HighCholesterolCrdPrv': 36.1,
#    'HighCholesterolAgeAdjPrv': 29.2}},
#  {'county': 'Franklin',
#   'state': 'IN',
#   'population': 22761,
#   'location': [39, -85],
#   'measurements': {'HighCholesterolAgeAdjPrv': 28.3,
#    'HighBloodPressureAgeAdjPrv': 31.5,
#    'HighCholesterolCrdPrv': 34.9,
#    'HighBloodPressureCrdPrv': 37.0}},
#  {'county': 'Franklin',
#   'state': 'KS',
#   'population': 25703,
#   'location': [38, -95],
#   'measurements': {'HighCholesterolCrdPrv': 34.1,
#    'HighCholesterolAgeAdjPrv': 28.6,
#    'HighBloodPressureAgeAdjPrv': 30.9,
#    'HighBloodPressureCrdPrv': 34.7}},
#  {'county': 'Franklin',
#   'state': 'KY',
#   'population': 51118,
#   'location': [38, -84],
#   'measurements': {'HighCholesterolAgeAdjPrv': 32.7,
#    'HighBloodPressureCrdPrv': 42.0,
#    'HighBloodPressureAgeAdjPrv': 38.2,
#    'HighCholesterolCrdPrv': 37.2}},
#  {'county': 'Franklin',
#   'state': 'LA',
#   'population': 19723,
#   'location': [32, -91],
#   'measurements': {'HighBloodPressureCrdPrv': 45.0,
#    'HighCholesterolAgeAdjPrv': 32.4,
#    'HighCholesterolCrdPrv': 38.3,
#    'HighBloodPressureAgeAdjPrv': 40.3}},
#  {'county': 'Franklin',
#   'state': 'MA',
#   'population': 70267,
#   'location': [42, -72],
#   'measurements': {'HighBloodPressureCrdPrv': 31.5,
#    'HighBloodPressureAgeAdjPrv': 25.6,
#    'HighCholesterolCrdPrv': 32.1,
#    'HighCholesterolAgeAdjPrv': 25.5}},
#  {'county': 'Franklin',
#   'state': 'ME',
#   'population': 29986,
#   'location': [44, -70],
#   'measurements': {'HighCholesterolAgeAdjPrv': 27.5,
#    'HighBloodPressureAgeAdjPrv': 29.0,
#    'HighBloodPressureCrdPrv': 35.3,
#    'HighCholesterolCrdPrv': 34.8}},
#  {'county': 'Franklin',
#   'state': 'MO',
#   'population': 104469,
#   'location': [38, -91],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 28.3,
#    'HighCholesterolCrdPrv': 36.9,
#    'HighCholesterolAgeAdjPrv': 30.6,
#    'HighBloodPressureCrdPrv': 32.9}},
#  {'county': 'Franklin',
#   'state': 'MS',
#   'population': 7657,
#   'location': [31, -90],
#   'measurements': {'HighCholesterolCrdPrv': 40.7,
#    'HighCholesterolAgeAdjPrv': 33.2,
#    'HighBloodPressureAgeAdjPrv': 41.4,
#    'HighBloodPressureCrdPrv': 48.0}},
#  {'county': 'Franklin',
#   'state': 'NC',
#   'population': 71859,
#   'location': [36, -78],
#   'measurements': {'HighCholesterolCrdPrv': 35.7,
#    'HighBloodPressureAgeAdjPrv': 33.7,
#    'HighCholesterolAgeAdjPrv': 30.7,
#    'HighBloodPressureCrdPrv': 37.4}},
#  {'county': 'Franklin',
#   'state': 'NE',
#   'population': 2940,
#   'location': [40, -98],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.3,
#    'HighCholesterolCrdPrv': 37.8,
#    'HighCholesterolAgeAdjPrv': 27.9,
#    'HighBloodPressureCrdPrv': 41.3}},
#  {'county': 'Franklin',
#   'state': 'NY',
#   'population': 49965,
#   'location': [44, -74],
#   'measurements': {'HighCholesterolCrdPrv': 33.6,
#    'HighCholesterolAgeAdjPrv': 29.4,
#    'HighBloodPressureCrdPrv': 35.4,
#    'HighBloodPressureAgeAdjPrv': 32.8}},
#  {'county': 'Franklin',
#   'state': 'OH',
#   'population': 1324624,
#   'location': [39, -83],
#   'measurements': {'HighBloodPressureCrdPrv': 31.3,
#    'HighCholesterolAgeAdjPrv': 28.3,
#    'HighCholesterolCrdPrv': 29.5,
#    'HighBloodPressureAgeAdjPrv': 32.2}},
#  {'county': 'Franklin',
#   'state': 'PA',
#   'population': 155637,
#   'location': [39, -77],
#   'measurements': {'HighCholesterolAgeAdjPrv': 27.7,
#    'HighBloodPressureCrdPrv': 35.7,
#    'HighBloodPressureAgeAdjPrv': 30.8,
#    'HighCholesterolCrdPrv': 33.5}},
#  {'county': 'Franklin',
#   'state': 'TN',
#   'population': 42485,
#   'location': [35, -86],
#   'measurements': {'HighCholesterolCrdPrv': 37.2,
#    'HighCholesterolAgeAdjPrv': 31.5,
#    'HighBloodPressureCrdPrv': 40.4,
#    'HighBloodPressureAgeAdjPrv': 36.0}},
#  {'county': 'Franklin',
#   'state': 'TX',
#   'population': 10821,
#   'location': [33, -95],
#   'measurements': {'HighBloodPressureCrdPrv': 36.4,
#    'HighCholesterolAgeAdjPrv': 30.6,
#    'HighCholesterolCrdPrv': 37.4,
#    'HighBloodPressureAgeAdjPrv': 30.6}},
#  {'county': 'Franklin',
#   'state': 'VA',
#   'population': 56167,
#   'location': [36, -79],
#   'measurements': {'HighBloodPressureCrdPrv': 42.3,
#    'HighBloodPressureAgeAdjPrv': 34.4,
#    'HighCholesterolAgeAdjPrv': 30.1,
#    'HighCholesterolCrdPrv': 38.5}},
#  {'county': 'Franklin',
#   'state': 'VT',
#   'population': 49685,
#   'location': [44, -72],
#   'measurements': {'HighCholesterolAgeAdjPrv': 25.2,
#    'HighBloodPressureCrdPrv': 29.3,
#    'HighBloodPressureAgeAdjPrv': 25.8,
#    'HighCholesterolCrdPrv': 30.4}},
#  {'county': 'Franklin',
#   'state': 'WA',
#   'population': 97075,
#   'location': [46, -118],
#   'measurements': {'HighBloodPressureCrdPrv': 26.2,
#    'HighCholesterolAgeAdjPrv': 29.4,
#    'HighBloodPressureAgeAdjPrv': 29.4,
#    'HighCholesterolCrdPrv': 29.0}},
#  {'county': 'Franklin City',
#   'state': 'VA',
#   'population': 7833,
#   'location': [36, -76],
#   'measurements': {'HighBloodPressureCrdPrv': 46.3,
#    'HighCholesterolAgeAdjPrv': 29.1,
#    'HighCholesterolCrdPrv': 35.2,
#    'HighBloodPressureAgeAdjPrv': 40.6}},
#  {'county': 'Frederick',
#   'state': 'MD',
#   'population': 265161,
#   'location': [39, -77],
#   'measurements': {'HighBloodPressureCrdPrv': 31.0,
#    'HighCholesterolAgeAdjPrv': 30.9,
#    'HighCholesterolCrdPrv': 34.4,
#    'HighBloodPressureAgeAdjPrv': 29.1}},
#  {'county': 'Frederick',
#   'state': 'VA',
#   'population': 91119,
#   'location': [39, -78],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.1,
#    'HighBloodPressureCrdPrv': 34.9,
#    'HighCholesterolAgeAdjPrv': 29.0,
#    'HighCholesterolCrdPrv': 33.8}},
#  {'county': 'Fredericksburg',
#   'state': 'VA',
#   'population': 29492,
#   'location': [38, -77],
#   'measurements': {'HighBloodPressureCrdPrv': 30.1,
#    'HighCholesterolAgeAdjPrv': 29.0,
#    'HighCholesterolCrdPrv': 27.8,
#    'HighBloodPressureAgeAdjPrv': 33.6}},
#  {'county': 'Freeborn',
#   'state': 'MN',
#   'population': 30364,
#   'location': [43, -93],
#   'measurements': {'HighBloodPressureCrdPrv': 33.2,
#    'HighCholesterolCrdPrv': 33.1,
#    'HighCholesterolAgeAdjPrv': 26.4,
#    'HighBloodPressureAgeAdjPrv': 27.3}},
#  {'county': 'Freestone',
#   'state': 'TX',
#   'population': 19874,
#   'location': [31, -96],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 36.0,
#    'HighCholesterolCrdPrv': 38.0,
#    'HighBloodPressureCrdPrv': 40.6,
#    'HighCholesterolAgeAdjPrv': 32.0}},
#  {'county': 'Fremont',
#   'state': 'CO',
#   'population': 47867,
#   'location': [38, -105],
#   'measurements': {'HighBloodPressureCrdPrv': 31.2,
#    'HighCholesterolCrdPrv': 31.6,
#    'HighBloodPressureAgeAdjPrv': 27.2,
#    'HighCholesterolAgeAdjPrv': 26.3}},
#  {'county': 'Fremont',
#   'state': 'IA',
#   'population': 6729,
#   'location': [40, -95],
#   'measurements': {'HighCholesterolCrdPrv': 36.8,
#    'HighBloodPressureCrdPrv': 38.0,
#    'HighBloodPressureAgeAdjPrv': 30.3,
#    'HighCholesterolAgeAdjPrv': 28.6}},
#  {'county': 'Fremont',
#   'state': 'ID',
#   'population': 13218,
#   'location': [44, -111],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 29.3,
#    'HighCholesterolCrdPrv': 32.2,
#    'HighCholesterolAgeAdjPrv': 27.3,
#    'HighBloodPressureCrdPrv': 32.2}},
#  {'county': 'Fremont',
#   'state': 'WY',
#   'population': 39317,
#   'location': [43, -108],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 25.3,
#    'HighBloodPressureCrdPrv': 29.4,
#    'HighCholesterolAgeAdjPrv': 24.8,
#    'HighCholesterolCrdPrv': 30.4}},
#  {'county': 'Fresno',
#   'state': 'CA',
#   'population': 1000918,
#   'location': [36, -119],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 29.7,
#    'HighBloodPressureCrdPrv': 28.5,
#    'HighCholesterolAgeAdjPrv': 28.0,
#    'HighCholesterolCrdPrv': 29.0}},
#  {'county': 'Frio',
#   'state': 'TX',
#   'population': 20379,
#   'location': [28, -99],
#   'measurements': {'HighCholesterolCrdPrv': 32.5,
#    'HighCholesterolAgeAdjPrv': 32.5,
#    'HighBloodPressureAgeAdjPrv': 35.0,
#    'HighBloodPressureCrdPrv': 32.1}},
#  {'county': 'Frontier',
#   'state': 'NE',
#   'population': 2587,
#   'location': [40, -100],
#   'measurements': {'HighCholesterolAgeAdjPrv': 26.5,
#    'HighCholesterolCrdPrv': 33.6,
#    'HighBloodPressureAgeAdjPrv': 28.1,
#    'HighBloodPressureCrdPrv': 34.4}},
#  {'county': 'Fulton',
#   'state': 'AR',
#   'population': 12381,
#   'location': [36, -91],
#   'measurements': {'HighCholesterolAgeAdjPrv': 34.0,
#    'HighCholesterolCrdPrv': 44.0,
#    'HighBloodPressureAgeAdjPrv': 38.0,
#    'HighBloodPressureCrdPrv': 47.4}},
#  {'county': 'Fulton',
#   'state': 'GA',
#   'population': 1077402,
#   'location': [33, -84],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 32.0,
#    'HighCholesterolCrdPrv': 29.1,
#    'HighCholesterolAgeAdjPrv': 28.4,
#    'HighBloodPressureCrdPrv': 31.1}},
#  {'county': 'Fulton',
#   'state': 'IL',
#   'population': 33690,
#   'location': [40, -90],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 32.2,
#    'HighBloodPressureCrdPrv': 37.1,
#    'HighCholesterolAgeAdjPrv': 29.1,
#    'HighCholesterolCrdPrv': 35.2}},
#  {'county': 'Fulton',
#   'state': 'IN',
#   'population': 20018,
#   'location': [41, -86],
#   'measurements': {'HighCholesterolAgeAdjPrv': 28.8,
#    'HighCholesterolCrdPrv': 35.1,
#    'HighBloodPressureAgeAdjPrv': 32.0,
#    'HighBloodPressureCrdPrv': 37.3}},
#  {'county': 'Fulton',
#   'state': 'KY',
#   'population': 5952,
#   'location': [36, -89],
#   'measurements': {'HighBloodPressureCrdPrv': 50.1,
#    'HighCholesterolAgeAdjPrv': 33.1,
#    'HighCholesterolCrdPrv': 39.4,
#    'HighBloodPressureAgeAdjPrv': 44.5}},
#  {'county': 'Fulton',
#   'state': 'NY',
#   'population': 52812,
#   'location': [43, -74],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.1,
#    'HighBloodPressureCrdPrv': 36.4,
#    'HighCholesterolAgeAdjPrv': 27.9,
#    'HighCholesterolCrdPrv': 34.1}},
#  {'county': 'Fulton',
#   'state': 'OH',
#   'population': 41889,
#   'location': [41, -84],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 30.4,
#    'HighBloodPressureCrdPrv': 34.7,
#    'HighCholesterolCrdPrv': 32.3,
#    'HighCholesterolAgeAdjPrv': 26.9}},
#  {'county': 'Fulton',
#   'state': 'PA',
#   'population': 14501,
#   'location': [39, -78],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 30.1,
#    'HighCholesterolAgeAdjPrv': 28.8,
#    'HighBloodPressureCrdPrv': 36.6,
#    'HighCholesterolCrdPrv': 36.2}},
#  {'county': 'Furnas',
#   'state': 'NE',
#   'population': 4653,
#   'location': [40, -99],
#   'measurements': {'HighCholesterolCrdPrv': 37.3,
#    'HighCholesterolAgeAdjPrv': 28.4,
#    'HighBloodPressureAgeAdjPrv': 31.4,
#    'HighBloodPressureCrdPrv': 39.6}},
#  {'county': 'Gadsden',
#   'state': 'FL',
#   'population': 45277,
#   'location': [30, -84],
#   'measurements': {'HighBloodPressureCrdPrv': 43.0,
#    'HighCholesterolAgeAdjPrv': 28.5,
#    'HighCholesterolCrdPrv': 33.5,
#    'HighBloodPressureAgeAdjPrv': 38.9}},
#  {'county': 'Gage',
#   'state': 'NE',
#   'population': 21431,
#   'location': [40, -96],
#   'measurements': {'HighCholesterolCrdPrv': 32.8,
#    'HighBloodPressureCrdPrv': 37.9,
#    'HighBloodPressureAgeAdjPrv': 31.3,
#    'HighCholesterolAgeAdjPrv': 25.8}},
#  {'county': 'Gaines',
#   'state': 'TX',
#   'population': 21996,
#   'location': [32, -102],
#   'measurements': {'HighCholesterolAgeAdjPrv': 31.6,
#    'HighCholesterolCrdPrv': 32.7,
#    'HighBloodPressureAgeAdjPrv': 33.1,
#    'HighBloodPressureCrdPrv': 31.3}},
#  {'county': 'Galax',
#   'state': 'VA',
#   'population': 6296,
#   'location': [36, -80],
#   'measurements': {'HighCholesterolCrdPrv': 36.8,
#    'HighBloodPressureCrdPrv': 40.3,
#    'HighBloodPressureAgeAdjPrv': 36.3,
#    'HighCholesterolAgeAdjPrv': 31.5}},
#  {'county': 'Gallatin',
#   'state': 'IL',
#   'population': 4793,
#   'location': [37, -88],
#   'measurements': {'HighBloodPressureCrdPrv': 40.9,
#    'HighBloodPressureAgeAdjPrv': 33.1,
#    'HighCholesterolCrdPrv': 38.0,
#    'HighCholesterolAgeAdjPrv': 29.6}},
#  {'county': 'Gallatin',
#   'state': 'KY',
#   'population': 8779,
#   'location': [38, -84],
#   'measurements': {'HighBloodPressureCrdPrv': 40.6,
#    'HighBloodPressureAgeAdjPrv': 37.9,
#    'HighCholesterolAgeAdjPrv': 33.3,
#    'HighCholesterolCrdPrv': 37.4}},
#  {'county': 'Gallatin',
#   'state': 'MT',
#   'population': 116806,
#   'location': [45, -111],
#   'measurements': {'HighCholesterolAgeAdjPrv': 23.3,
#    'HighBloodPressureCrdPrv': 20.0,
#    'HighBloodPressureAgeAdjPrv': 21.5,
#    'HighCholesterolCrdPrv': 24.0}},
#  ...]

# %%
import json

data = {}
data['data'] = data_list
data
# Out:
# {'data': [{'county': 'Abbeville',
#    'state': 'SC',
#    'population': 24404,
#    'location': [34, -82],
#    'measurements': {'HighBloodPressureCrdPrv': 45.0,
#     'HighCholesterolAgeAdjPrv': 32.1,
#     'HighCholesterolCrdPrv': 39.5,
#     'HighBloodPressureAgeAdjPrv': 38.7}},
#   {'county': 'Acadia',
#    'state': 'LA',
#    'population': 61918,
#    'location': [30, -92],
#    'measurements': {'HighBloodPressureCrdPrv': 41.8,
#     'HighCholesterolAgeAdjPrv': 34.6,
#     'HighCholesterolCrdPrv': 39.5,
#     'HighBloodPressureAgeAdjPrv': 38.7}},
#   {'county': 'Accomack',
#    'state': 'VA',
#    'population': 32238,
#    'location': [37, -75],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 37.1,
#     'HighBloodPressureCrdPrv': 44.7,
#     'HighCholesterolAgeAdjPrv': 28.8,
#     'HighCholesterolCrdPrv': 36.5}},
#   {'county': 'Ada',
#    'state': 'ID',
#    'population': 494399,
#    'location': [43, -116],
#    'measurements': {'HighBloodPressureCrdPrv': 28.5,
#     'HighCholesterolAgeAdjPrv': 26.8,
#     'HighCholesterolCrdPrv': 30.0,
#     'HighBloodPressureAgeAdjPrv': 27.3}},
#   {'county': 'Adair',
#    'state': 'IA',
#    'population': 7059,
#    'location': [41, -94],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 30.0,
#     'HighBloodPressureCrdPrv': 37.0,
#     'HighCholesterolAgeAdjPrv': 29.0,
#     'HighCholesterolCrdPrv': 36.6}},
#   {'county': 'Adair',
#    'state': 'KY',
#    'population': 19555,
#    'location': [37, -85],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 40.4,
#     'HighCholesterolCrdPrv': 40.7,
#     'HighCholesterolAgeAdjPrv': 35.6,
#     'HighBloodPressureCrdPrv': 44.4}},
#   {'county': 'Adair',
#    'state': 'MO',
#    'population': 25399,
#    'location': [40, -92],
#    'measurements': {'HighCholesterolAgeAdjPrv': 29.8,
#     'HighCholesterolCrdPrv': 29.8,
#     'HighBloodPressureAgeAdjPrv': 30.7,
#     'HighBloodPressureCrdPrv': 27.8}},
#   {'county': 'Adair',
#    'state': 'OK',
#    'population': 21955,
#    'location': [35, -94],
#    'measurements': {'HighCholesterolCrdPrv': 39.1,
#     'HighBloodPressureAgeAdjPrv': 41.5,
#     'HighBloodPressureCrdPrv': 44.8,
#     'HighCholesterolAgeAdjPrv': 33.7}},
#   {'county': 'Adams',
#    'state': 'CO',
#    'population': 519883,
#    'location': [39, -104],
#    'measurements': {'HighCholesterolCrdPrv': 27.0,
#     'HighCholesterolAgeAdjPrv': 26.8,
#     'HighBloodPressureAgeAdjPrv': 25.0,
#     'HighBloodPressureCrdPrv': 23.3}},
#   {'county': 'Adams',
#    'state': 'IA',
#    'population': 3588,
#    'location': [41, -94],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 30.4,
#     'HighCholesterolCrdPrv': 37.3,
#     'HighCholesterolAgeAdjPrv': 28.6,
#     'HighBloodPressureCrdPrv': 38.6}},
#   {'county': 'Adams',
#    'state': 'ID',
#    'population': 4447,
#    'location': [44, -116],
#    'measurements': {'HighBloodPressureCrdPrv': 39.4,
#     'HighBloodPressureAgeAdjPrv': 28.2,
#     'HighCholesterolAgeAdjPrv': 26.7,
#     'HighCholesterolCrdPrv': 37.9}},
#   {'county': 'Adams',
#    'state': 'IL',
#    'population': 64783,
#    'location': [39, -91],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.1,
#     'HighCholesterolCrdPrv': 33.9,
#     'HighCholesterolAgeAdjPrv': 27.8,
#     'HighBloodPressureCrdPrv': 36.6}},
#   {'county': 'Adams',
#    'state': 'IN',
#    'population': 35839,
#    'location': [40, -84],
#    'measurements': {'HighBloodPressureCrdPrv': 37.0,
#     'HighCholesterolAgeAdjPrv': 29.6,
#     'HighCholesterolCrdPrv': 34.5,
#     'HighBloodPressureAgeAdjPrv': 33.7}},
#   {'county': 'Adams',
#    'state': 'MS',
#    'population': 30275,
#    'location': [31, -91],
#    'measurements': {'HighBloodPressureCrdPrv': 47.7,
#     'HighCholesterolAgeAdjPrv': 31.3,
#     'HighCholesterolCrdPrv': 36.5,
#     'HighBloodPressureAgeAdjPrv': 43.6}},
#   {'county': 'Adams',
#    'state': 'ND',
#    'population': 2188,
#    'location': [46, -102],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 28.9,
#     'HighCholesterolAgeAdjPrv': 26.8,
#     'HighCholesterolCrdPrv': 36.3,
#     'HighBloodPressureCrdPrv': 38.6}},
#   {'county': 'Adams',
#    'state': 'NE',
#    'population': 31321,
#    'location': [40, -98],
#    'measurements': {'HighCholesterolAgeAdjPrv': 29.2,
#     'HighBloodPressureCrdPrv': 31.8,
#     'HighBloodPressureAgeAdjPrv': 28.8,
#     'HighCholesterolCrdPrv': 34.2}},
#   {'county': 'Adams',
#    'state': 'OH',
#    'population': 27531,
#    'location': [38, -83],
#    'measurements': {'HighCholesterolAgeAdjPrv': 30.2,
#     'HighCholesterolCrdPrv': 37.2,
#     'HighBloodPressureAgeAdjPrv': 35.4,
#     'HighBloodPressureCrdPrv': 41.0}},
#   {'county': 'Adams',
#    'state': 'PA',
#    'population': 102742,
#    'location': [39, -77],
#    'measurements': {'HighCholesterolCrdPrv': 34.9,
#     'HighBloodPressureCrdPrv': 33.7,
#     'HighCholesterolAgeAdjPrv': 28.7,
#     'HighBloodPressureAgeAdjPrv': 28.6}},
#   {'county': 'Adams',
#    'state': 'WA',
#    'population': 20027,
#    'location': [47, -118],
#    'measurements': {'HighCholesterolAgeAdjPrv': 29.2,
#     'HighCholesterolCrdPrv': 30.2,
#     'HighBloodPressureAgeAdjPrv': 30.0,
#     'HighBloodPressureCrdPrv': 28.0}},
#   {'county': 'Adams',
#    'state': 'WI',
#    'population': 20498,
#    'location': [43, -89],
#    'measurements': {'HighCholesterolCrdPrv': 40.3,
#     'HighCholesterolAgeAdjPrv': 29.4,
#     'HighBloodPressureCrdPrv': 40.4,
#     'HighBloodPressureAgeAdjPrv': 30.3}},
#   {'county': 'Addison',
#    'state': 'VT',
#    'population': 36851,
#    'location': [44, -73],
#    'measurements': {'HighCholesterolAgeAdjPrv': 24.7,
#     'HighCholesterolCrdPrv': 30.0,
#     'HighBloodPressureAgeAdjPrv': 25.7,
#     'HighBloodPressureCrdPrv': 29.3}},
#   {'county': 'Aiken',
#    'state': 'SC',
#    'population': 172895,
#    'location': [33, -81],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 35.2,
#     'HighCholesterolCrdPrv': 35.9,
#     'HighCholesterolAgeAdjPrv': 30.0,
#     'HighBloodPressureCrdPrv': 40.0}},
#   {'county': 'Aitkin',
#    'state': 'MN',
#    'population': 15848,
#    'location': [46, -93],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 29.6,
#     'HighBloodPressureCrdPrv': 42.1,
#     'HighCholesterolAgeAdjPrv': 25.7,
#     'HighCholesterolCrdPrv': 37.0}},
#   {'county': 'Alachua',
#    'state': 'FL',
#    'population': 271218,
#    'location': [29, -82],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 30.9,
#     'HighCholesterolCrdPrv': 27.6,
#     'HighCholesterolAgeAdjPrv': 28.2,
#     'HighBloodPressureCrdPrv': 28.0}},
#   {'county': 'Alamance',
#    'state': 'NC',
#    'population': 171346,
#    'location': [36, -79],
#    'measurements': {'HighBloodPressureCrdPrv': 36.3,
#     'HighCholesterolCrdPrv': 34.4,
#     'HighCholesterolAgeAdjPrv': 30.6,
#     'HighBloodPressureAgeAdjPrv': 34.0}},
#   {'county': 'Alameda',
#    'state': 'CA',
#    'population': 1662323,
#    'location': [37, -121],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 25.5,
#     'HighCholesterolAgeAdjPrv': 27.1,
#     'HighCholesterolCrdPrv': 28.8,
#     'HighBloodPressureCrdPrv': 25.7}},
#   {'county': 'Alamosa',
#    'state': 'CO',
#    'population': 16180,
#    'location': [37, -105],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 28.0,
#     'HighCholesterolAgeAdjPrv': 26.5,
#     'HighBloodPressureCrdPrv': 26.6,
#     'HighCholesterolCrdPrv': 27.6}},
#   {'county': 'Albany',
#    'state': 'NY',
#    'population': 303654,
#    'location': [42, -73],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 26.1,
#     'HighBloodPressureCrdPrv': 27.3,
#     'HighCholesterolAgeAdjPrv': 28.4,
#     'HighCholesterolCrdPrv': 30.9}},
#   {'county': 'Albany',
#    'state': 'WY',
#    'population': 38950,
#    'location': [41, -105],
#    'measurements': {'HighCholesterolAgeAdjPrv': 25.8,
#     'HighBloodPressureAgeAdjPrv': 27.8,
#     'HighCholesterolCrdPrv': 23.7,
#     'HighBloodPressureCrdPrv': 22.8}},
#   {'county': 'Albemarle',
#    'state': 'VA',
#    'population': 110652,
#    'location': [38, -78],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 27.3,
#     'HighBloodPressureCrdPrv': 30.1,
#     'HighCholesterolAgeAdjPrv': 27.7,
#     'HighCholesterolCrdPrv': 31.4}},
#   {'county': 'Alcona',
#    'state': 'MI',
#    'population': 10505,
#    'location': [44, -83],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.7,
#     'HighCholesterolCrdPrv': 43.3,
#     'HighBloodPressureCrdPrv': 45.6,
#     'HighCholesterolAgeAdjPrv': 30.5}},
#   {'county': 'Alcorn',
#    'state': 'MS',
#    'population': 36889,
#    'location': [34, -88],
#    'measurements': {'HighCholesterolCrdPrv': 38.5,
#     'HighCholesterolAgeAdjPrv': 32.6,
#     'HighBloodPressureCrdPrv': 42.8,
#     'HighBloodPressureAgeAdjPrv': 38.3}},
#   {'county': 'Aleutians East',
#    'state': 'AK',
#    'population': 3401,
#    'location': [55, -161],
#    'measurements': {'HighCholesterolAgeAdjPrv': 28.4,
#     'HighCholesterolCrdPrv': 31.2,
#     'HighBloodPressureCrdPrv': 34.1,
#     'HighBloodPressureAgeAdjPrv': 34.3}},
#   {'county': 'Aleutians West',
#    'state': 'AK',
#    'population': 5680,
#    'location': [51, 178],
#    'measurements': {'HighBloodPressureCrdPrv': 30.3,
#     'HighCholesterolAgeAdjPrv': 28.2,
#     'HighCholesterolCrdPrv': 30.3,
#     'HighBloodPressureAgeAdjPrv': 31.5}},
#   {'county': 'Alexander',
#    'state': 'IL',
#    'population': 5497,
#    'location': [37, -89],
#    'measurements': {'HighBloodPressureCrdPrv': 45.7,
#     'HighBloodPressureAgeAdjPrv': 37.2,
#     'HighCholesterolCrdPrv': 37.9,
#     'HighCholesterolAgeAdjPrv': 29.3}},
#   {'county': 'Alexander',
#    'state': 'NC',
#    'population': 37441,
#    'location': [35, -81],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.2,
#     'HighCholesterolAgeAdjPrv': 30.4,
#     'HighBloodPressureCrdPrv': 36.4,
#     'HighCholesterolCrdPrv': 36.9}},
#   {'county': 'Alexandria',
#    'state': 'VA',
#    'population': 158726,
#    'location': [38, -77],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 30.8,
#     'HighCholesterolCrdPrv': 29.5,
#     'HighCholesterolAgeAdjPrv': 29.1,
#     'HighBloodPressureCrdPrv': 29.7}},
#   {'county': 'Alfalfa',
#    'state': 'OK',
#    'population': 5718,
#    'location': [36, -98],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 35.4,
#     'HighCholesterolCrdPrv': 37.9,
#     'HighCholesterolAgeAdjPrv': 31.5,
#     'HighBloodPressureCrdPrv': 40.8}},
#   {'county': 'Alger',
#    'state': 'MI',
#    'population': 9015,
#    'location': [46, -86],
#    'measurements': {'HighCholesterolCrdPrv': 38.3,
#     'HighBloodPressureAgeAdjPrv': 32.8,
#     'HighCholesterolAgeAdjPrv': 30.1,
#     'HighBloodPressureCrdPrv': 40.3}},
#   {'county': 'Allamakee',
#    'state': 'IA',
#    'population': 13642,
#    'location': [43, -91],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 29.5,
#     'HighCholesterolCrdPrv': 33.8,
#     'HighCholesterolAgeAdjPrv': 26.2,
#     'HighBloodPressureCrdPrv': 36.6}},
#   {'county': 'Allegan',
#    'state': 'MI',
#    'population': 118927,
#    'location': [42, -86],
#    'measurements': {'HighBloodPressureCrdPrv': 34.9,
#     'HighCholesterolAgeAdjPrv': 29.1,
#     'HighBloodPressureAgeAdjPrv': 31.1,
#     'HighCholesterolCrdPrv': 34.0}},
#   {'county': 'Allegany',
#    'state': 'MD',
#    'population': 70057,
#    'location': [39, -78],
#    'measurements': {'HighCholesterolAgeAdjPrv': 27.3,
#     'HighBloodPressureCrdPrv': 39.2,
#     'HighBloodPressureAgeAdjPrv': 35.8,
#     'HighCholesterolCrdPrv': 31.7}},
#   {'county': 'Allegany',
#    'state': 'NY',
#    'population': 45587,
#    'location': [42, -78],
#    'measurements': {'HighCholesterolCrdPrv': 33.6,
#     'HighBloodPressureCrdPrv': 32.3,
#     'HighBloodPressureAgeAdjPrv': 28.9,
#     'HighCholesterolAgeAdjPrv': 28.7}},
#   {'county': 'Alleghany',
#    'state': 'NC',
#    'population': 11194,
#    'location': [36, -81],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 33.1,
#     'HighCholesterolAgeAdjPrv': 31.6,
#     'HighBloodPressureCrdPrv': 42.2,
#     'HighCholesterolCrdPrv': 41.1}},
#   {'county': 'Alleghany',
#    'state': 'VA',
#    'population': 14701,
#    'location': [37, -80],
#    'measurements': {'HighCholesterolAgeAdjPrv': 29.5,
#     'HighBloodPressureCrdPrv': 42.6,
#     'HighCholesterolCrdPrv': 38.0,
#     'HighBloodPressureAgeAdjPrv': 34.1}},
#   {'county': 'Allegheny',
#    'state': 'PA',
#    'population': 1211358,
#    'location': [40, -79],
#    'measurements': {'HighCholesterolCrdPrv': 30.6,
#     'HighCholesterolAgeAdjPrv': 26.3,
#     'HighBloodPressureAgeAdjPrv': 28.5,
#     'HighBloodPressureCrdPrv': 31.9}},
#   {'county': 'Allen',
#    'state': 'IN',
#    'population': 382187,
#    'location': [41, -85],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.6,
#     'HighBloodPressureCrdPrv': 33.1,
#     'HighCholesterolAgeAdjPrv': 27.2,
#     'HighCholesterolCrdPrv': 30.3}},
#   {'county': 'Allen',
#    'state': 'KS',
#    'population': 12399,
#    'location': [37, -95],
#    'measurements': {'HighBloodPressureCrdPrv': 37.8,
#     'HighCholesterolAgeAdjPrv': 29.8,
#     'HighBloodPressureAgeAdjPrv': 32.6,
#     'HighCholesterolCrdPrv': 36.4}},
#   {'county': 'Allen',
#    'state': 'KY',
#    'population': 21303,
#    'location': [36, -86],
#    'measurements': {'HighCholesterolCrdPrv': 37.9,
#     'HighBloodPressureAgeAdjPrv': 39.3,
#     'HighBloodPressureCrdPrv': 43.9,
#     'HighCholesterolAgeAdjPrv': 32.5}},
#   {'county': 'Allen',
#    'state': 'LA',
#    'population': 25440,
#    'location': [30, -92],
#    'measurements': {'HighBloodPressureCrdPrv': 39.2,
#     'HighBloodPressureAgeAdjPrv': 37.4,
#     'HighCholesterolAgeAdjPrv': 32.1,
#     'HighCholesterolCrdPrv': 35.6}},
#   {'county': 'Allen',
#    'state': 'OH',
#    'population': 101980,
#    'location': [40, -84],
#    'measurements': {'HighCholesterolAgeAdjPrv': 26.7,
#     'HighCholesterolCrdPrv': 31.6,
#     'HighBloodPressureCrdPrv': 36.2,
#     'HighBloodPressureAgeAdjPrv': 32.7}},
#   {'county': 'Allendale',
#    'state': 'SC',
#    'population': 8331,
#    'location': [32, -81],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 46.5,
#     'HighCholesterolCrdPrv': 38.1,
#     'HighCholesterolAgeAdjPrv': 32.1,
#     'HighBloodPressureCrdPrv': 51.1}},
#   {'county': 'Alpena',
#    'state': 'MI',
#    'population': 28238,
#    'location': [44, -83],
#    'measurements': {'HighBloodPressureCrdPrv': 39.4,
#     'HighCholesterolAgeAdjPrv': 31.7,
#     'HighCholesterolCrdPrv': 40.0,
#     'HighBloodPressureAgeAdjPrv': 31.7}},
#   {'county': 'Alpine',
#    'state': 'CA',
#    'population': 1119,
#    'location': [38, -119],
#    'measurements': {'HighBloodPressureCrdPrv': 35.7,
#     'HighCholesterolAgeAdjPrv': 27.5,
#     'HighCholesterolCrdPrv': 35.4,
#     'HighBloodPressureAgeAdjPrv': 28.7}},
#   {'county': 'Amador',
#    'state': 'CA',
#    'population': 40083,
#    'location': [38, -120],
#    'measurements': {'HighCholesterolAgeAdjPrv': 27.4,
#     'HighBloodPressureCrdPrv': 34.4,
#     'HighBloodPressureAgeAdjPrv': 27.4,
#     'HighCholesterolCrdPrv': 35.2}},
#   {'county': 'Amelia',
#    'state': 'VA',
#    'population': 13014,
#    'location': [37, -77],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 35.1,
#     'HighBloodPressureCrdPrv': 41.8,
#     'HighCholesterolAgeAdjPrv': 30.9,
#     'HighCholesterolCrdPrv': 38.1}},
#   {'county': 'Amherst',
#    'state': 'VA',
#    'population': 31667,
#    'location': [37, -79],
#    'measurements': {'HighCholesterolCrdPrv': 35.7,
#     'HighCholesterolAgeAdjPrv': 29.0,
#     'HighBloodPressureCrdPrv': 40.3,
#     'HighBloodPressureAgeAdjPrv': 34.1}},
#   {'county': 'Amite',
#    'state': 'MS',
#    'population': 12205,
#    'location': [31, -90],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 42.2,
#     'HighBloodPressureCrdPrv': 50.7,
#     'HighCholesterolAgeAdjPrv': 32.9,
#     'HighCholesterolCrdPrv': 42.0}},
#   {'county': 'Anchorage',
#    'state': 'AK',
#    'population': 287095,
#    'location': [61, -149],
#    'measurements': {'HighBloodPressureCrdPrv': 28.8,
#     'HighCholesterolAgeAdjPrv': 27.8,
#     'HighBloodPressureAgeAdjPrv': 29.8,
#     'HighCholesterolCrdPrv': 29.4}},
#   {'county': 'Anderson',
#    'state': 'KS',
#    'population': 7949,
#    'location': [38, -95],
#    'measurements': {'HighCholesterolAgeAdjPrv': 29.2,
#     'HighBloodPressureAgeAdjPrv': 33.0,
#     'HighBloodPressureCrdPrv': 40.1,
#     'HighCholesterolCrdPrv': 37.0}},
#   {'county': 'Anderson',
#    'state': 'KY',
#    'population': 22833,
#    'location': [38, -84],
#    'measurements': {'HighCholesterolCrdPrv': 36.8,
#     'HighBloodPressureCrdPrv': 41.7,
#     'HighBloodPressureAgeAdjPrv': 37.6,
#     'HighCholesterolAgeAdjPrv': 31.9}},
#   {'county': 'Anderson',
#    'state': 'SC',
#    'population': 204353,
#    'location': [34, -82],
#    'measurements': {'HighCholesterolCrdPrv': 37.1,
#     'HighBloodPressureAgeAdjPrv': 35.8,
#     'HighBloodPressureCrdPrv': 40.1,
#     'HighCholesterolAgeAdjPrv': 31.4}},
#   {'county': 'Anderson',
#    'state': 'TN',
#    'population': 77558,
#    'location': [36, -84],
#    'measurements': {'HighBloodPressureCrdPrv': 42.1,
#     'HighBloodPressureAgeAdjPrv': 36.6,
#     'HighCholesterolAgeAdjPrv': 32.8,
#     'HighCholesterolCrdPrv': 39.3}},
#   {'county': 'Anderson',
#    'state': 'TX',
#    'population': 57805,
#    'location': [31, -95],
#    'measurements': {'HighBloodPressureCrdPrv': 37.7,
#     'HighCholesterolAgeAdjPrv': 31.7,
#     'HighCholesterolCrdPrv': 34.2,
#     'HighBloodPressureAgeAdjPrv': 37.4}},
#   {'county': 'Andrew',
#    'state': 'MO',
#    'population': 17586,
#    'location': [39, -94],
#    'measurements': {'HighCholesterolCrdPrv': 36.2,
#     'HighBloodPressureAgeAdjPrv': 28.6,
#     'HighBloodPressureCrdPrv': 33.7,
#     'HighCholesterolAgeAdjPrv': 29.7}},
#   {'county': 'Andrews',
#    'state': 'TX',
#    'population': 18879,
#    'location': [32, -102],
#    'measurements': {'HighCholesterolAgeAdjPrv': 31.3,
#     'HighBloodPressureAgeAdjPrv': 31.6,
#     'HighCholesterolCrdPrv': 31.6,
#     'HighBloodPressureCrdPrv': 29.3}},
#   {'county': 'Androscoggin',
#    'state': 'ME',
#    'population': 108547,
#    'location': [44, -70],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 29.8,
#     'HighBloodPressureCrdPrv': 33.8,
#     'HighCholesterolCrdPrv': 32.7,
#     'HighCholesterolAgeAdjPrv': 27.3}},
#   {'county': 'Angelina',
#    'state': 'TX',
#    'population': 86796,
#    'location': [31, -94],
#    'measurements': {'HighBloodPressureCrdPrv': 39.9,
#     'HighCholesterolAgeAdjPrv': 32.7,
#     'HighCholesterolCrdPrv': 36.7,
#     'HighBloodPressureAgeAdjPrv': 37.8}},
#   {'county': 'Anne Arundel',
#    'state': 'MD',
#    'population': 582777,
#    'location': [38, -76],
#    'measurements': {'HighCholesterolAgeAdjPrv': 29.3,
#     'HighCholesterolCrdPrv': 32.2,
#     'HighBloodPressureAgeAdjPrv': 31.0,
#     'HighBloodPressureCrdPrv': 32.7}},
#   {'county': 'Anoka',
#    'state': 'MN',
#    'population': 359921,
#    'location': [45, -93],
#    'measurements': {'HighCholesterolCrdPrv': 31.5,
#     'HighBloodPressureAgeAdjPrv': 28.2,
#     'HighCholesterolAgeAdjPrv': 27.6,
#     'HighBloodPressureCrdPrv': 30.4}},
#   {'county': 'Anson',
#    'state': 'NC',
#    'population': 24097,
#    'location': [34, -80],
#    'measurements': {'HighCholesterolAgeAdjPrv': 30.7,
#     'HighCholesterolCrdPrv': 35.8,
#     'HighBloodPressureAgeAdjPrv': 38.7,
#     'HighBloodPressureCrdPrv': 42.6}},
#   {'county': 'Antelope',
#    'state': 'NE',
#    'population': 6264,
#    'location': [42, -98],
#    'measurements': {'HighBloodPressureCrdPrv': 37.2,
#     'HighCholesterolAgeAdjPrv': 27.5,
#     'HighCholesterolCrdPrv': 35.8,
#     'HighBloodPressureAgeAdjPrv': 29.5}},
#   {'county': 'Antrim',
#    'state': 'MI',
#    'population': 23449,
#    'location': [45, -85],
#    'measurements': {'HighBloodPressureCrdPrv': 40.9,
#     'HighCholesterolAgeAdjPrv': 29.9,
#     'HighBloodPressureAgeAdjPrv': 30.9,
#     'HighCholesterolCrdPrv': 39.6}},
#   {'county': 'Apache',
#    'state': 'AZ',
#    'population': 71875,
#    'location': [35, -109],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 33.8,
#     'HighCholesterolAgeAdjPrv': 26.4,
#     'HighBloodPressureCrdPrv': 36.6,
#     'HighCholesterolCrdPrv': 31.0}},
#   {'county': 'Appanoose',
#    'state': 'IA',
#    'population': 12430,
#    'location': [40, -92],
#    'measurements': {'HighCholesterolCrdPrv': 37.1,
#     'HighBloodPressureAgeAdjPrv': 32.1,
#     'HighCholesterolAgeAdjPrv': 29.1,
#     'HighBloodPressureCrdPrv': 39.7}},
#   {'county': 'Appling',
#    'state': 'GA',
#    'population': 18325,
#    'location': [31, -82],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 37.8,
#     'HighBloodPressureCrdPrv': 41.5,
#     'HighCholesterolAgeAdjPrv': 31.8,
#     'HighCholesterolCrdPrv': 37.1}},
#   {'county': 'Appomattox',
#    'state': 'VA',
#    'population': 16043,
#    'location': [37, -78],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 33.8,
#     'HighCholesterolCrdPrv': 35.1,
#     'HighCholesterolAgeAdjPrv': 28.7,
#     'HighBloodPressureCrdPrv': 39.7}},
#   {'county': 'Aransas',
#    'state': 'TX',
#    'population': 23814,
#    'location': [28, -96],
#    'measurements': {'HighCholesterolCrdPrv': 41.4,
#     'HighBloodPressureCrdPrv': 42.7,
#     'HighBloodPressureAgeAdjPrv': 34.0,
#     'HighCholesterolAgeAdjPrv': 32.1}},
#   {'county': 'Arapahoe',
#    'state': 'CO',
#    'population': 657452,
#    'location': [39, -104],
#    'measurements': {'HighBloodPressureCrdPrv': 26.4,
#     'HighCholesterolCrdPrv': 27.6,
#     'HighCholesterolAgeAdjPrv': 25.9,
#     'HighBloodPressureAgeAdjPrv': 26.4}},
#   {'county': 'Archer',
#    'state': 'TX',
#    'population': 8730,
#    'location': [33, -98],
#    'measurements': {'HighCholesterolCrdPrv': 38.3,
#     'HighCholesterolAgeAdjPrv': 31.3,
#     'HighBloodPressureCrdPrv': 37.3,
#     'HighBloodPressureAgeAdjPrv': 31.7}},
#   {'county': 'Archuleta',
#    'state': 'CO',
#    'population': 14196,
#    'location': [37, -107],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 24.1,
#     'HighBloodPressureCrdPrv': 31.7,
#     'HighCholesterolAgeAdjPrv': 26.3,
#     'HighCholesterolCrdPrv': 34.9}},
#   {'county': 'Arenac',
#    'state': 'MI',
#    'population': 14953,
#    'location': [44, -83],
#    'measurements': {'HighCholesterolAgeAdjPrv': 31.0,
#     'HighCholesterolCrdPrv': 40.4,
#     'HighBloodPressureCrdPrv': 41.3,
#     'HighBloodPressureAgeAdjPrv': 32.2}},
#   {'county': 'Arkansas',
#    'state': 'AR',
#    'population': 17383,
#    'location': [34, -91],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 37.0,
#     'HighBloodPressureCrdPrv': 42.9,
#     'HighCholesterolAgeAdjPrv': 32.1,
#     'HighCholesterolCrdPrv': 39.0}},
#   {'county': 'Arlington',
#    'state': 'VA',
#    'population': 240119,
#    'location': [38, -77],
#    'measurements': {'HighCholesterolCrdPrv': 27.5,
#     'HighBloodPressureAgeAdjPrv': 25.0,
#     'HighCholesterolAgeAdjPrv': 28.3,
#     'HighBloodPressureCrdPrv': 22.8}},
#   {'county': 'Armstrong',
#    'state': 'PA',
#    'population': 64162,
#    'location': [40, -79],
#    'measurements': {'HighBloodPressureCrdPrv': 37.0,
#     'HighCholesterolAgeAdjPrv': 27.3,
#     'HighBloodPressureAgeAdjPrv': 29.8,
#     'HighCholesterolCrdPrv': 35.0}},
#   {'county': 'Armstrong',
#    'state': 'TX',
#    'population': 1869,
#    'location': [34, -101],
#    'measurements': {'HighCholesterolCrdPrv': 39.7,
#     'HighCholesterolAgeAdjPrv': 31.0,
#     'HighBloodPressureAgeAdjPrv': 30.9,
#     'HighBloodPressureCrdPrv': 39.1}},
#   {'county': 'Aroostook',
#    'state': 'ME',
#    'population': 66804,
#    'location': [46, -68],
#    'measurements': {'HighBloodPressureCrdPrv': 42.4,
#     'HighBloodPressureAgeAdjPrv': 34.1,
#     'HighCholesterolCrdPrv': 38.7,
#     'HighCholesterolAgeAdjPrv': 30.1}},
#   {'county': 'Arthur',
#    'state': 'NE',
#    'population': 466,
#    'location': [41, -101],
#    'measurements': {'HighCholesterolCrdPrv': 33.7,
#     'HighBloodPressureCrdPrv': 34.8,
#     'HighBloodPressureAgeAdjPrv': 30.4,
#     'HighCholesterolAgeAdjPrv': 28.0}},
#   {'county': 'Ascension',
#    'state': 'LA',
#    'population': 128665,
#    'location': [30, -90],
#    'measurements': {'HighCholesterolAgeAdjPrv': 32.4,
#     'HighCholesterolCrdPrv': 35.0,
#     'HighBloodPressureAgeAdjPrv': 34.9,
#     'HighBloodPressureCrdPrv': 35.7}},
#   {'county': 'Ashe',
#    'state': 'NC',
#    'population': 27166,
#    'location': [36, -81],
#    'measurements': {'HighCholesterolAgeAdjPrv': 30.7,
#     'HighBloodPressureCrdPrv': 40.0,
#     'HighCholesterolCrdPrv': 39.6,
#     'HighBloodPressureAgeAdjPrv': 31.5}},
#   {'county': 'Ashland',
#    'state': 'OH',
#    'population': 53362,
#    'location': [40, -82],
#    'measurements': {'HighCholesterolCrdPrv': 33.4,
#     'HighCholesterolAgeAdjPrv': 27.7,
#     'HighBloodPressureCrdPrv': 35.7,
#     'HighBloodPressureAgeAdjPrv': 31.4}},
#   {'county': 'Ashland',
#    'state': 'WI',
#    'population': 15415,
#    'location': [46, -90],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 30.5,
#     'HighBloodPressureCrdPrv': 35.9,
#     'HighCholesterolAgeAdjPrv': 28.9,
#     'HighCholesterolCrdPrv': 36.3}},
#   {'county': 'Ashley',
#    'state': 'AR',
#    'population': 19339,
#    'location': [33, -91],
#    'measurements': {'HighCholesterolCrdPrv': 39.6,
#     'HighBloodPressureAgeAdjPrv': 39.7,
#     'HighCholesterolAgeAdjPrv': 32.5,
#     'HighBloodPressureCrdPrv': 45.9}},
#   {'county': 'Ashtabula',
#    'state': 'OH',
#    'population': 96513,
#    'location': [41, -80],
#    'measurements': {'HighCholesterolAgeAdjPrv': 29.9,
#     'HighBloodPressureAgeAdjPrv': 33.4,
#     'HighBloodPressureCrdPrv': 38.7,
#     'HighCholesterolCrdPrv': 36.7}},
#   {'county': 'Asotin',
#    'state': 'WA',
#    'population': 22820,
#    'location': [46, -117],
#    'measurements': {'HighCholesterolAgeAdjPrv': 28.6,
#     'HighBloodPressureCrdPrv': 36.3,
#     'HighBloodPressureAgeAdjPrv': 29.3,
#     'HighCholesterolCrdPrv': 36.7}},
#   {'county': 'Assumption',
#    'state': 'LA',
#    'population': 21621,
#    'location': [29, -91],
#    'measurements': {'HighCholesterolCrdPrv': 37.9,
#     'HighBloodPressureAgeAdjPrv': 38.7,
#     'HighCholesterolAgeAdjPrv': 31.9,
#     'HighBloodPressureCrdPrv': 43.5}},
#   {'county': 'Atascosa',
#    'state': 'TX',
#    'population': 51724,
#    'location': [28, -98],
#    'measurements': {'HighCholesterolAgeAdjPrv': 31.8,
#     'HighBloodPressureCrdPrv': 33.7,
#     'HighCholesterolCrdPrv': 35.2,
#     'HighBloodPressureAgeAdjPrv': 32.4}},
#   {'county': 'Atchison',
#    'state': 'KS',
#    'population': 16015,
#    'location': [39, -95],
#    'measurements': {'HighCholesterolAgeAdjPrv': 30.0,
#     'HighCholesterolCrdPrv': 34.5,
#     'HighBloodPressureAgeAdjPrv': 32.3,
#     'HighBloodPressureCrdPrv': 34.8}},
#   {'county': 'Atchison',
#    'state': 'MO',
#    'population': 5096,
#    'location': [40, -95],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 29.5,
#     'HighCholesterolCrdPrv': 38.2,
#     'HighCholesterolAgeAdjPrv': 29.2,
#     'HighBloodPressureCrdPrv': 38.1}},
#   {'county': 'Athens',
#    'state': 'OH',
#    'population': 65481,
#    'location': [39, -82],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 34.2,
#     'HighCholesterolAgeAdjPrv': 27.2,
#     'HighCholesterolCrdPrv': 26.8,
#     'HighBloodPressureCrdPrv': 30.1}},
#   {'county': 'Atkinson',
#    'state': 'GA',
#    'population': 8393,
#    'location': [31, -82],
#    'measurements': {'HighCholesterolAgeAdjPrv': 31.7,
#     'HighBloodPressureAgeAdjPrv': 37.9,
#     'HighBloodPressureCrdPrv': 38.7,
#     'HighCholesterolCrdPrv': 34.7}},
#   {'county': 'Atoka',
#    'state': 'OK',
#    'population': 13912,
#    'location': [34, -96],
#    'measurements': {'HighCholesterolCrdPrv': 37.9,
#     'HighCholesterolAgeAdjPrv': 31.6,
#     'HighBloodPressureCrdPrv': 42.7,
#     'HighBloodPressureAgeAdjPrv': 37.9}},
#   {'county': 'Attala',
#    'state': 'MS',
#    'population': 18004,
#    'location': [33, -89],
#    'measurements': {'HighBloodPressureCrdPrv': 50.1,
#     'HighCholesterolAgeAdjPrv': 33.0,
#     'HighCholesterolCrdPrv': 39.4,
#     'HighBloodPressureAgeAdjPrv': 44.9}},
#   {'county': 'Audrain',
#    'state': 'MO',
#    'population': 24835,
#    'location': [39, -91],
#    'measurements': {'HighCholesterolCrdPrv': 36.2,
#     'HighBloodPressureAgeAdjPrv': 31.5,
#     'HighCholesterolAgeAdjPrv': 30.7,
#     'HighBloodPressureCrdPrv': 35.3}},
#   {'county': 'Audubon',
#    'state': 'IA',
#    'population': 5481,
#    'location': [41, -94],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 29.9,
#     'HighCholesterolCrdPrv': 36.8,
#     'HighCholesterolAgeAdjPrv': 28.2,
#     'HighBloodPressureCrdPrv': 38.2}},
#   {'county': 'Auglaize',
#    'state': 'OH',
#    'population': 45680,
#    'location': [40, -84],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.6,
#     'HighCholesterolCrdPrv': 32.5,
#     'HighBloodPressureCrdPrv': 36.7,
#     'HighCholesterolAgeAdjPrv': 26.6}},
#   {'county': 'Augusta',
#    'state': 'VA',
#    'population': 76544,
#    'location': [38, -79],
#    'measurements': {'HighBloodPressureCrdPrv': 37.7,
#     'HighCholesterolCrdPrv': 37.4,
#     'HighBloodPressureAgeAdjPrv': 31.8,
#     'HighCholesterolAgeAdjPrv': 30.5}},
#   {'county': 'Aurora',
#    'state': 'SD',
#    'population': 2730,
#    'location': [43, -98],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 26.2,
#     'HighCholesterolCrdPrv': 32.1,
#     'HighBloodPressureCrdPrv': 31.2,
#     'HighCholesterolAgeAdjPrv': 25.8}},
#   {'county': 'Austin',
#    'state': 'TX',
#    'population': 29972,
#    'location': [29, -96],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.5,
#     'HighCholesterolCrdPrv': 35.9,
#     'HighBloodPressureCrdPrv': 35.5,
#     'HighCholesterolAgeAdjPrv': 30.4}},
#   {'county': 'Autauga',
#    'state': 'AL',
#    'population': 56145,
#    'location': [32, -86],
#    'measurements': {'HighCholesterolCrdPrv': 36.4,
#     'HighBloodPressureAgeAdjPrv': 38.2,
#     'HighBloodPressureCrdPrv': 41.3,
#     'HighCholesterolAgeAdjPrv': 32.1}},
#   {'county': 'Avery',
#    'state': 'NC',
#    'population': 17571,
#    'location': [36, -81],
#    'measurements': {'HighCholesterolAgeAdjPrv': 31.3,
#     'HighBloodPressureCrdPrv': 37.6,
#     'HighBloodPressureAgeAdjPrv': 32.8,
#     'HighCholesterolCrdPrv': 37.4}},
#   {'county': 'Avoyelles',
#    'state': 'LA',
#    'population': 39966,
#    'location': [31, -91],
#    'measurements': {'HighCholesterolCrdPrv': 39.0,
#     'HighBloodPressureAgeAdjPrv': 40.2,
#     'HighCholesterolAgeAdjPrv': 34.0,
#     'HighBloodPressureCrdPrv': 43.6}},
#   {'county': 'Baca',
#    'state': 'CO',
#    'population': 3555,
#    'location': [37, -102],
#    'measurements': {'HighCholesterolCrdPrv': 34.9,
#     'HighCholesterolAgeAdjPrv': 27.4,
#     'HighBloodPressureCrdPrv': 35.5,
#     'HighBloodPressureAgeAdjPrv': 28.6}},
#   {'county': 'Bacon',
#    'state': 'GA',
#    'population': 11036,
#    'location': [31, -82],
#    'measurements': {'HighBloodPressureCrdPrv': 40.0,
#     'HighCholesterolAgeAdjPrv': 31.4,
#     'HighCholesterolCrdPrv': 36.0,
#     'HighBloodPressureAgeAdjPrv': 37.1}},
#   {'county': 'Bailey',
#    'state': 'TX',
#    'population': 6697,
#    'location': [34, -102],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.2,
#     'HighBloodPressureCrdPrv': 31.7,
#     'HighCholesterolAgeAdjPrv': 31.1,
#     'HighCholesterolCrdPrv': 33.7}},
#   {'county': 'Baker',
#    'state': 'FL',
#    'population': 29566,
#    'location': [30, -82],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 34.6,
#     'HighCholesterolCrdPrv': 32.5,
#     'HighBloodPressureCrdPrv': 36.2,
#     'HighCholesterolAgeAdjPrv': 29.1}},
#   {'county': 'Baker',
#    'state': 'GA',
#    'population': 2971,
#    'location': [31, -84],
#    'measurements': {'HighBloodPressureCrdPrv': 46.1,
#     'HighCholesterolAgeAdjPrv': 30.5,
#     'HighCholesterolCrdPrv': 38.1,
#     'HighBloodPressureAgeAdjPrv': 38.6}},
#   {'county': 'Baker',
#    'state': 'OR',
#    'population': 16284,
#    'location': [44, -117],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 29.3,
#     'HighBloodPressureCrdPrv': 37.5,
#     'HighCholesterolCrdPrv': 36.3,
#     'HighCholesterolAgeAdjPrv': 27.9}},
#   {'county': 'Baldwin',
#    'state': 'AL',
#    'population': 229287,
#    'location': [30, -87],
#    'measurements': {'HighBloodPressureCrdPrv': 39.2,
#     'HighBloodPressureAgeAdjPrv': 33.4,
#     'HighCholesterolAgeAdjPrv': 31.3,
#     'HighCholesterolCrdPrv': 37.9}},
#   {'county': 'Baldwin',
#    'state': 'GA',
#    'population': 45099,
#    'location': [33, -83],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 40.1,
#     'HighCholesterolAgeAdjPrv': 29.5,
#     'HighCholesterolCrdPrv': 31.9,
#     'HighBloodPressureCrdPrv': 39.9}},
#   {'county': 'Ballard',
#    'state': 'KY',
#    'population': 7769,
#    'location': [37, -89],
#    'measurements': {'HighBloodPressureCrdPrv': 46.9,
#     'HighCholesterolAgeAdjPrv': 32.9,
#     'HighCholesterolCrdPrv': 40.0,
#     'HighBloodPressureAgeAdjPrv': 39.9}},
#   {'county': 'Baltimore',
#    'state': 'MD',
#    'population': 826017,
#    'location': [39, -76],
#    'measurements': {'HighCholesterolCrdPrv': 33.1,
#     'HighBloodPressureCrdPrv': 35.5,
#     'HighCholesterolAgeAdjPrv': 29.2,
#     'HighBloodPressureAgeAdjPrv': 32.4}},
#   {'county': 'Baltimore City',
#    'state': 'MD',
#    'population': 586131,
#    'location': [39, -76],
#    'measurements': {'HighCholesterolAgeAdjPrv': 29.2,
#     'HighBloodPressureCrdPrv': 39.8,
#     'HighCholesterolCrdPrv': 30.9,
#     'HighBloodPressureAgeAdjPrv': 39.6}},
#   {'county': 'Bamberg',
#    'state': 'SC',
#    'population': 13906,
#    'location': [33, -81],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 41.9,
#     'HighCholesterolCrdPrv': 38.2,
#     'HighCholesterolAgeAdjPrv': 31.8,
#     'HighBloodPressureCrdPrv': 47.2}},
#   {'county': 'Bandera',
#    'state': 'TX',
#    'population': 23861,
#    'location': [29, -99],
#    'measurements': {'HighCholesterolAgeAdjPrv': 30.8,
#     'HighBloodPressureAgeAdjPrv': 31.8,
#     'HighBloodPressureCrdPrv': 41.3,
#     'HighCholesterolCrdPrv': 40.9}},
#   {'county': 'Banks',
#    'state': 'GA',
#    'population': 19352,
#    'location': [34, -83],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 34.4,
#     'HighBloodPressureCrdPrv': 38.4,
#     'HighCholesterolAgeAdjPrv': 31.3,
#     'HighCholesterolCrdPrv': 36.8}},
#   {'county': 'Banner',
#    'state': 'NE',
#    'population': 786,
#    'location': [41, -103],
#    'measurements': {'HighBloodPressureCrdPrv': 36.1,
#     'HighCholesterolAgeAdjPrv': 27.2,
#     'HighBloodPressureAgeAdjPrv': 28.5,
#     'HighCholesterolCrdPrv': 35.6}},
#   {'county': 'Bannock',
#    'state': 'ID',
#    'population': 88795,
#    'location': [42, -112],
#    'measurements': {'HighBloodPressureCrdPrv': 30.7,
#     'HighCholesterolAgeAdjPrv': 26.8,
#     'HighCholesterolCrdPrv': 29.6,
#     'HighBloodPressureAgeAdjPrv': 30.3}},
#   {'county': 'Baraga',
#    'state': 'MI',
#    'population': 8164,
#    'location': [46, -88],
#    'measurements': {'HighCholesterolCrdPrv': 37.4,
#     'HighBloodPressureAgeAdjPrv': 33.4,
#     'HighCholesterolAgeAdjPrv': 30.6,
#     'HighBloodPressureCrdPrv': 39.1}},
#   {'county': 'Barber',
#    'state': 'KS',
#    'population': 4358,
#    'location': [37, -98],
#    'measurements': {'HighCholesterolCrdPrv': 37.5,
#     'HighBloodPressureCrdPrv': 40.4,
#     'HighBloodPressureAgeAdjPrv': 32.6,
#     'HighCholesterolAgeAdjPrv': 28.9}},
#   {'county': 'Barbour',
#    'state': 'AL',
#    'population': 24589,
#    'location': [31, -85],
#    'measurements': {'HighBloodPressureCrdPrv': 49.6,
#     'HighBloodPressureAgeAdjPrv': 45.6,
#     'HighCholesterolAgeAdjPrv': 33.2,
#     'HighCholesterolCrdPrv': 38.6}},
#   {'county': 'Barbour',
#    'state': 'WV',
#    'population': 16444,
#    'location': [39, -79],
#    'measurements': {'HighBloodPressureCrdPrv': 41.7,
#     'HighBloodPressureAgeAdjPrv': 36.8,
#     'HighCholesterolCrdPrv': 36.7,
#     'HighCholesterolAgeAdjPrv': 30.7}},
#   {'county': 'Barnes',
#    'state': 'ND',
#    'population': 10402,
#    'location': [46, -98],
#    'measurements': {'HighCholesterolCrdPrv': 34.3,
#     'HighBloodPressureAgeAdjPrv': 28.6,
#     'HighBloodPressureCrdPrv': 34.6,
#     'HighCholesterolAgeAdjPrv': 27.3}},
#   {'county': 'Barnstable',
#    'state': 'MA',
#    'population': 213164,
#    'location': [41, -70],
#    'measurements': {'HighCholesterolCrdPrv': 35.5,
#     'HighCholesterolAgeAdjPrv': 26.1,
#     'HighBloodPressureAgeAdjPrv': 25.6,
#     'HighBloodPressureCrdPrv': 35.1}},
#   {'county': 'Barnwell',
#    'state': 'SC',
#    'population': 20805,
#    'location': [33, -81],
#    'measurements': {'HighCholesterolAgeAdjPrv': 32.7,
#     'HighCholesterolCrdPrv': 39.5,
#     'HighBloodPressureAgeAdjPrv': 42.3,
#     'HighBloodPressureCrdPrv': 47.6}},
#   {'county': 'Barren',
#    'state': 'KY',
#    'population': 44300,
#    'location': [36, -85],
#    'measurements': {'HighBloodPressureCrdPrv': 44.1,
#     'HighCholesterolAgeAdjPrv': 32.6,
#     'HighCholesterolCrdPrv': 37.9,
#     'HighBloodPressureAgeAdjPrv': 39.5}},
#   {'county': 'Barron',
#    'state': 'WI',
#    'population': 45090,
#    'location': [45, -91],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 29.1,
#     'HighBloodPressureCrdPrv': 35.8,
#     'HighCholesterolAgeAdjPrv': 28.4,
#     'HighCholesterolCrdPrv': 36.5}},
#   {'county': 'Barrow',
#    'state': 'GA',
#    'population': 85588,
#    'location': [33, -83],
#    'measurements': {'HighCholesterolAgeAdjPrv': 30.6,
#     'HighBloodPressureCrdPrv': 32.9,
#     'HighBloodPressureAgeAdjPrv': 32.5,
#     'HighCholesterolCrdPrv': 32.8}},
#   {'county': 'Barry',
#    'state': 'MI',
#    'population': 62061,
#    'location': [42, -85],
#    'measurements': {'HighCholesterolCrdPrv': 37.3,
#     'HighCholesterolAgeAdjPrv': 31.1,
#     'HighBloodPressureCrdPrv': 34.8,
#     'HighBloodPressureAgeAdjPrv': 29.8}},
#   {'county': 'Barry',
#    'state': 'MO',
#    'population': 35818,
#    'location': [36, -93],
#    'measurements': {'HighBloodPressureCrdPrv': 36.5,
#     'HighBloodPressureAgeAdjPrv': 30.8,
#     'HighCholesterolCrdPrv': 36.6,
#     'HighCholesterolAgeAdjPrv': 29.5}},
#   {'county': 'Bartholomew',
#    'state': 'IN',
#    'population': 84447,
#    'location': [39, -85],
#    'measurements': {'HighBloodPressureCrdPrv': 35.2,
#     'HighCholesterolAgeAdjPrv': 30.4,
#     'HighCholesterolCrdPrv': 34.2,
#     'HighBloodPressureAgeAdjPrv': 32.9}},
#   {'county': 'Barton',
#    'state': 'KS',
#    'population': 25658,
#    'location': [38, -98],
#    'measurements': {'HighCholesterolAgeAdjPrv': 30.4,
#     'HighBloodPressureCrdPrv': 37.2,
#     'HighBloodPressureAgeAdjPrv': 32.9,
#     'HighCholesterolCrdPrv': 36.2}},
#   {'county': 'Barton',
#    'state': 'MO',
#    'population': 11592,
#    'location': [37, -94],
#    'measurements': {'HighBloodPressureCrdPrv': 38.0,
#     'HighBloodPressureAgeAdjPrv': 31.7,
#     'HighCholesterolCrdPrv': 37.8,
#     'HighCholesterolAgeAdjPrv': 30.3}},
#   {'county': 'Bartow',
#    'state': 'GA',
#    'population': 109426,
#    'location': [34, -84],
#    'measurements': {'HighCholesterolAgeAdjPrv': 30.9,
#     'HighBloodPressureAgeAdjPrv': 34.2,
#     'HighBloodPressureCrdPrv': 36.1,
#     'HighCholesterolCrdPrv': 34.6}},
#   {'county': 'Bastrop',
#    'state': 'TX',
#    'population': 91601,
#    'location': [30, -97],
#    'measurements': {'HighBloodPressureCrdPrv': 33.2,
#     'HighBloodPressureAgeAdjPrv': 31.8,
#     'HighCholesterolAgeAdjPrv': 31.8,
#     'HighCholesterolCrdPrv': 35.4}},
#   {'county': 'Bates',
#    'state': 'MO',
#    'population': 16242,
#    'location': [38, -94],
#    'measurements': {'HighCholesterolAgeAdjPrv': 30.3,
#     'HighCholesterolCrdPrv': 37.2,
#     'HighBloodPressureAgeAdjPrv': 29.8,
#     'HighBloodPressureCrdPrv': 35.1}},
#   {'county': 'Bath',
#    'state': 'KY',
#    'population': 12481,
#    'location': [38, -83],
#    'measurements': {'HighCholesterolAgeAdjPrv': 33.4,
#     'HighBloodPressureCrdPrv': 43.7,
#     'HighBloodPressureAgeAdjPrv': 38.9,
#     'HighCholesterolCrdPrv': 39.0}},
#   {'county': 'Bath',
#    'state': 'VA',
#    'population': 4119,
#    'location': [38, -79],
#    'measurements': {'HighCholesterolCrdPrv': 39.9,
#     'HighBloodPressureAgeAdjPrv': 35.0,
#     'HighBloodPressureCrdPrv': 44.8,
#     'HighCholesterolAgeAdjPrv': 30.3}},
#   {'county': 'Baxter',
#    'state': 'AR',
#    'population': 42242,
#    'location': [36, -92],
#    'measurements': {'HighCholesterolCrdPrv': 42.1,
#     'HighCholesterolAgeAdjPrv': 31.4,
#     'HighBloodPressureCrdPrv': 43.6,
#     'HighBloodPressureAgeAdjPrv': 32.6}},
#   {'county': 'Bay',
#    'state': 'FL',
#    'population': 171322,
#    'location': [30, -85],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.6,
#     'HighCholesterolAgeAdjPrv': 28.2,
#     'HighBloodPressureCrdPrv': 35.7,
#     'HighCholesterolCrdPrv': 33.5}},
#   {'county': 'Bay',
#    'state': 'MI',
#    'population': 102387,
#    'location': [43, -83],
#    'measurements': {'HighCholesterolCrdPrv': 37.0,
#     'HighCholesterolAgeAdjPrv': 30.7,
#     'HighBloodPressureCrdPrv': 36.2,
#     'HighBloodPressureAgeAdjPrv': 30.8}},
#   {'county': 'Bayfield',
#    'state': 'WI',
#    'population': 15242,
#    'location': [46, -91],
#    'measurements': {'HighBloodPressureCrdPrv': 39.1,
#     'HighBloodPressureAgeAdjPrv': 29.1,
#     'HighCholesterolCrdPrv': 37.1,
#     'HighCholesterolAgeAdjPrv': 26.7}},
#   {'county': 'Baylor',
#    'state': 'TX',
#    'population': 3518,
#    'location': [33, -99],
#    'measurements': {'HighCholesterolAgeAdjPrv': 30.9,
#     'HighBloodPressureCrdPrv': 38.9,
#     'HighCholesterolCrdPrv': 38.5,
#     'HighBloodPressureAgeAdjPrv': 32.0}},
#   {'county': 'Beadle',
#    'state': 'SD',
#    'population': 18513,
#    'location': [44, -98],
#    'measurements': {'HighCholesterolAgeAdjPrv': 26.8,
#     'HighCholesterolCrdPrv': 32.2,
#     'HighBloodPressureCrdPrv': 32.3,
#     'HighBloodPressureAgeAdjPrv': 28.7}},
#   {'county': 'Bear Lake',
#    'state': 'ID',
#    'population': 6143,
#    'location': [42, -111],
#    'measurements': {'HighCholesterolAgeAdjPrv': 25.6,
#     'HighCholesterolCrdPrv': 32.5,
#     'HighBloodPressureAgeAdjPrv': 28.7,
#     'HighBloodPressureCrdPrv': 34.5}},
#   {'county': 'Beaufort',
#    'state': 'NC',
#    'population': 47073,
#    'location': [35, -76],
#    'measurements': {'HighCholesterolAgeAdjPrv': 29.9,
#     'HighBloodPressureCrdPrv': 41.8,
#     'HighCholesterolCrdPrv': 37.7,
#     'HighBloodPressureAgeAdjPrv': 34.4}},
#   {'county': 'Beaufort',
#    'state': 'SC',
#    'population': 195656,
#    'location': [32, -80],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.8,
#     'HighCholesterolAgeAdjPrv': 30.9,
#     'HighBloodPressureCrdPrv': 38.7,
#     'HighCholesterolCrdPrv': 38.7}},
#   {'county': 'Beauregard',
#    'state': 'LA',
#    'population': 37881,
#    'location': [30, -93],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 35.7,
#     'HighCholesterolCrdPrv': 37.2,
#     'HighCholesterolAgeAdjPrv': 33.0,
#     'HighBloodPressureCrdPrv': 38.3}},
#   {'county': 'Beaver',
#    'state': 'OK',
#    'population': 5207,
#    'location': [36, -100],
#    'measurements': {'HighCholesterolAgeAdjPrv': 30.1,
#     'HighCholesterolCrdPrv': 35.3,
#     'HighBloodPressureAgeAdjPrv': 34.2,
#     'HighBloodPressureCrdPrv': 38.2}},
#   {'county': 'Beaver',
#    'state': 'PA',
#    'population': 162575,
#    'location': [40, -80],
#    'measurements': {'HighCholesterolCrdPrv': 37.0,
#     'HighBloodPressureAgeAdjPrv': 30.0,
#     'HighBloodPressureCrdPrv': 36.2,
#     'HighCholesterolAgeAdjPrv': 29.9}},
#   {'county': 'Beaver',
#    'state': 'UT',
#    'population': 6761,
#    'location': [38, -113],
#    'measurements': {'HighBloodPressureCrdPrv': 29.6,
#     'HighCholesterolAgeAdjPrv': 28.0,
#     'HighCholesterolCrdPrv': 32.0,
#     'HighBloodPressureAgeAdjPrv': 28.0}},
#   {'county': 'Beaverhead',
#    'state': 'MT',
#    'population': 9483,
#    'location': [45, -112],
#    'measurements': {'HighCholesterolCrdPrv': 31.5,
#     'HighBloodPressureAgeAdjPrv': 26.1,
#     'HighBloodPressureCrdPrv': 30.0,
#     'HighCholesterolAgeAdjPrv': 25.9}},
#   {'county': 'Becker',
#    'state': 'MN',
#    'population': 34456,
#    'location': [46, -95],
#    'measurements': {'HighCholesterolCrdPrv': 34.5,
#     'HighBloodPressureAgeAdjPrv': 27.3,
#     'HighBloodPressureCrdPrv': 33.3,
#     'HighCholesterolAgeAdjPrv': 27.4}},
#   {'county': 'Beckham',
#    'state': 'OK',
#    'population': 21468,
#    'location': [35, -99],
#    'measurements': {'HighBloodPressureCrdPrv': 36.3,
#     'HighCholesterolAgeAdjPrv': 32.1,
#     'HighCholesterolCrdPrv': 34.6,
#     'HighBloodPressureAgeAdjPrv': 36.1}},
#   {'county': 'Bedford',
#    'state': 'PA',
#    'population': 47817,
#    'location': [39, -78],
#    'measurements': {'HighCholesterolCrdPrv': 36.5,
#     'HighBloodPressureAgeAdjPrv': 30.1,
#     'HighBloodPressureCrdPrv': 37.5,
#     'HighCholesterolAgeAdjPrv': 28.5}},
#   {'county': 'Bedford',
#    'state': 'TN',
#    'population': 50179,
#    'location': [35, -86],
#    'measurements': {'HighBloodPressureCrdPrv': 37.3,
#     'HighBloodPressureAgeAdjPrv': 35.8,
#     'HighCholesterolAgeAdjPrv': 30.2,
#     'HighCholesterolCrdPrv': 33.5}},
#   {'county': 'Bedford',
#    'state': 'VA',
#    'population': 79811,
#    'location': [37, -79],
#    'measurements': {'HighCholesterolCrdPrv': 36.4,
#     'HighBloodPressureAgeAdjPrv': 30.4,
#     'HighBloodPressureCrdPrv': 37.2,
#     'HighCholesterolAgeAdjPrv': 29.0}},
#   {'county': 'Bee',
#    'state': 'TX',
#    'population': 32513,
#    'location': [28, -97],
#    'measurements': {'HighCholesterolAgeAdjPrv': 32.0,
#     'HighBloodPressureCrdPrv': 33.3,
#     'HighBloodPressureAgeAdjPrv': 35.1,
#     'HighCholesterolCrdPrv': 33.0}},
#   {'county': 'Belknap',
#    'state': 'NH',
#    'population': 61551,
#    'location': [43, -71],
#    'measurements': {'HighCholesterolCrdPrv': 35.1,
#     'HighBloodPressureAgeAdjPrv': 28.3,
#     'HighCholesterolAgeAdjPrv': 27.4,
#     'HighBloodPressureCrdPrv': 35.2}},
#   {'county': 'Bell',
#    'state': 'KY',
#    'population': 25482,
#    'location': [36, -83],
#    'measurements': {'HighCholesterolAgeAdjPrv': 35.6,
#     'HighBloodPressureAgeAdjPrv': 44.7,
#     'HighBloodPressureCrdPrv': 50.1,
#     'HighCholesterolCrdPrv': 42.1}},
#   {'county': 'Bell',
#    'state': 'TX',
#    'population': 369927,
#    'location': [31, -97],
#    'measurements': {'HighBloodPressureCrdPrv': 30.9,
#     'HighCholesterolAgeAdjPrv': 29.8,
#     'HighBloodPressureAgeAdjPrv': 33.4,
#     'HighCholesterolCrdPrv': 29.7}},
#   {'county': 'Belmont',
#    'state': 'OH',
#    'population': 65932,
#    'location': [40, -80],
#    'measurements': {'HighCholesterolCrdPrv': 35.1,
#     'HighBloodPressureAgeAdjPrv': 30.4,
#     'HighBloodPressureCrdPrv': 36.0,
#     'HighCholesterolAgeAdjPrv': 28.3}},
#   {'county': 'Beltrami',
#    'state': 'MN',
#    'population': 47442,
#    'location': [47, -95],
#    'measurements': {'HighBloodPressureCrdPrv': 28.8,
#     'HighCholesterolCrdPrv': 30.1,
#     'HighBloodPressureAgeAdjPrv': 27.2,
#     'HighCholesterolAgeAdjPrv': 26.5}},
#   {'county': 'Ben Hill',
#    'state': 'GA',
#    'population': 16614,
#    'location': [31, -83],
#    'measurements': {'HighCholesterolCrdPrv': 36.1,
#     'HighBloodPressureAgeAdjPrv': 39.1,
#     'HighBloodPressureCrdPrv': 43.3,
#     'HighCholesterolAgeAdjPrv': 30.7}},
#   {'county': 'Benewah',
#    'state': 'ID',
#    'population': 9430,
#    'location': [47, -116],
#    'measurements': {'HighCholesterolCrdPrv': 35.5,
#     'HighBloodPressureAgeAdjPrv': 29.6,
#     'HighBloodPressureCrdPrv': 37.1,
#     'HighCholesterolAgeAdjPrv': 26.8}},
#   {'county': 'Bennett',
#    'state': 'SD',
#    'population': 3399,
#    'location': [43, -101],
#    'measurements': {'HighCholesterolAgeAdjPrv': 26.1,
#     'HighBloodPressureAgeAdjPrv': 34.9,
#     'HighCholesterolCrdPrv': 30.1,
#     'HighBloodPressureCrdPrv': 36.3}},
#   {'county': 'Bennington',
#    'state': 'VT',
#    'population': 35338,
#    'location': [43, -73],
#    'measurements': {'HighCholesterolAgeAdjPrv': 23.6,
#     'HighCholesterolCrdPrv': 30.5,
#     'HighBloodPressureAgeAdjPrv': 24.3,
#     'HighBloodPressureCrdPrv': 30.3}},
#   {'county': 'Benson',
#    'state': 'ND',
#    'population': 6762,
#    'location': [48, -99],
#    'measurements': {'HighCholesterolCrdPrv': 32.3,
#     'HighBloodPressureCrdPrv': 39.0,
#     'HighBloodPressureAgeAdjPrv': 35.8,
#     'HighCholesterolAgeAdjPrv': 27.0}},
#   {'county': 'Bent',
#    'state': 'CO',
#    'population': 5356,
#    'location': [37, -103],
#    'measurements': {'HighCholesterolAgeAdjPrv': 27.8,
#     'HighCholesterolCrdPrv': 31.4,
#     'HighBloodPressureCrdPrv': 33.3,
#     'HighBloodPressureAgeAdjPrv': 31.8}},
#   {'county': 'Benton',
#    'state': 'AR',
#    'population': 288774,
#    'location': [36, -94],
#    'measurements': {'HighCholesterolCrdPrv': 31.9,
#     'HighCholesterolAgeAdjPrv': 30.0,
#     'HighBloodPressureCrdPrv': 31.6,
#     'HighBloodPressureAgeAdjPrv': 31.5}},
#   {'county': 'Benton',
#    'state': 'IA',
#    'population': 25414,
#    'location': [42, -92],
#    'measurements': {'HighBloodPressureCrdPrv': 33.6,
#     'HighCholesterolAgeAdjPrv': 27.6,
#     'HighCholesterolCrdPrv': 34.2,
#     'HighBloodPressureAgeAdjPrv': 28.1}},
#   {'county': 'Benton',
#    'state': 'IN',
#    'population': 8741,
#    'location': [40, -87],
#    'measurements': {'HighBloodPressureCrdPrv': 37.7,
#     'HighBloodPressureAgeAdjPrv': 32.9,
#     'HighCholesterolAgeAdjPrv': 29.2,
#     'HighCholesterolCrdPrv': 35.1}},
#   {'county': 'Benton',
#    'state': 'MN',
#    'population': 40958,
#    'location': [45, -94],
#    'measurements': {'HighBloodPressureCrdPrv': 28.1,
#     'HighBloodPressureAgeAdjPrv': 26.7,
#     'HighCholesterolCrdPrv': 28.8,
#     'HighCholesterolAgeAdjPrv': 25.7}},
#   {'county': 'Benton',
#    'state': 'MO',
#    'population': 19627,
#    'location': [38, -93],
#    'measurements': {'HighCholesterolAgeAdjPrv': 30.9,
#     'HighBloodPressureAgeAdjPrv': 31.3,
#     'HighBloodPressureCrdPrv': 43.0,
#     'HighCholesterolCrdPrv': 42.7}},
#   {'county': 'Benton',
#    'state': 'MS',
#    'population': 8351,
#    'location': [34, -89],
#    'measurements': {'HighBloodPressureCrdPrv': 46.3,
# ...
#     'HighCholesterolCrdPrv': 33.3,
#     'HighBloodPressureAgeAdjPrv': 36.1}},
#   {'county': 'Forest',
#    'state': 'WI',
#    'population': 8960,
#    'location': [45, -88],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.4,
#     'HighCholesterolCrdPrv': 37.2,
#     'HighCholesterolAgeAdjPrv': 28.6,
#     'HighBloodPressureCrdPrv': 38.5}},
#   {'county': 'Forrest',
#    'state': 'MS',
#    'population': 75009,
#    'location': [31, -89],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 41.2,
#     'HighBloodPressureCrdPrv': 40.2,
#     'HighCholesterolCrdPrv': 35.3,
#     'HighCholesterolAgeAdjPrv': 33.9}},
#   {'county': 'Forsyth',
#    'state': 'GA',
#    'population': 250847,
#    'location': [34, -84],
#    'measurements': {'HighCholesterolCrdPrv': 33.9,
#     'HighBloodPressureAgeAdjPrv': 26.9,
#     'HighCholesterolAgeAdjPrv': 30.8,
#     'HighBloodPressureCrdPrv': 28.3}},
#   {'county': 'Forsyth',
#    'state': 'NC',
#    'population': 383843,
#    'location': [36, -80],
#    'measurements': {'HighCholesterolCrdPrv': 33.1,
#     'HighBloodPressureAgeAdjPrv': 31.5,
#     'HighBloodPressureCrdPrv': 33.6,
#     'HighCholesterolAgeAdjPrv': 29.7}},
#   {'county': 'Fort Bend',
#    'state': 'TX',
#    'population': 839706,
#    'location': [29, -95],
#    'measurements': {'HighCholesterolCrdPrv': 34.2,
#     'HighBloodPressureCrdPrv': 31.9,
#     'HighCholesterolAgeAdjPrv': 32.0,
#     'HighBloodPressureAgeAdjPrv': 31.6}},
#   {'county': 'Foster',
#    'state': 'ND',
#    'population': 3165,
#    'location': [47, -98],
#    'measurements': {'HighCholesterolAgeAdjPrv': 27.2,
#     'HighBloodPressureAgeAdjPrv': 28.9,
#     'HighCholesterolCrdPrv': 34.9,
#     'HighBloodPressureCrdPrv': 36.0}},
#   {'county': 'Fountain',
#    'state': 'IN',
#    'population': 16511,
#    'location': [40, -87],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 32.3,
#     'HighCholesterolAgeAdjPrv': 30.3,
#     'HighBloodPressureCrdPrv': 38.1,
#     'HighCholesterolCrdPrv': 37.2}},
#   {'county': 'Franklin',
#    'state': 'AL',
#    'population': 31507,
#    'location': [34, -87],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 37.7,
#     'HighCholesterolAgeAdjPrv': 32.1,
#     'HighBloodPressureCrdPrv': 40.4,
#     'HighCholesterolCrdPrv': 36.2}},
#   {'county': 'Franklin',
#    'state': 'AR',
#    'population': 17897,
#    'location': [35, -93],
#    'measurements': {'HighCholesterolCrdPrv': 42.1,
#     'HighCholesterolAgeAdjPrv': 34.9,
#     'HighBloodPressureAgeAdjPrv': 36.6,
#     'HighBloodPressureCrdPrv': 42.1}},
#   {'county': 'Franklin',
#    'state': 'FL',
#    'population': 12201,
#    'location': [29, -84],
#    'measurements': {'HighCholesterolAgeAdjPrv': 29.8,
#     'HighCholesterolCrdPrv': 36.5,
#     'HighBloodPressureAgeAdjPrv': 35.2,
#     'HighBloodPressureCrdPrv': 40.6}},
#   {'county': 'Franklin',
#    'state': 'GA',
#    'population': 23504,
#    'location': [34, -83],
#    'measurements': {'HighBloodPressureCrdPrv': 38.9,
#     'HighBloodPressureAgeAdjPrv': 34.9,
#     'HighCholesterolCrdPrv': 36.8,
#     'HighCholesterolAgeAdjPrv': 31.3}},
#   {'county': 'Franklin',
#    'state': 'IA',
#    'population': 9971,
#    'location': [42, -93],
#    'measurements': {'HighBloodPressureCrdPrv': 36.4,
#     'HighCholesterolCrdPrv': 33.8,
#     'HighBloodPressureAgeAdjPrv': 30.6,
#     'HighCholesterolAgeAdjPrv': 27.3}},
#   {'county': 'Franklin',
#    'state': 'ID',
#    'population': 14215,
#    'location': [42, -111],
#    'measurements': {'HighCholesterolCrdPrv': 31.4,
#     'HighBloodPressureAgeAdjPrv': 27.3,
#     'HighBloodPressureCrdPrv': 29.5,
#     'HighCholesterolAgeAdjPrv': 27.0}},
#   {'county': 'Franklin',
#    'state': 'IL',
#    'population': 38060,
#    'location': [37, -88],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 32.9,
#     'HighBloodPressureCrdPrv': 39.0,
#     'HighCholesterolCrdPrv': 36.1,
#     'HighCholesterolAgeAdjPrv': 29.2}},
#   {'county': 'Franklin',
#    'state': 'IN',
#    'population': 22761,
#    'location': [39, -85],
#    'measurements': {'HighCholesterolAgeAdjPrv': 28.3,
#     'HighBloodPressureAgeAdjPrv': 31.5,
#     'HighCholesterolCrdPrv': 34.9,
#     'HighBloodPressureCrdPrv': 37.0}},
#   {'county': 'Franklin',
#    'state': 'KS',
#    'population': 25703,
#    'location': [38, -95],
#    'measurements': {'HighCholesterolCrdPrv': 34.1,
#     'HighCholesterolAgeAdjPrv': 28.6,
#     'HighBloodPressureAgeAdjPrv': 30.9,
#     'HighBloodPressureCrdPrv': 34.7}},
#   {'county': 'Franklin',
#    'state': 'KY',
#    'population': 51118,
#    'location': [38, -84],
#    'measurements': {'HighCholesterolAgeAdjPrv': 32.7,
#     'HighBloodPressureCrdPrv': 42.0,
#     'HighBloodPressureAgeAdjPrv': 38.2,
#     'HighCholesterolCrdPrv': 37.2}},
#   {'county': 'Franklin',
#    'state': 'LA',
#    'population': 19723,
#    'location': [32, -91],
#    'measurements': {'HighBloodPressureCrdPrv': 45.0,
#     'HighCholesterolAgeAdjPrv': 32.4,
#     'HighCholesterolCrdPrv': 38.3,
#     'HighBloodPressureAgeAdjPrv': 40.3}},
#   {'county': 'Franklin',
#    'state': 'MA',
#    'population': 70267,
#    'location': [42, -72],
#    'measurements': {'HighBloodPressureCrdPrv': 31.5,
#     'HighBloodPressureAgeAdjPrv': 25.6,
#     'HighCholesterolCrdPrv': 32.1,
#     'HighCholesterolAgeAdjPrv': 25.5}},
#   {'county': 'Franklin',
#    'state': 'ME',
#    'population': 29986,
#    'location': [44, -70],
#    'measurements': {'HighCholesterolAgeAdjPrv': 27.5,
#     'HighBloodPressureAgeAdjPrv': 29.0,
#     'HighBloodPressureCrdPrv': 35.3,
#     'HighCholesterolCrdPrv': 34.8}},
#   {'county': 'Franklin',
#    'state': 'MO',
#    'population': 104469,
#    'location': [38, -91],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 28.3,
#     'HighCholesterolCrdPrv': 36.9,
#     'HighCholesterolAgeAdjPrv': 30.6,
#     'HighBloodPressureCrdPrv': 32.9}},
#   {'county': 'Franklin',
#    'state': 'MS',
#    'population': 7657,
#    'location': [31, -90],
#    'measurements': {'HighCholesterolCrdPrv': 40.7,
#     'HighCholesterolAgeAdjPrv': 33.2,
#     'HighBloodPressureAgeAdjPrv': 41.4,
#     'HighBloodPressureCrdPrv': 48.0}},
#   {'county': 'Franklin',
#    'state': 'NC',
#    'population': 71859,
#    'location': [36, -78],
#    'measurements': {'HighCholesterolCrdPrv': 35.7,
#     'HighBloodPressureAgeAdjPrv': 33.7,
#     'HighCholesterolAgeAdjPrv': 30.7,
#     'HighBloodPressureCrdPrv': 37.4}},
#   {'county': 'Franklin',
#    'state': 'NE',
#    'population': 2940,
#    'location': [40, -98],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.3,
#     'HighCholesterolCrdPrv': 37.8,
#     'HighCholesterolAgeAdjPrv': 27.9,
#     'HighBloodPressureCrdPrv': 41.3}},
#   {'county': 'Franklin',
#    'state': 'NY',
#    'population': 49965,
#    'location': [44, -74],
#    'measurements': {'HighCholesterolCrdPrv': 33.6,
#     'HighCholesterolAgeAdjPrv': 29.4,
#     'HighBloodPressureCrdPrv': 35.4,
#     'HighBloodPressureAgeAdjPrv': 32.8}},
#   {'county': 'Franklin',
#    'state': 'OH',
#    'population': 1324624,
#    'location': [39, -83],
#    'measurements': {'HighBloodPressureCrdPrv': 31.3,
#     'HighCholesterolAgeAdjPrv': 28.3,
#     'HighCholesterolCrdPrv': 29.5,
#     'HighBloodPressureAgeAdjPrv': 32.2}},
#   {'county': 'Franklin',
#    'state': 'PA',
#    'population': 155637,
#    'location': [39, -77],
#    'measurements': {'HighCholesterolAgeAdjPrv': 27.7,
#     'HighBloodPressureCrdPrv': 35.7,
#     'HighBloodPressureAgeAdjPrv': 30.8,
#     'HighCholesterolCrdPrv': 33.5}},
#   {'county': 'Franklin',
#    'state': 'TN',
#    'population': 42485,
#    'location': [35, -86],
#    'measurements': {'HighCholesterolCrdPrv': 37.2,
#     'HighCholesterolAgeAdjPrv': 31.5,
#     'HighBloodPressureCrdPrv': 40.4,
#     'HighBloodPressureAgeAdjPrv': 36.0}},
#   {'county': 'Franklin',
#    'state': 'TX',
#    'population': 10821,
#    'location': [33, -95],
#    'measurements': {'HighBloodPressureCrdPrv': 36.4,
#     'HighCholesterolAgeAdjPrv': 30.6,
#     'HighCholesterolCrdPrv': 37.4,
#     'HighBloodPressureAgeAdjPrv': 30.6}},
#   {'county': 'Franklin',
#    'state': 'VA',
#    'population': 56167,
#    'location': [36, -79],
#    'measurements': {'HighBloodPressureCrdPrv': 42.3,
#     'HighBloodPressureAgeAdjPrv': 34.4,
#     'HighCholesterolAgeAdjPrv': 30.1,
#     'HighCholesterolCrdPrv': 38.5}},
#   {'county': 'Franklin',
#    'state': 'VT',
#    'population': 49685,
#    'location': [44, -72],
#    'measurements': {'HighCholesterolAgeAdjPrv': 25.2,
#     'HighBloodPressureCrdPrv': 29.3,
#     'HighBloodPressureAgeAdjPrv': 25.8,
#     'HighCholesterolCrdPrv': 30.4}},
#   {'county': 'Franklin',
#    'state': 'WA',
#    'population': 97075,
#    'location': [46, -118],
#    'measurements': {'HighBloodPressureCrdPrv': 26.2,
#     'HighCholesterolAgeAdjPrv': 29.4,
#     'HighBloodPressureAgeAdjPrv': 29.4,
#     'HighCholesterolCrdPrv': 29.0}},
#   {'county': 'Franklin City',
#    'state': 'VA',
#    'population': 7833,
#    'location': [36, -76],
#    'measurements': {'HighBloodPressureCrdPrv': 46.3,
#     'HighCholesterolAgeAdjPrv': 29.1,
#     'HighCholesterolCrdPrv': 35.2,
#     'HighBloodPressureAgeAdjPrv': 40.6}},
#   {'county': 'Frederick',
#    'state': 'MD',
#    'population': 265161,
#    'location': [39, -77],
#    'measurements': {'HighBloodPressureCrdPrv': 31.0,
#     'HighCholesterolAgeAdjPrv': 30.9,
#     'HighCholesterolCrdPrv': 34.4,
#     'HighBloodPressureAgeAdjPrv': 29.1}},
#   {'county': 'Frederick',
#    'state': 'VA',
#    'population': 91119,
#    'location': [39, -78],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.1,
#     'HighBloodPressureCrdPrv': 34.9,
#     'HighCholesterolAgeAdjPrv': 29.0,
#     'HighCholesterolCrdPrv': 33.8}},
#   {'county': 'Fredericksburg',
#    'state': 'VA',
#    'population': 29492,
#    'location': [38, -77],
#    'measurements': {'HighBloodPressureCrdPrv': 30.1,
#     'HighCholesterolAgeAdjPrv': 29.0,
#     'HighCholesterolCrdPrv': 27.8,
#     'HighBloodPressureAgeAdjPrv': 33.6}},
#   {'county': 'Freeborn',
#    'state': 'MN',
#    'population': 30364,
#    'location': [43, -93],
#    'measurements': {'HighBloodPressureCrdPrv': 33.2,
#     'HighCholesterolCrdPrv': 33.1,
#     'HighCholesterolAgeAdjPrv': 26.4,
#     'HighBloodPressureAgeAdjPrv': 27.3}},
#   {'county': 'Freestone',
#    'state': 'TX',
#    'population': 19874,
#    'location': [31, -96],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 36.0,
#     'HighCholesterolCrdPrv': 38.0,
#     'HighBloodPressureCrdPrv': 40.6,
#     'HighCholesterolAgeAdjPrv': 32.0}},
#   {'county': 'Fremont',
#    'state': 'CO',
#    'population': 47867,
#    'location': [38, -105],
#    'measurements': {'HighBloodPressureCrdPrv': 31.2,
#     'HighCholesterolCrdPrv': 31.6,
#     'HighBloodPressureAgeAdjPrv': 27.2,
#     'HighCholesterolAgeAdjPrv': 26.3}},
#   {'county': 'Fremont',
#    'state': 'IA',
#    'population': 6729,
#    'location': [40, -95],
#    'measurements': {'HighCholesterolCrdPrv': 36.8,
#     'HighBloodPressureCrdPrv': 38.0,
#     'HighBloodPressureAgeAdjPrv': 30.3,
#     'HighCholesterolAgeAdjPrv': 28.6}},
#   {'county': 'Fremont',
#    'state': 'ID',
#    'population': 13218,
#    'location': [44, -111],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 29.3,
#     'HighCholesterolCrdPrv': 32.2,
#     'HighCholesterolAgeAdjPrv': 27.3,
#     'HighBloodPressureCrdPrv': 32.2}},
#   {'county': 'Fremont',
#    'state': 'WY',
#    'population': 39317,
#    'location': [43, -108],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 25.3,
#     'HighBloodPressureCrdPrv': 29.4,
#     'HighCholesterolAgeAdjPrv': 24.8,
#     'HighCholesterolCrdPrv': 30.4}},
#   {'county': 'Fresno',
#    'state': 'CA',
#    'population': 1000918,
#    'location': [36, -119],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 29.7,
#     'HighBloodPressureCrdPrv': 28.5,
#     'HighCholesterolAgeAdjPrv': 28.0,
#     'HighCholesterolCrdPrv': 29.0}},
#   {'county': 'Frio',
#    'state': 'TX',
#    'population': 20379,
#    'location': [28, -99],
#    'measurements': {'HighCholesterolCrdPrv': 32.5,
#     'HighCholesterolAgeAdjPrv': 32.5,
#     'HighBloodPressureAgeAdjPrv': 35.0,
#     'HighBloodPressureCrdPrv': 32.1}},
#   {'county': 'Frontier',
#    'state': 'NE',
#    'population': 2587,
#    'location': [40, -100],
#    'measurements': {'HighCholesterolAgeAdjPrv': 26.5,
#     'HighCholesterolCrdPrv': 33.6,
#     'HighBloodPressureAgeAdjPrv': 28.1,
#     'HighBloodPressureCrdPrv': 34.4}},
#   {'county': 'Fulton',
#    'state': 'AR',
#    'population': 12381,
#    'location': [36, -91],
#    'measurements': {'HighCholesterolAgeAdjPrv': 34.0,
#     'HighCholesterolCrdPrv': 44.0,
#     'HighBloodPressureAgeAdjPrv': 38.0,
#     'HighBloodPressureCrdPrv': 47.4}},
#   {'county': 'Fulton',
#    'state': 'GA',
#    'population': 1077402,
#    'location': [33, -84],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 32.0,
#     'HighCholesterolCrdPrv': 29.1,
#     'HighCholesterolAgeAdjPrv': 28.4,
#     'HighBloodPressureCrdPrv': 31.1}},
#   {'county': 'Fulton',
#    'state': 'IL',
#    'population': 33690,
#    'location': [40, -90],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 32.2,
#     'HighBloodPressureCrdPrv': 37.1,
#     'HighCholesterolAgeAdjPrv': 29.1,
#     'HighCholesterolCrdPrv': 35.2}},
#   {'county': 'Fulton',
#    'state': 'IN',
#    'population': 20018,
#    'location': [41, -86],
#    'measurements': {'HighCholesterolAgeAdjPrv': 28.8,
#     'HighCholesterolCrdPrv': 35.1,
#     'HighBloodPressureAgeAdjPrv': 32.0,
#     'HighBloodPressureCrdPrv': 37.3}},
#   {'county': 'Fulton',
#    'state': 'KY',
#    'population': 5952,
#    'location': [36, -89],
#    'measurements': {'HighBloodPressureCrdPrv': 50.1,
#     'HighCholesterolAgeAdjPrv': 33.1,
#     'HighCholesterolCrdPrv': 39.4,
#     'HighBloodPressureAgeAdjPrv': 44.5}},
#   {'county': 'Fulton',
#    'state': 'NY',
#    'population': 52812,
#    'location': [43, -74],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 31.1,
#     'HighBloodPressureCrdPrv': 36.4,
#     'HighCholesterolAgeAdjPrv': 27.9,
#     'HighCholesterolCrdPrv': 34.1}},
#   {'county': 'Fulton',
#    'state': 'OH',
#    'population': 41889,
#    'location': [41, -84],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 30.4,
#     'HighBloodPressureCrdPrv': 34.7,
#     'HighCholesterolCrdPrv': 32.3,
#     'HighCholesterolAgeAdjPrv': 26.9}},
#   {'county': 'Fulton',
#    'state': 'PA',
#    'population': 14501,
#    'location': [39, -78],
#    'measurements': {'HighBloodPressureAgeAdjPrv': 30.1,
#     'HighCholesterolAgeAdjPrv': 28.8,
#     'HighBloodPressureCrdPrv': 36.6,
#     'HighCholesterolCrdPrv': 36.2}},
#   {'county': 'Furnas',
#    'state': 'NE',
#    'population': 4653,
#    'location': [40, -99],
#    'measurements': {'HighCholesterolCrdPrv': 37.3,
#     'HighCholesterolAgeAdjPrv': 28.4,
#     'HighBloodPressureAgeAdjPrv': 31.4,
#     'HighBloodPressureCrdPrv': 39.6}},
#   {'county': 'Gadsden',
#    'state': 'FL',
#    'population': 45277,
#    'location': [30, -84],
#    'measurements': {'HighBloodPressureCrdPrv': 43.0,
#     'HighCholesterolAgeAdjPrv': 28.5,
#     'HighCholesterolCrdPrv': 33.5,
#     'HighBloodPressureAgeAdjPrv': 38.9}},
#   {'county': 'Gage',
#    'state': 'NE',
#    'population': 21431,
#    'location': [40, -96],
#    'measurements': {'HighCholesterolCrdPrv': 32.8,
#     'HighBloodPressureCrdPrv': 37.9,
#     'HighBloodPressureAgeAdjPrv': 31.3,
#     'HighCholesterolAgeAdjPrv': 25.8}},
#   {'county': 'Gaines',
#    'state': 'TX',
#    'population': 21996,
#    'location': [32, -102],
#    'measurements': {'HighCholesterolAgeAdjPrv': 31.6,
#     'HighCholesterolCrdPrv': 32.7,
#     'HighBloodPressureAgeAdjPrv': 33.1,
#     'HighBloodPressureCrdPrv': 31.3}},
#   {'county': 'Galax',
#    'state': 'VA',
#    'population': 6296,
#    'location': [36, -80],
#    'measurements': {'HighCholesterolCrdPrv': 36.8,
#     'HighBloodPressureCrdPrv': 40.3,
#     'HighBloodPressureAgeAdjPrv': 36.3,
#     'HighCholesterolAgeAdjPrv': 31.5}},
#   {'county': 'Gallatin',
#    'state': 'IL',
#    'population': 4793,
#    'location': [37, -88],
#    'measurements': {'HighBloodPressureCrdPrv': 40.9,
#     'HighBloodPressureAgeAdjPrv': 33.1,
#     'HighCholesterolCrdPrv': 38.0,
#     'HighCholesterolAgeAdjPrv': 29.6}},
#   {'county': 'Gallatin',
#    'state': 'KY',
#    'population': 8779,
#    'location': [38, -84],
#    'measurements': {'HighBloodPressureCrdPrv': 40.6,
#     'HighBloodPressureAgeAdjPrv': 37.9,
#     'HighCholesterolAgeAdjPrv': 33.3,
#     'HighCholesterolCrdPrv': 37.4}},
#   {'county': 'Gallatin',
#    'state': 'MT',
#    'population': 116806,
#    'location': [45, -111],
#    'measurements': {'HighCholesterolAgeAdjPrv': 23.3,
#     'HighBloodPressureCrdPrv': 20.0,
#     'HighBloodPressureAgeAdjPrv': 21.5,
#     'HighCholesterolCrdPrv': 24.0}},
#   ...]}

# %%
with open("data.json", "w") as outfile:
    json.dump(data, outfile)
