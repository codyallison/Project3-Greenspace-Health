# %%
## Import Dependencies
from pprint import pprint
import pandas as pd
import re
import matplotlib.pyplot as plt
from scipy.stats import linregress
import scipy.stats as stats

# %%
## Create the Dataframe and list the column names

df = pd.read_csv('../Resources/CountyHealthData.csv')
list(df.columns)
# Out:
# ['Year',
#  'StateAbbr',
#  'StateDesc',
#  'LocationName',
#  'DataSource',
#  'Category',
#  'Measure',
#  'Data_Value_Unit',
#  'Data_Value_Type',
#  'Data_Value',
#  'Data_Value_Footnote_Symbol',
#  'Data_Value_Footnote',
#  'Low_Confidence_Limit',
#  'High_Confidence_Limit',
#  'TotalPopulation',
#  'LocationID',
#  'CategoryID',
#  'MeasureId',
#  'DataValueTypeID',
#  'Short_Question_Text',
#  'Geolocation',
#  'States',
#  'Counties']

# %%
list(df['Short_Question_Text'].unique())
# Out:
# ['High Blood Pressure',
#  'Physical Inactivity',
#  'Binge Drinking',
#  'Arthritis',
#  'Annual Checkup',
#  'Chronic Kidney Disease',
#  'Cancer (except skin)',
#  'Mental Health',
#  'Cholesterol Screening',
#  'Cervical Cancer Screening',
#  'General Health',
#  'Core preventive services for older men',
#  'Stroke',
#  'COPD',
#  'Taking BP Medication',
#  'Current Smoking',
#  'Physical Health',
#  'Dental Visit',
#  'Sleep <7 hours',
#  'Current Asthma',
#  'Obesity',
#  'Depression',
#  'Colorectal Cancer Screening',
#  'Diabetes',
#  'All Teeth Lost',
#  'Mammography',
#  'Core preventive services for older women',
#  'Health Insurance',
#  'Coronary Heart Disease',
#  'High Cholesterol']

# %%
new_df = df.loc[df['Short_Question_Text'].isin(
                        ['High Blood Pressure', 
                         'Physical Inactivity'
                         'Binge Drinking',
                         'Mental Health',
                         'Current Smoking',
                         'Sleep <7 hours',
                         'Obesity',
                         
                         'High Cholesterol',
                         'Depression'])]

new_df = new_df.loc[new_df['Year'] == 2019]
new_df
# Out:
#         Year StateAbbr StateDesc LocationName DataSource         Category  \
# 0       2019        WY   Wyoming        Crook      BRFSS  Health Outcomes
# 24      2019        WY   Wyoming       Carbon      BRFSS  Health Outcomes
# 28      2019        WY   Wyoming       Platte      BRFSS  Health Outcomes
# 76      2019        WY   Wyoming     Niobrara      BRFSS  Health Outcomes
# 78      2019        WY   Wyoming       Weston      BRFSS  Health Outcomes
# ...      ...       ...       ...          ...        ...              ...
# 188352  2019        AL   Alabama       Monroe      BRFSS  Health Outcomes
# 188356  2019        AL   Alabama      Russell      BRFSS  Health Outcomes
# 188359  2019        AL   Alabama       Mobile      BRFSS  Health Outcomes
# 188382  2019        AL   Alabama         Bibb      BRFSS  Health Outcomes
# 188393  2019        AL   Alabama   Lauderdale      BRFSS  Health Outcomes
#
#                                                   Measure Data_Value_Unit  \
# 0        High blood pressure among adults aged >=18 years               %
# 24       High blood pressure among adults aged >=18 years               %
# 28       High blood pressure among adults aged >=18 years               %
# 76      High cholesterol among adults aged >=18 years ...               %
# 78      High cholesterol among adults aged >=18 years ...               %
# ...                                                   ...             ...
# 188352  High cholesterol among adults aged >=18 years ...               %
# 188356  High cholesterol among adults aged >=18 years ...               %
# 188359   High blood pressure among adults aged >=18 years               %
# 188382   High blood pressure among adults aged >=18 years               %
# 188393  High cholesterol among adults aged >=18 years ...               %
#
#                 Data_Value_Type  Data_Value  ...  High_Confidence_Limit  \
# 0       Age-adjusted prevalence        27.0  ...                   28.2
# 24      Age-adjusted prevalence        29.6  ...                   30.6
# 28             Crude prevalence        36.4  ...                   37.7
# 76             Crude prevalence        31.0  ...                   32.3
# 78      Age-adjusted prevalence        25.7  ...                   26.6
# ...                         ...         ...  ...                    ...
# 188352         Crude prevalence        38.8  ...                   39.7
# 188356         Crude prevalence        34.7  ...                   35.5
# 188359  Age-adjusted prevalence        39.5  ...                   40.5
# 188382  Age-adjusted prevalence        41.3  ...                   42.4
# 188393         Crude prevalence        35.4  ...                   36.4
#
#         TotalPopulation  LocationID  CategoryID  MeasureId  DataValueTypeID  \
# 0                  7593       56011     HLTHOUT     BPHIGH        AgeAdjPrv
# 24                14711       56007     HLTHOUT     BPHIGH        AgeAdjPrv
# 28                 8578       56031     HLTHOUT     BPHIGH           CrdPrv
# 76                 2275       56027     HLTHOUT   HIGHCHOL           CrdPrv
# 78                 6743       56045     HLTHOUT   HIGHCHOL        AgeAdjPrv
# ...                 ...         ...         ...        ...              ...
# 188352            20459        1099     HLTHOUT   HIGHCHOL           CrdPrv
# 188356            58237        1113     HLTHOUT   HIGHCHOL           CrdPrv
# 188359           412716        1097     HLTHOUT     BPHIGH        AgeAdjPrv
# 188382            22136        1007     HLTHOUT     BPHIGH        AgeAdjPrv
# 188393            93368        1077     HLTHOUT   HIGHCHOL           CrdPrv
#
#         Short_Question_Text                      Geolocation States Counties
# 0       High Blood Pressure  POINT (-104.5672975 44.5892657)   14.0   3083.0
# 24      High Blood Pressure  POINT (-106.9331526 41.7035904)   14.0   3081.0
# 28      High Blood Pressure  POINT (-104.9539626 42.1315927)   14.0    892.0
# 76         High Cholesterol   POINT (-104.4683727 43.062159)   14.0   3121.0
# 78         High Cholesterol  POINT (-104.5700202 43.8462133)   14.0    894.0
# ...                     ...                              ...    ...      ...
# 188352     High Cholesterol   POINT (-87.3832656 31.5803324)   29.0   1592.0
# 188356     High Cholesterol   POINT (-85.1869798 32.2898113)   29.0   1634.0
# 188359  High Blood Pressure   POINT (-88.1965682 30.6845725)   29.0   1591.0
# 188382  High Blood Pressure   POINT (-87.1271475 33.0158929)   29.0     92.0
# 188393     High Cholesterol   POINT (-87.6509966 34.9041221)   29.0   1584.0
#
# [12484 rows x 23 columns]

# %%
## Clean the DataFrame and only show the columns we need

new_df = new_df[['Year',
 'StateAbbr',
 'LocationName',
 'Data_Value_Type',
 'Data_Value',
 'TotalPopulation',
 'CategoryID',
 'MeasureId',
 'DataValueTypeID',
 'Short_Question_Text',
 'Geolocation']]
new_df.dropna()
# Out:
#         Year StateAbbr LocationName          Data_Value_Type  Data_Value  \
# 0       2019        WY        Crook  Age-adjusted prevalence        27.0
# 24      2019        WY       Carbon  Age-adjusted prevalence        29.6
# 28      2019        WY       Platte         Crude prevalence        36.4
# 76      2019        WY     Niobrara         Crude prevalence        31.0
# 78      2019        WY       Weston  Age-adjusted prevalence        25.7
# ...      ...       ...          ...                      ...         ...
# 188352  2019        AL       Monroe         Crude prevalence        38.8
# 188356  2019        AL      Russell         Crude prevalence        34.7
# 188359  2019        AL       Mobile  Age-adjusted prevalence        39.5
# 188382  2019        AL         Bibb  Age-adjusted prevalence        41.3
# 188393  2019        AL   Lauderdale         Crude prevalence        35.4
#
#         TotalPopulation CategoryID MeasureId DataValueTypeID  \
# 0                  7593    HLTHOUT    BPHIGH       AgeAdjPrv
# 24                14711    HLTHOUT    BPHIGH       AgeAdjPrv
# 28                 8578    HLTHOUT    BPHIGH          CrdPrv
# 76                 2275    HLTHOUT  HIGHCHOL          CrdPrv
# 78                 6743    HLTHOUT  HIGHCHOL       AgeAdjPrv
# ...                 ...        ...       ...             ...
# 188352            20459    HLTHOUT  HIGHCHOL          CrdPrv
# 188356            58237    HLTHOUT  HIGHCHOL          CrdPrv
# 188359           412716    HLTHOUT    BPHIGH       AgeAdjPrv
# 188382            22136    HLTHOUT    BPHIGH       AgeAdjPrv
# 188393            93368    HLTHOUT  HIGHCHOL          CrdPrv
#
#         Short_Question_Text                      Geolocation
# 0       High Blood Pressure  POINT (-104.5672975 44.5892657)
# 24      High Blood Pressure  POINT (-106.9331526 41.7035904)
# 28      High Blood Pressure  POINT (-104.9539626 42.1315927)
# 76         High Cholesterol   POINT (-104.4683727 43.062159)
# 78         High Cholesterol  POINT (-104.5700202 43.8462133)
# ...                     ...                              ...
# 188352     High Cholesterol   POINT (-87.3832656 31.5803324)
# 188356     High Cholesterol   POINT (-85.1869798 32.2898113)
# 188359  High Blood Pressure   POINT (-88.1965682 30.6845725)
# 188382  High Blood Pressure   POINT (-87.1271475 33.0158929)
# 188393     High Cholesterol   POINT (-87.6509966 34.9041221)
#
# [12480 rows x 11 columns]

# %%
list(new_df['Short_Question_Text'].unique())
# Out:
# ['High Blood Pressure', 'High Cholesterol']

# %%
## Fix the format of the Geolocation column

## Create an empty list
lats = []
lons = []

## Iterate through the rows
for i in new_df['Geolocation']:
    ## Set each item to a string
    s = str(i)
    # get lon-lat from "POINT (lon lat)"
    loc = s[7:-1]
    ## Turn the returned string into a list
    l = loc.split(' ')
    ## Reverse the list
    
    try:
        lats.append(l[1])
        
    except:
        lats.append('')
        
    try:
        lons.append(l[0])
        
    except:
        lats.append('')
           
        
        
        
    ## Use a list comprehension to turn the string values in the list back in to floats
new_df['Lat'] = lats
new_df['Lon'] = lons
# Out:
# C:\Users\Cody\AppData\Local\Temp\ipykernel_29424\3299178455.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Lat'] = lats
# C:\Users\Cody\AppData\Local\Temp\ipykernel_29424\3299178455.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Lon'] = lons

# %%
gs_df = pd.read_excel('../Resources/US-data-only-green-area-per_capita-square-meters-per-capita.xlsx')
gs_df = gs_df[['city', 'state', 'county','average_greenspace']]
gs_df
# Out:
#               city state        county  average_greenspace
# 0     Philadelphia    PA  Philadelphia         1516.564566
# 1           Denver    CO        Denver           12.665109
# 2         Portland    OR    Multnomah           964.247742
# 3        Baltimore    MD     Baltimore         1939.655916
# 4       Cincinnati    OH     Hamilton          6291.645367
# ..             ...   ...           ...                 ...
# 61      Des Moines    IA          Polk         3023.467223
# 62           Omaha    NE      Douglas           638.824150
# 63           Akron    OH       Summit           696.782397
# 64  Salt Lake City    UT     Salt Lake          630.237928
# 65      Pittsburgh    PA     Allegheny          754.310435
#
# [66 rows x 4 columns]

# %%
gs_df['county'] = gs_df['county'].str.strip()
gs_df['city'] = gs_df['city'].str.strip()
gs_df['state'] = gs_df['state'].str.strip()

# %%
## Show the DataFrame again with the new location values
final_df = new_df.drop(columns = ['CategoryID', 'MeasureId', 'Geolocation'])
final_df
# Out:
#         Year StateAbbr LocationName          Data_Value_Type  Data_Value  \
# 0       2019        WY        Crook  Age-adjusted prevalence        27.0
# 24      2019        WY       Carbon  Age-adjusted prevalence        29.6
# 28      2019        WY       Platte         Crude prevalence        36.4
# 76      2019        WY     Niobrara         Crude prevalence        31.0
# 78      2019        WY       Weston  Age-adjusted prevalence        25.7
# ...      ...       ...          ...                      ...         ...
# 188352  2019        AL       Monroe         Crude prevalence        38.8
# 188356  2019        AL      Russell         Crude prevalence        34.7
# 188359  2019        AL       Mobile  Age-adjusted prevalence        39.5
# 188382  2019        AL         Bibb  Age-adjusted prevalence        41.3
# 188393  2019        AL   Lauderdale         Crude prevalence        35.4
#
#         TotalPopulation DataValueTypeID  Short_Question_Text         Lat  \
# 0                  7593       AgeAdjPrv  High Blood Pressure  44.5892657
# 24                14711       AgeAdjPrv  High Blood Pressure  41.7035904
# 28                 8578          CrdPrv  High Blood Pressure  42.1315927
# 76                 2275          CrdPrv     High Cholesterol   43.062159
# 78                 6743       AgeAdjPrv     High Cholesterol  43.8462133
# ...                 ...             ...                  ...         ...
# 188352            20459          CrdPrv     High Cholesterol  31.5803324
# 188356            58237          CrdPrv     High Cholesterol  32.2898113
# 188359           412716       AgeAdjPrv  High Blood Pressure  30.6845725
# 188382            22136       AgeAdjPrv  High Blood Pressure  33.0158929
# 188393            93368          CrdPrv     High Cholesterol  34.9041221
#
#                  Lon
# 0       -104.5672975
# 24      -106.9331526
# 28      -104.9539626
# 76      -104.4683727
# 78      -104.5700202
# ...              ...
# 188352   -87.3832656
# 188356   -85.1869798
# 188359   -88.1965682
# 188382   -87.1271475
# 188393   -87.6509966
#
# [12484 rows x 10 columns]

# %%
## Changing column types
final_df['Lat'] = pd.to_numeric(final_df['Lat'])
final_df['Lon'] = pd.to_numeric(final_df['Lon'])

# %%
final_df['LocationName'] = final_df['LocationName'].str.strip()
final_df['StateAbbr'] = final_df['StateAbbr'].str.strip()
test4 = final_df.loc[final_df['LocationName'] == 'Jefferson']
test4
# Out:
#         Year StateAbbr LocationName          Data_Value_Type  Data_Value  \
# 3206    2019        WI    Jefferson  Age-adjusted prevalence        27.9
# 3928    2019        WI    Jefferson         Crude prevalence        30.2
# 5025    2019        WI    Jefferson         Crude prevalence        33.3
# 5110    2019        WI    Jefferson  Age-adjusted prevalence        26.9
# 6614    2019        WV    Jefferson         Crude prevalence        37.4
# ...      ...       ...          ...                      ...         ...
# 181715  2019        AR    Jefferson  Age-adjusted prevalence        44.1
# 185293  2019        AL    Jefferson         Crude prevalence        40.1
# 185797  2019        AL    Jefferson  Age-adjusted prevalence        28.6
# 186251  2019        AL    Jefferson         Crude prevalence        31.9
# 188118  2019        AL    Jefferson  Age-adjusted prevalence        37.7
#
#         TotalPopulation DataValueTypeID  Short_Question_Text        Lat  \
# 3206              85038       AgeAdjPrv     High Cholesterol  43.013804
# 3928              85038          CrdPrv  High Blood Pressure  43.013804
# 5025              85038          CrdPrv     High Cholesterol  43.013804
# 5110              85038       AgeAdjPrv  High Blood Pressure  43.013804
# 6614              57486          CrdPrv  High Blood Pressure  39.307398
# ...                 ...             ...                  ...        ...
# 181715            65377       AgeAdjPrv  High Blood Pressure  34.277239
# 185293           655342          CrdPrv  High Blood Pressure  33.553444
# 185797           655342       AgeAdjPrv     High Cholesterol  33.553444
# 186251           655342          CrdPrv     High Cholesterol  33.553444
# 188118           655342       AgeAdjPrv  High Blood Pressure  33.553444
#
#               Lon
# 3206   -88.773985
# 3928   -88.773985
# 5025   -88.773985
# 5110   -88.773985
# 6614   -77.863220
# ...           ...
# 181715 -91.929673
# 185293 -86.896536
# 185797 -86.896536
# 186251 -86.896536
# 188118 -86.896536
#
# [104 rows x 10 columns]

# %%
final_df = pd.merge(final_df, gs_df, how='inner', left_on=['LocationName', 'StateAbbr'], right_on=['county', 'state'])
final_df
# Out:
#      Year StateAbbr LocationName          Data_Value_Type  Data_Value  \
# 0    2019        WI    Milwaukee  Age-adjusted prevalence        31.4
# 1    2019        WI    Milwaukee         Crude prevalence        31.5
# 2    2019        WI    Milwaukee  Age-adjusted prevalence        29.9
# 3    2019        WI    Milwaukee         Crude prevalence        32.3
# 4    2019        WI         Dane         Crude prevalence        26.2
# ..    ...       ...          ...                      ...         ...
# 259  2019        AZ     Maricopa  Age-adjusted prevalence        29.3
# 260  2019        AL    Jefferson         Crude prevalence        40.1
# 261  2019        AL    Jefferson  Age-adjusted prevalence        28.6
# 262  2019        AL    Jefferson         Crude prevalence        31.9
# 263  2019        AL    Jefferson  Age-adjusted prevalence        37.7
#
#      TotalPopulation DataValueTypeID  Short_Question_Text        Lat  \
# 0             945016       AgeAdjPrv  High Blood Pressure  42.912643
# 1             945016          CrdPrv  High Blood Pressure  42.912643
# 2             945016       AgeAdjPrv     High Cholesterol  42.912643
# 3             945016          CrdPrv     High Cholesterol  42.912643
# 4             552536          CrdPrv  High Blood Pressure  43.067468
# ..               ...             ...                  ...        ...
# 259          4579081       AgeAdjPrv  High Blood Pressure  33.345176
# 260           655342          CrdPrv  High Blood Pressure  33.553444
# 261           655342       AgeAdjPrv     High Cholesterol  33.553444
# 262           655342          CrdPrv     High Cholesterol  33.553444
# 263           655342       AgeAdjPrv  High Blood Pressure  33.553444
#
#             Lon        city state     county  average_greenspace
# 0    -87.862312   Milwaukee    WI  Milwaukee         2475.873538
# 1    -87.862312   Milwaukee    WI  Milwaukee         2475.873538
# 2    -87.862312   Milwaukee    WI  Milwaukee         2475.873538
# 3    -87.862312   Milwaukee    WI  Milwaukee         2475.873538
# 4    -89.417852     Madison    WI       Dane         2698.259680
# ..          ...         ...   ...        ...                 ...
# 259 -112.498930     Phoenix    AZ   Maricopa           38.427155
# 260  -86.896536  Birmingham    AL  Jefferson         1088.105755
# 261  -86.896536  Birmingham    AL  Jefferson         1088.105755
# 262  -86.896536  Birmingham    AL  Jefferson         1088.105755
# 263  -86.896536  Birmingham    AL  Jefferson         1088.105755
#
# [264 rows x 14 columns]

# %%
final_df.replace("Miami-Dade", "Miami Dade", inplace=True)
test4 = final_df.loc[final_df['county'] == 'Miami Dade']
test4
# Out:
#      Year StateAbbr LocationName          Data_Value_Type  Data_Value  \
# 204  2019        FL   Miami Dade         Crude prevalence        31.3
# 205  2019        FL   Miami Dade  Age-adjusted prevalence        28.9
# 206  2019        FL   Miami Dade         Crude prevalence        31.9
# 207  2019        FL   Miami Dade  Age-adjusted prevalence        27.2
#
#      TotalPopulation DataValueTypeID  Short_Question_Text        Lat  \
# 204          2707303          CrdPrv     High Cholesterol  25.616008
# 205          2707303       AgeAdjPrv  High Blood Pressure  25.616008
# 206          2707303          CrdPrv  High Blood Pressure  25.616008
# 207          2707303       AgeAdjPrv     High Cholesterol  25.616008
#
#            Lon   city state      county  average_greenspace
# 204 -80.503749  Miami    FL  Miami Dade          818.067688
# 205 -80.503749  Miami    FL  Miami Dade          818.067688
# 206 -80.503749  Miami    FL  Miami Dade          818.067688
# 207 -80.503749  Miami    FL  Miami Dade          818.067688

# %%
## Export it to a file

df.to_csv('../Resources/CleanedHealthCountyData.csv')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264 entries, 0 to 263
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 264 non-null    int64
#  1   StateAbbr            264 non-null    object
#  2   LocationName         264 non-null    object
#  3   Data_Value_Type      264 non-null    object
#  4   Data_Value           264 non-null    float64
#  5   TotalPopulation      264 non-null    int64
#  6   DataValueTypeID      264 non-null    object
#  7   Short_Question_Text  264 non-null    object
#  8   Lat                  264 non-null    float64
#  9   Lon                  264 non-null    float64
#  10  city                 264 non-null    object
#  11  state                264 non-null    object
#  12  county               264 non-null    object
#  13  average_greenspace   264 non-null    float64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 30.9+ KB

# %%
group = final_df.groupby(['LocationName', 'StateAbbr'])

data_list = []
for row in group:
    empty_dict = {

    }
    county = row[0][0]
    empty_dict['county'] = county
        
    state = row[0][1]
    empty_dict['state'] = state
        
    data = row[1]
    parameters = [x for x in data['Short_Question_Text']]
    data_types = [x for x in data['DataValueTypeID']]
    
    data_values = [x for x in data['Data_Value']]
    
    population = data['TotalPopulation'].head(1)
    empty_dict['population'] = int(population.values[0])
    
    city = data['city'].head(1).values[0]
    empty_dict['city'] = city
    
    gpc = data['average_greenspace'].head(1).values[0]
    empty_dict['greenspace_per_capita'] = round(gpc,2)
    
    
    lat = data['Lat'].head(1)
    
    lon = data['Lon'].head(1)
    empty_dict['location'] = [float(lat.values[0]),float(lon.values[0])]

    ##print(county, state, parameters, data_types, measurements, population, lat, lon)
    measurements = {}
    for i in range(4):
        m = parameters[i].replace(' ','')
        dt = data_types[i]
        m=m+dt
        measurements[m] = data_values[i]
        empty_dict['measurements'] = measurements

    data_list.append(empty_dict)
data_list
# Out:
# [{'county': 'Albany',
#   'state': 'NY',
#   'population': 303654,
#   'city': 'Albany',
#   'greenspace_per_capita': 1601.78,
#   'location': [42.5882401, -73.9740095],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 26.1,
#    'HighBloodPressureCrdPrv': 27.3,
#    'HighCholesterolAgeAdjPrv': 28.4,
#    'HighCholesterolCrdPrv': 30.9}},
#  {'county': 'Allegheny',
#   'state': 'PA',
#   'population': 1211358,
#   'city': 'Pittsburgh',
#   'greenspace_per_capita': 754.31,
#   'location': [40.4697574, -79.9804515],
#   'measurements': {'HighCholesterolCrdPrv': 30.6,
#    'HighCholesterolAgeAdjPrv': 26.3,
#    'HighBloodPressureAgeAdjPrv': 28.5,
#    'HighBloodPressureCrdPrv': 31.9}},
#  {'county': 'Baltimore',
#   'state': 'MD',
#   'population': 826017,
#   'city': 'Baltimore',
#   'greenspace_per_capita': 1939.66,
#   'location': [39.4431666, -76.6165693],
#   'measurements': {'HighCholesterolCrdPrv': 33.1,
#    'HighBloodPressureCrdPrv': 35.5,
#    'HighCholesterolAgeAdjPrv': 29.2,
#    'HighBloodPressureAgeAdjPrv': 32.4}},
#  {'county': 'Bernalillo',
#   'state': 'NM',
#   'population': 681666,
#   'city': 'Albuquerque',
#   'greenspace_per_capita': 60.75,
#   'location': [35.053628, -106.6690805],
#   'measurements': {'HighCholesterolCrdPrv': 28.6,
#    'HighBloodPressureCrdPrv': 26.9,
#    'HighBloodPressureAgeAdjPrv': 25.5,
#    'HighCholesterolAgeAdjPrv': 25.5}},
#  {'county': 'Bexar',
#   'state': 'TX',
#   'population': 2026823,
#   'city': 'San Antonio',
#   'greenspace_per_capita': 294.73,
#   'location': [29.4486708, -98.5201465],
#   'measurements': {'HighBloodPressureCrdPrv': 32.5,
#    'HighCholesterolAgeAdjPrv': 31.1,
#    'HighCholesterolCrdPrv': 32.2,
#    'HighBloodPressureAgeAdjPrv': 33.6}},
#  {'county': 'Charleston',
#   'state': 'SC',
#   'population': 417981,
#   'city': 'Charleston',
#   'greenspace_per_capita': 302.88,
#   'location': [32.8004582, -79.94248],
#   'measurements': {'HighCholesterolCrdPrv': 34.1,
#    'HighCholesterolAgeAdjPrv': 30.5,
#    'HighBloodPressureCrdPrv': 33.8,
#    'HighBloodPressureAgeAdjPrv': 31.9}},
#  {'county': 'Clark',
#   'state': 'NV',
#   'population': 2315963,
#   'city': 'Las Vegas',
#   'greenspace_per_capita': 3.22,
#   'location': [36.2141295, -115.0143977],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 29.6,
#    'HighBloodPressureCrdPrv': 30.2,
#    'HighCholesterolAgeAdjPrv': 29.3,
#    'HighCholesterolCrdPrv': 31.8}},
#  {'county': 'Cook',
#   'state': 'IL',
#   'population': 5108284,
#   'city': 'Chicago',
#   'greenspace_per_capita': 3970.97,
#   'location': [41.8942937, -87.6454546],
#   'measurements': {'HighCholesterolAgeAdjPrv': 27.2,
#    'HighBloodPressureCrdPrv': 29.8,
#    'HighBloodPressureAgeAdjPrv': 29.2,
#    'HighCholesterolCrdPrv': 29.3}},
#  {'county': 'Cuyahoga',
#   'state': 'OH',
#   'population': 1227883,
#   'city': 'Cleveland',
#   'greenspace_per_capita': 767.4,
#   'location': [41.555037, -81.6049566],
#   'measurements': {'HighCholesterolAgeAdjPrv': 27.5,
#    'HighBloodPressureCrdPrv': 35.4,
#    'HighCholesterolCrdPrv': 32.2,
#    'HighBloodPressureAgeAdjPrv': 31.9}},
#  {'county': 'Dallas',
#   'state': 'TX',
#   'population': 2635888,
#   'city': 'Dallas',
#   'greenspace_per_capita': 895.34,
#   'location': [32.7669866, -96.7784238],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 32.0,
#    'HighCholesterolCrdPrv': 30.8,
#    'HighCholesterolAgeAdjPrv': 30.3,
#    'HighBloodPressureCrdPrv': 30.1}},
#  {'county': 'Dane',
#   'state': 'WI',
#   'population': 552536,
#   'city': 'Madison',
#   'greenspace_per_capita': 2698.26,
#   'location': [43.0674684, -89.4178523],
#   'measurements': {'HighBloodPressureCrdPrv': 26.2,
#    'HighCholesterolAgeAdjPrv': 29.0,
#    'HighCholesterolCrdPrv': 30.7,
#    'HighBloodPressureAgeAdjPrv': 26.8}},
#  {'county': 'Dauphin',
#   'state': 'PA',
#   'population': 279874,
#   'city': 'Harrisburg',
#   'greenspace_per_capita': 2185.01,
#   'location': [40.4125646, -76.7926343],
#   'measurements': {'HighBloodPressureCrdPrv': 32.7,
#    'HighCholesterolAgeAdjPrv': 28.8,
#    'HighCholesterolCrdPrv': 33.1,
#    'HighBloodPressureAgeAdjPrv': 29.8}},
#  {'county': 'Davidson',
#   'state': 'TN',
#   'population': 694176,
#   'city': 'Nashville',
#   'greenspace_per_capita': 5360.46,
#   'location': [36.1691287, -86.7847898],
#   'measurements': {'HighBloodPressureCrdPrv': 32.7,
#    'HighCholesterolCrdPrv': 30.3,
#    'HighCholesterolAgeAdjPrv': 30.1,
#    'HighBloodPressureAgeAdjPrv': 34.3}},
#  {'county': 'Denver',
#   'state': 'CO',
#   'population': 735538,
#   'city': 'Denver',
#   'greenspace_per_capita': 12.67,
#   'location': [39.7618502, -104.8811054],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 24.3,
#    'HighCholesterolAgeAdjPrv': 26.2,
#    'HighBloodPressureCrdPrv': 22.2,
#    'HighCholesterolCrdPrv': 25.8}},
#  {'county': 'Douglas',
#   'state': 'NE',
#   'population': 574332,
#   'city': 'Omaha',
#   'greenspace_per_capita': 638.82,
#   'location': [41.2970908, -96.1540664],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 28.9,
#    'HighCholesterolCrdPrv': 29.5,
#    'HighCholesterolAgeAdjPrv': 27.4,
#    'HighBloodPressureCrdPrv': 28.9}},
#  {'county': 'Duval',
#   'state': 'FL',
#   'population': 966728,
#   'city': 'Jacksonville',
#   'greenspace_per_capita': 217.45,
#   'location': [30.3352449, -81.6481132],
#   'measurements': {'HighCholesterolAgeAdjPrv': 28.8,
#    'HighBloodPressureAgeAdjPrv': 33.6,
#    'HighBloodPressureCrdPrv': 34.5,
#    'HighCholesterolCrdPrv': 31.3}},
#  {'county': 'East Baton Rouge',
#   'state': 'LA',
#   'population': 439729,
#   'city': 'Baton Rouge',
#   'greenspace_per_capita': 542.66,
#   'location': [30.5439297, -91.093131],
#   'measurements': {'HighBloodPressureCrdPrv': 38.5,
#    'HighCholesterolCrdPrv': 31.8,
#    'HighCholesterolAgeAdjPrv': 30.2,
#    'HighBloodPressureAgeAdjPrv': 38.8}},
#  {'county': 'El Paso',
#   'state': 'CO',
#   'population': 728310,
#   'city': 'Colorado Springs',
#   'greenspace_per_capita': 10.3,
#   'location': [38.8273831, -104.5274718],
#   'measurements': {'HighBloodPressureCrdPrv': 26.7,
#    'HighBloodPressureAgeAdjPrv': 27.3,
#    'HighCholesterolCrdPrv': 30.0,
#    'HighCholesterolAgeAdjPrv': 28.7}},
#  {'county': 'El Paso',
#   'state': 'TX',
#   'population': 841286,
#   'city': 'El Paso',
#   'greenspace_per_capita': 3.01,
#   'location': [31.7664803, -106.2414234],
#   'measurements': {'HighCholesterolCrdPrv': 31.6,
#    'HighBloodPressureCrdPrv': 31.4,
#    'HighBloodPressureAgeAdjPrv': 31.9,
#    'HighCholesterolAgeAdjPrv': 29.8}},
#  {'county': 'Erie',
#   'state': 'NY',
#   'population': 917241,
#   'city': 'Buffalo',
#   'greenspace_per_capita': 2640.95,
#   'location': [42.752759, -78.7781922],
#   'measurements': {'HighCholesterolCrdPrv': 32.8,
#    'HighBloodPressureCrdPrv': 32.4,
#    'HighBloodPressureAgeAdjPrv': 29.1,
#    'HighCholesterolAgeAdjPrv': 28.5}},
#  {'county': 'Fresno',
#   'state': 'CA',
#   'population': 1000918,
#   'city': 'Fresno',
#   'greenspace_per_capita': 87.58,
#   'location': [36.7610058, -119.6550193],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 29.7,
#    'HighBloodPressureCrdPrv': 28.5,
#    'HighCholesterolAgeAdjPrv': 28.0,
#    'HighCholesterolCrdPrv': 29.0}},
#  {'county': 'Fulton',
#   'state': 'GA',
#   'population': 1077402,
#   'city': 'Atlanta',
#   'greenspace_per_capita': 466.88,
#   'location': [33.7900338, -84.4681816],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 32.0,
#    'HighCholesterolCrdPrv': 29.1,
#    'HighCholesterolAgeAdjPrv': 28.4,
#    'HighBloodPressureCrdPrv': 31.1}},
#  {'county': 'Hamilton',
#   'state': 'OH',
#   'population': 817985,
#   'city': 'Cincinnati',
#   'greenspace_per_capita': 6291.65,
#   'location': [39.1969272, -84.5441868],
#   'measurements': {'HighCholesterolCrdPrv': 29.1,
#    'HighCholesterolAgeAdjPrv': 25.9,
#    'HighBloodPressureCrdPrv': 34.0,
#    'HighBloodPressureAgeAdjPrv': 32.1}},
#  {'county': 'Harris',
#   'state': 'TX',
#   'population': 4738253,
#   'city': 'Houston',
#   'greenspace_per_capita': 3856.77,
#   'location': [29.857273, -95.3930371],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 32.5,
#    'HighCholesterolCrdPrv': 34.1,
#    'HighCholesterolAgeAdjPrv': 33.6,
#    'HighBloodPressureCrdPrv': 30.7}},
#  {'county': 'Hennepin',
#   'state': 'MN',
#   'population': 1268408,
#   'city': 'Minneapolis',
#   'greenspace_per_capita': 9833.09,
#   'location': [45.0061209, -93.4752279],
#   'measurements': {'HighCholesterolAgeAdjPrv': 25.3,
#    'HighCholesterolCrdPrv': 27.5,
#    'HighBloodPressureCrdPrv': 25.6,
#    'HighBloodPressureAgeAdjPrv': 25.0}},
#  {'county': 'Henrico',
#   'state': 'VA',
#   'population': 333766,
#   'city': 'Richmond',
#   'greenspace_per_capita': 107.33,
#   'location': [37.4375205, -77.300333],
#   'measurements': {'HighBloodPressureCrdPrv': 34.9,
#    'HighBloodPressureAgeAdjPrv': 32.5,
#    'HighCholesterolCrdPrv': 31.3,
#    'HighCholesterolAgeAdjPrv': 27.9}},
#  {'county': 'Hidalgo',
#   'state': 'TX',
#   'population': 875200,
#   'city': 'Mcallen',
#   'greenspace_per_capita': 108.4,
#   'location': [26.3963839, -98.18099],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.9,
#    'HighBloodPressureCrdPrv': 33.5,
#    'HighCholesterolCrdPrv': 32.0,
#    'HighBloodPressureAgeAdjPrv': 35.2}},
#  {'county': 'Hillsborough',
#   'state': 'FL',
#   'population': 1497957,
#   'city': 'Tampa',
#   'greenspace_per_capita': 567.77,
#   'location': [27.8876095, -82.3744173],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 30.2,
#    'HighCholesterolCrdPrv': 30.4,
#    'HighCholesterolAgeAdjPrv': 28.1,
#    'HighBloodPressureCrdPrv': 30.9}},
#  {'county': 'Jackson',
#   'state': 'MO',
#   'population': 705925,
#   'city': 'Kansas City',
#   'greenspace_per_capita': 8672.43,
#   'location': [39.005364, -94.3432105],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.6,
#    'HighCholesterolCrdPrv': 33.0,
#    'HighBloodPressureAgeAdjPrv': 29.5,
#    'HighBloodPressureCrdPrv': 31.1}},
#  {'county': 'Jefferson',
#   'state': 'AL',
#   'population': 655342,
#   'city': 'Birmingham',
#   'greenspace_per_capita': 1088.11,
#   'location': [33.5534439, -86.8965359],
#   'measurements': {'HighBloodPressureCrdPrv': 40.1,
#    'HighCholesterolAgeAdjPrv': 28.6,
#    'HighCholesterolCrdPrv': 31.9,
#    'HighBloodPressureAgeAdjPrv': 37.7}},
#  {'county': 'Jefferson',
#   'state': 'KY',
#   'population': 767452,
#   'city': 'Louisville',
#   'greenspace_per_capita': 5172.63,
#   'location': [38.1895321, -85.6576243],
#   'measurements': {'HighBloodPressureCrdPrv': 39.9,
#    'HighCholesterolAgeAdjPrv': 31.9,
#    'HighCholesterolCrdPrv': 35.3,
#    'HighBloodPressureAgeAdjPrv': 37.4}},
#  {'county': 'Kent',
#   'state': 'MI',
#   'population': 658708,
#   'city': 'Grand Rapids',
#   'greenspace_per_capita': 1688.72,
#   'location': [43.0324971, -85.547446],
#   'measurements': {'HighCholesterolCrdPrv': 31.5,
#    'HighBloodPressureCrdPrv': 30.6,
#    'HighCholesterolAgeAdjPrv': 29.6,
#    'HighBloodPressureAgeAdjPrv': 30.1}},
#  {'county': 'King',
#   'state': 'WA',
#   'population': 2274315,
#   'city': 'Seattle',
#   'greenspace_per_capita': 275.19,
#   'location': [47.4905518, -121.8339765],
#   'measurements': {'HighBloodPressureCrdPrv': 26.0,
#    'HighBloodPressureAgeAdjPrv': 26.3,
#    'HighCholesterolCrdPrv': 29.1,
#    'HighCholesterolAgeAdjPrv': 27.5}},
#  {'county': 'Los Angeles',
#   'state': 'CA',
#   'population': 9943046,
#   'city': 'Los Angeles',
#   'greenspace_per_capita': 90.16,
#   'location': [34.1963983, -118.2618616],
#   'measurements': {'HighCholesterolCrdPrv': 28.6,
#    'HighBloodPressureCrdPrv': 26.2,
#    'HighCholesterolAgeAdjPrv': 27.1,
#    'HighBloodPressureAgeAdjPrv': 26.4}},
#  {'county': 'Lucas',
#   'state': 'OH',
#   'population': 428294,
#   'city': 'Toledo',
#   'greenspace_per_capita': 253.08,
#   'location': [41.6823213, -83.4689033],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 33.0,
#    'HighBloodPressureCrdPrv': 35.7,
#    'HighCholesterolCrdPrv': 31.2,
#    'HighCholesterolAgeAdjPrv': 27.0}},
#  {'county': 'Maricopa',
#   'state': 'AZ',
#   'population': 4579081,
#   'city': 'Phoenix',
#   'greenspace_per_capita': 38.43,
#   'location': [33.3451756, -112.4989296],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.1,
#    'HighBloodPressureCrdPrv': 29.6,
#    'HighCholesterolCrdPrv': 31.2,
#    'HighBloodPressureAgeAdjPrv': 29.3}},
#  {'county': 'Marion',
#   'state': 'IN',
#   'population': 966183,
#   'city': 'Indianapolis',
#   'greenspace_per_capita': 1712.12,
#   'location': [39.7829759, -86.1357939],
#   'measurements': {'HighBloodPressureCrdPrv': 35.0,
#    'HighCholesterolAgeAdjPrv': 29.6,
#    'HighBloodPressureAgeAdjPrv': 35.5,
#    'HighCholesterolCrdPrv': 31.1}},
#  {'county': 'Mecklenburg',
#   'state': 'NC',
#   'population': 1128945,
#   'city': 'Charlotte',
#   'greenspace_per_capita': 1020.06,
#   'location': [35.2468623, -80.8338317],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.1,
#    'HighBloodPressureCrdPrv': 29.8,
#    'HighBloodPressureAgeAdjPrv': 30.9,
#    'HighCholesterolCrdPrv': 29.7}},
#  {'county': 'Miami Dade',
#   'state': 'FL',
#   'population': 2707303,
#   'city': 'Miami',
#   'greenspace_per_capita': 818.07,
#   'location': [25.6160085, -80.5037495],
#   'measurements': {'HighCholesterolCrdPrv': 31.3,
#    'HighBloodPressureAgeAdjPrv': 28.9,
#    'HighBloodPressureCrdPrv': 31.9,
#    'HighCholesterolAgeAdjPrv': 27.2}},
#  {'county': 'Milwaukee',
#   'state': 'WI',
#   'population': 945016,
#   'city': 'Milwaukee',
#   'greenspace_per_capita': 2475.87,
#   'location': [42.9126431, -87.8623115],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 31.4,
#    'HighBloodPressureCrdPrv': 31.5,
#    'HighCholesterolAgeAdjPrv': 29.9,
#    'HighCholesterolCrdPrv': 32.3}},
#  {'county': 'Montgomery',
#   'state': 'OH',
#   'population': 531610,
#   'city': 'Dayton',
#   'greenspace_per_capita': 776.63,
#   'location': [39.7537357, -84.2905915],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 33.7,
#    'HighCholesterolCrdPrv': 33.0,
#    'HighCholesterolAgeAdjPrv': 28.2,
#    'HighBloodPressureCrdPrv': 37.2}},
#  {'county': 'Multnomah',
#   'state': 'OR',
#   'population': 815637,
#   'city': 'Portland',
#   'greenspace_per_capita': 964.25,
#   'location': [45.5477107, -122.4173625],
#   'measurements': {'HighBloodPressureCrdPrv': 26.2,
#    'HighCholesterolAgeAdjPrv': 25.9,
#    'HighBloodPressureAgeAdjPrv': 26.7,
#    'HighCholesterolCrdPrv': 27.0}},
#  {'county': 'New York',
#   'state': 'NY',
#   'population': 1611989,
#   'city': 'New York',
#   'greenspace_per_capita': 658.36,
#   'location': [40.7766419, -73.9701871],
#   'measurements': {'HighBloodPressureCrdPrv': 25.1,
#    'HighCholesterolAgeAdjPrv': 29.2,
#    'HighCholesterolCrdPrv': 30.8,
#    'HighBloodPressureAgeAdjPrv': 24.5}},
#  {'county': 'Oklahoma',
#   'state': 'OK',
#   'population': 804041,
#   'city': 'Oklahoma city',
#   'greenspace_per_capita': 164.64,
#   'location': [35.5546109, -97.4094007],
#   'measurements': {'HighBloodPressureCrdPrv': 33.5,
#    'HighCholesterolCrdPrv': 32.4,
#    'HighCholesterolAgeAdjPrv': 30.3,
#    'HighBloodPressureAgeAdjPrv': 33.4}},
#  {'county': 'Orange',
#   'state': 'FL',
#   'population': 1404396,
#   'city': 'Orlando',
#   'greenspace_per_capita': 989.79,
#   'location': [28.5143906, -81.3232839],
#   'measurements': {'HighCholesterolCrdPrv': 28.2,
#    'HighBloodPressureAgeAdjPrv': 29.9,
#    'HighBloodPressureCrdPrv': 29.0,
#    'HighCholesterolAgeAdjPrv': 27.4}},
#  {'county': 'Orleans',
#   'state': 'LA',
#   'population': 389476,
#   'city': 'New Orleans',
#   'greenspace_per_capita': 238.92,
#   'location': [30.0534195, -89.9345018],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 39.2,
#    'HighCholesterolCrdPrv': 34.2,
#    'HighCholesterolAgeAdjPrv': 31.4,
#    'HighBloodPressureCrdPrv': 40.8}},
#  {'county': 'Philadelphia',
#   'state': 'PA',
#   'population': 1578487,
#   'city': 'Philadelphia',
#   'greenspace_per_capita': 1516.56,
#   'location': [40.0093755, -75.1333459],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.5,
#    'HighCholesterolCrdPrv': 30.8,
#    'HighBloodPressureAgeAdjPrv': 33.5,
#    'HighBloodPressureCrdPrv': 32.9}},
#  {'county': 'Pima',
#   'state': 'AZ',
#   'population': 1061175,
#   'city': 'Tucson',
#   'greenspace_per_capita': 1.07,
#   'location': [32.128038, -111.7836574],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 28.0,
#    'HighCholesterolCrdPrv': 32.5,
#    'HighBloodPressureCrdPrv': 29.9,
#    'HighCholesterolAgeAdjPrv': 29.0}},
#  {'county': 'Pinellas',
#   'state': 'FL',
#   'population': 976802,
#   'city': 'Clearwater/Saint Petersburg',
#   'greenspace_per_capita': 384.67,
#   'location': [27.9053425, -82.7980663],
#   'measurements': {'HighCholesterolAgeAdjPrv': 29.0,
#    'HighBloodPressureCrdPrv': 37.4,
#    'HighBloodPressureAgeAdjPrv': 30.5,
#    'HighCholesterolCrdPrv': 36.4}},
#  {'county': 'Polk',
#   'state': 'IA',
#   'population': 494281,
#   'city': 'Des Moines',
#   'greenspace_per_capita': 3023.47,
#   'location': [41.6848158, -93.568971],
#   'measurements': {'HighBloodPressureCrdPrv': 28.6,
#    'HighBloodPressureAgeAdjPrv': 28.2,
#    'HighCholesterolCrdPrv': 31.3,
#    'HighCholesterolAgeAdjPrv': 29.1}},
#  {'county': 'Providence',
#   'state': 'RI',
#   'population': 636547,
#   'city': 'Providence',
#   'greenspace_per_capita': 103.68,
#   'location': [41.8697678, -71.5786246],
#   'measurements': {'HighBloodPressureCrdPrv': 31.0,
#    'HighCholesterolCrdPrv': 29.8,
#    'HighBloodPressureAgeAdjPrv': 30.4,
#    'HighCholesterolAgeAdjPrv': 27.9}},
#  {'county': 'Pulaski',
#   'state': 'AR',
#   'population': 392980,
#   'city': 'Little Rock',
#   'greenspace_per_capita': 1884.49,
#   'location': [34.7703106, -92.312996],
#   'measurements': {'HighCholesterolCrdPrv': 35.2,
#    'HighBloodPressureAgeAdjPrv': 37.3,
#    'HighBloodPressureCrdPrv': 39.4,
#    'HighCholesterolAgeAdjPrv': 31.4}},
#  {'county': 'Sacramento',
#   'state': 'CA',
#   'population': 1559146,
#   'city': 'Sacramento/Roseville',
#   'greenspace_per_capita': 126.22,
#   'location': [38.4501363, -121.3443291],
#   'measurements': {'HighCholesterolCrdPrv': 28.5,
#    'HighCholesterolAgeAdjPrv': 26.5,
#    'HighBloodPressureCrdPrv': 27.1,
#    'HighBloodPressureAgeAdjPrv': 26.7}},
#  {'county': 'Salt Lake',
#   'state': 'UT',
#   'population': 1165517,
#   'city': 'Salt Lake City',
#   'greenspace_per_capita': 630.24,
#   'location': [40.6678828, -111.9242397],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 27.0,
#    'HighCholesterolCrdPrv': 27.5,
#    'HighCholesterolAgeAdjPrv': 26.9,
#    'HighBloodPressureCrdPrv': 25.3}},
#  {'county': 'San Diego',
#   'state': 'CA',
#   'population': 3332427,
#   'city': 'San Diego',
#   'greenspace_per_capita': 33.27,
#   'location': [33.0236041, -116.7761174],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 27.1,
#    'HighCholesterolAgeAdjPrv': 27.3,
#    'HighCholesterolCrdPrv': 28.6,
#    'HighBloodPressureCrdPrv': 26.8}},
#  {'county': 'San Francisco',
#   'state': 'CA',
#   'population': 866606,
#   'city': 'San Francisco',
#   'greenspace_per_capita': 162.28,
#   'location': [37.7272391, -123.0322294],
#   'measurements': {'HighCholesterolCrdPrv': 28.0,
#    'HighBloodPressureAgeAdjPrv': 24.2,
#    'HighBloodPressureCrdPrv': 24.2,
#    'HighCholesterolAgeAdjPrv': 26.7}},
#  {'county': 'Sedgwick',
#   'state': 'KS',
#   'population': 519907,
#   'city': 'Wichita',
#   'greenspace_per_capita': 24.47,
#   'location': [37.681045, -97.4610535],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 32.5,
#    'HighBloodPressureCrdPrv': 33.6,
#    'HighCholesterolCrdPrv': 34.9,
#    'HighCholesterolAgeAdjPrv': 31.7}},
#  {'county': 'Shelby',
#   'state': 'TN',
#   'population': 936017,
#   'city': 'Memphis',
#   'greenspace_per_capita': 4058.98,
#   'location': [35.1845529, -89.8946125],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.6,
#    'HighBloodPressureAgeAdjPrv': 39.2,
#    'HighBloodPressureCrdPrv': 40.3,
#    'HighCholesterolCrdPrv': 33.1}},
#  {'county': 'St. Louis',
#   'state': 'MO',
#   'population': 994020,
#   'city': 'Saint Louis',
#   'greenspace_per_capita': 4764.13,
#   'location': [38.6406881, -90.4460731],
#   'measurements': {'HighCholesterolCrdPrv': 31.5,
#    'HighBloodPressureCrdPrv': 33.1,
#    'HighCholesterolAgeAdjPrv': 26.7,
#    'HighBloodPressureAgeAdjPrv': 29.3}},
#  {'county': 'Suffolk',
#   'state': 'MA',
#   'population': 801582,
#   'city': 'Boston',
#   'greenspace_per_capita': 317.05,
#   'location': [42.3385513, -71.018253],
#   'measurements': {'HighCholesterolAgeAdjPrv': 26.0,
#    'HighBloodPressureCrdPrv': 23.5,
#    'HighCholesterolCrdPrv': 24.8,
#    'HighBloodPressureAgeAdjPrv': 26.4}},
#  {'county': 'Summit',
#   'state': 'OH',
#   'population': 538866,
#   'city': 'Akron',
#   'greenspace_per_capita': 696.78,
#   'location': [41.1218471, -81.5349279],
#   'measurements': {'HighBloodPressureAgeAdjPrv': 30.7,
#    'HighCholesterolAgeAdjPrv': 25.4,
#    'HighCholesterolCrdPrv': 30.4,
#    'HighBloodPressureCrdPrv': 34.7}},
#  {'county': 'Tarrant',
#   'state': 'TX',
#   'population': 2123347,
#   'city': 'Fort Worth',
#   'greenspace_per_capita': 45.29,
#   'location': [32.7721191, -97.2912241],
#   'measurements': {'HighCholesterolCrdPrv': 34.4,
#    'HighCholesterolAgeAdjPrv': 33.2,
#    'HighBloodPressureCrdPrv': 30.3,
#    'HighBloodPressureAgeAdjPrv': 31.3}},
#  {'county': 'Travis',
#   'state': 'TX',
#   'population': 1300503,
#   'city': 'Austin',
#   'greenspace_per_capita': 276.69,
#   'location': [30.2395128, -97.6912697],
#   'measurements': {'HighCholesterolAgeAdjPrv': 30.4,
#    'HighBloodPressureCrdPrv': 23.6,
#    'HighCholesterolCrdPrv': 29.8,
#    'HighBloodPressureAgeAdjPrv': 26.3}},
#  {'county': 'Tulsa',
#   'state': 'OK',
#   'population': 657589,
#   'city': 'Tulsa',
#   'greenspace_per_capita': 2050.42,
#   'location': [36.1203177, -95.9418132],
#   'measurements': {'HighCholesterolCrdPrv': 34.0,
#    'HighBloodPressureCrdPrv': 34.8,
#    'HighBloodPressureAgeAdjPrv': 33.9,
#    'HighCholesterolAgeAdjPrv': 31.1}},
#  {'county': 'Wake',
#   'state': 'NC',
#   'population': 1132271,
#   'city': 'Raleigh',
#   'greenspace_per_capita': 1853.36,
#   'location': [35.7898464, -78.650624],
#   'measurements': {'HighCholesterolAgeAdjPrv': 28.8,
#    'HighBloodPressureAgeAdjPrv': 29.4,
#    'HighCholesterolCrdPrv': 30.2,
#    'HighBloodPressureCrdPrv': 29.2}},
#  {'county': 'Wayne',
#   'state': 'MI',
#   'population': 1740623,
#   'city': 'Detroit',
#   'greenspace_per_capita': 2097.0,
#   'location': [42.2846636, -83.2619533],
#   'measurements': {'HighCholesterolCrdPrv': 34.7,
#    'HighCholesterolAgeAdjPrv': 31.1,
#    'HighBloodPressureCrdPrv': 36.9,
#    'HighBloodPressureAgeAdjPrv': 34.5}}]

# %%
import json

with open("../Resources/data.json", "w") as outfile:
    json.dump(data_list, outfile)

# %%
plots_df = final_df.copy()
plots_df
# Out:
#      Year StateAbbr LocationName          Data_Value_Type  Data_Value  \
# 0    2019        WI    Milwaukee  Age-adjusted prevalence        31.4
# 1    2019        WI    Milwaukee         Crude prevalence        31.5
# 2    2019        WI    Milwaukee  Age-adjusted prevalence        29.9
# 3    2019        WI    Milwaukee         Crude prevalence        32.3
# 4    2019        WI         Dane         Crude prevalence        26.2
# ..    ...       ...          ...                      ...         ...
# 259  2019        AZ     Maricopa  Age-adjusted prevalence        29.3
# 260  2019        AL    Jefferson         Crude prevalence        40.1
# 261  2019        AL    Jefferson  Age-adjusted prevalence        28.6
# 262  2019        AL    Jefferson         Crude prevalence        31.9
# 263  2019        AL    Jefferson  Age-adjusted prevalence        37.7
#
#      TotalPopulation DataValueTypeID  Short_Question_Text        Lat  \
# 0             945016       AgeAdjPrv  High Blood Pressure  42.912643
# 1             945016          CrdPrv  High Blood Pressure  42.912643
# 2             945016       AgeAdjPrv     High Cholesterol  42.912643
# 3             945016          CrdPrv     High Cholesterol  42.912643
# 4             552536          CrdPrv  High Blood Pressure  43.067468
# ..               ...             ...                  ...        ...
# 259          4579081       AgeAdjPrv  High Blood Pressure  33.345176
# 260           655342          CrdPrv  High Blood Pressure  33.553444
# 261           655342       AgeAdjPrv     High Cholesterol  33.553444
# 262           655342          CrdPrv     High Cholesterol  33.553444
# 263           655342       AgeAdjPrv  High Blood Pressure  33.553444
#
#             Lon        city state     county  average_greenspace
# 0    -87.862312   Milwaukee    WI  Milwaukee         2475.873538
# 1    -87.862312   Milwaukee    WI  Milwaukee         2475.873538
# 2    -87.862312   Milwaukee    WI  Milwaukee         2475.873538
# 3    -87.862312   Milwaukee    WI  Milwaukee         2475.873538
# 4    -89.417852     Madison    WI       Dane         2698.259680
# ..          ...         ...   ...        ...                 ...
# 259 -112.498930     Phoenix    AZ   Maricopa           38.427155
# 260  -86.896536  Birmingham    AL  Jefferson         1088.105755
# 261  -86.896536  Birmingham    AL  Jefferson         1088.105755
# 262  -86.896536  Birmingham    AL  Jefferson         1088.105755
# 263  -86.896536  Birmingham    AL  Jefferson         1088.105755
#
# [264 rows x 14 columns]

# %%
plotsGPC = plots_df[['LocationName','average_greenspace']]
plotsGPCList = plotsGPC.average_greenspace.unique()

# %%
bpCrudePlot = plots_df.loc[(plots_df['Data_Value_Type'] == 'Crude prevalence') & (plots_df['Short_Question_Text'] == 'High Blood Pressure'),:]

# %%
bpAgePlot = plots_df.loc[(plots_df['Data_Value_Type'] == 'Age-adjusted prevalence') & (plots_df['Short_Question_Text'] == 'High Blood Pressure'),:]

# %%
cholesterolCrudePlot = plots_df.loc[(plots_df['Data_Value_Type'] == 'Crude prevalence') & (plots_df['Short_Question_Text'] == 'High Cholesterol'),:]

# %%
cholesterolAgePlot = plots_df.loc[(plots_df['Data_Value_Type'] == 'Age-adjusted prevalence') & (plots_df['Short_Question_Text'] == 'High Cholesterol'),:]

# %%
plt.scatter(plotsGPCList, bpCrudePlot['Data_Value'])
plt.xlabel("Average Green Space Per Capita (Sq m per million people)")
plt.ylabel("Percent Population w/ High Blood Pressure (crude)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(plotsGPCList,bpCrudePlot['Data_Value'])
regress_values = plotsGPCList * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(plotsGPCList,regress_values,"r-")
plt.annotate(line_eq,xy=(0, 1), xytext=(5, -5), va='top',
             xycoords='axes fraction', textcoords='offset points',fontsize=15,color="red")
print(f"The r-value is: {rvalue}")
plt.savefig("../Resources/bpCrude.png")
plt.show()
# Out:
# The r-value is: 0.11748078568362919

# %%
plt.scatter(plotsGPCList, bpAgePlot['Data_Value'])
plt.xlabel("Average Green Space Per Capita (Sq m per million people)")
plt.ylabel("Percent Population w/ High Blood Pressure (Age A)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(plotsGPCList,bpAgePlot['Data_Value'])
regress_values = plotsGPCList * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(plotsGPCList,regress_values,"r-")
plt.annotate(line_eq,xy=(0, 1), xytext=(5, -5), va='top',
             xycoords='axes fraction', textcoords='offset points',fontsize=15,color="red")
print(f"The r-value is: {rvalue}")
plt.savefig("../Resources/bpAge.png")
plt.show()
# Out:
# The r-value is: 0.07553644789806985

# %%
plt.scatter(plotsGPCList, cholesterolCrudePlot['Data_Value'])
plt.xlabel("Average Green Space Per Capita (Sq m per million people)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(plotsGPCList,cholesterolCrudePlot['Data_Value'])
regress_values = plotsGPCList * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(plotsGPCList,regress_values,"r-")
plt.annotate(line_eq,xy=(0, 1), xytext=(5, -5), va='top',
             xycoords='axes fraction', textcoords='offset points',fontsize=15,color="red")
print(f"The r-value is: {rvalue}")
plt.savefig("../Resources/cholesterolCrude.png")
plt.show()
# Out:
# The r-value is: 0.08655232298662026

# %%
plt.scatter(plotsGPCList, cholesterolAgePlot['Data_Value'])
plt.xlabel("Average Green Space Per Capita (Sq m per million people)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(plotsGPCList,cholesterolAgePlot['Data_Value'])
regress_values = plotsGPCList * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(plotsGPCList,regress_values,"r-")
plt.annotate(line_eq,xy=(0, 1), xytext=(5, -5), va='top',
             xycoords='axes fraction', textcoords='offset points',fontsize=15,color="red")
print(f"The r-value is: {rvalue}")
plt.savefig("../Resources/cholesterolAge.png")
plt.show()
# Out:
# The r-value is: 0.006165196794651982

# %%
group0 = bpCrudePlot['Data_Value']
group1 = bpAgePlot['Data_Value']
group2 = cholesterolCrudePlot['Data_Value']
group3 = cholesterolAgePlot['Data_Value']
stats.f_oneway(group0, group1, group2, group3)
# Out:
# F_onewayResult(statistic=8.54267034827498, pvalue=1.9747055348811156e-05)
