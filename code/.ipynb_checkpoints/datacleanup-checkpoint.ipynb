# %%
import pandas as pd
import re

# %%
df
# Out:
#         Year StateAbbr StateDesc LocationName DataSource  \
# 0       2019        WY   Wyoming        Crook      BRFSS
# 1       2020        WY   Wyoming         Park      BRFSS
# 2       2020        WY   Wyoming       Weston      BRFSS
# 3       2020        WY   Wyoming     Washakie      BRFSS
# 4       2020        WY   Wyoming      Laramie      BRFSS
# ...      ...       ...       ...          ...        ...
# 188451  2020        AL   Alabama       DeKalb      BRFSS
# 188452  2019        AL   Alabama         Dale      BRFSS
# 188453  2020        AL   Alabama         Dale      BRFSS
# 188454  2020        AL   Alabama        Coosa      BRFSS
# 188455  2020        AL   Alabama      Colbert      BRFSS
#
#                      Category  \
# 0             Health Outcomes
# 1       Health Risk Behaviors
# 2       Health Risk Behaviors
# 3             Health Outcomes
# 4                  Prevention
# ...                       ...
# 188451        Health Outcomes
# ...

# %%
df = pd.read_csv('../Resources/CountyHealthData.csv')
list(df.columns)
# Out:
# ['Year',
#  'StateAbbr',
#  'StateDesc',
#  'LocationName',
#  'DataSource',
#  'Category',
#  'Measure',
#  'Data_Value_Unit',
#  'Data_Value_Type',
#  'Data_Value',
#  'Data_Value_Footnote_Symbol',
#  'Data_Value_Footnote',
#  'Low_Confidence_Limit',
#  'High_Confidence_Limit',
#  'TotalPopulation',
#  'LocationID',
#  'CategoryID',
#  'MeasureId',
#  'DataValueTypeID',
#  'Short_Question_Text',
#  'Geolocation',
#  'States',
#  'Counties']

# %%
df = df[['Year',
 'StateAbbr',
 'LocationName',
 'Data_Value_Type',
 'Data_Value',
 'TotalPopulation',
 'CategoryID',
 'MeasureId',
 'DataValueTypeID',
 'Short_Question_Text',
 'Geolocation',]]
df['Geolocation'] = df['Geolocation'].refind("(")+1:-1
# Out:
#         Year StateAbbr LocationName          Data_Value_Type  Data_Value  \
# 0       2019        WY        Crook  Age-adjusted prevalence        27.0
# 1       2020        WY         Park         Crude prevalence        22.6
# 2       2020        WY       Weston  Age-adjusted prevalence        17.8
# 3       2020        WY     Washakie  Age-adjusted prevalence        19.3
# 4       2020        WY      Laramie  Age-adjusted prevalence        70.9
# ...      ...       ...          ...                      ...         ...
# 188451  2020        AL       DeKalb         Crude prevalence        36.4
# 188452  2019        AL         Dale  Age-adjusted prevalence        86.6
# 188453  2020        AL         Dale         Crude prevalence         4.2
# 188454  2020        AL        Coosa         Crude prevalence        37.8
# 188455  2020        AL      Colbert         Crude prevalence        34.8
#
#         TotalPopulation CategoryID   MeasureId DataValueTypeID  \
# ...
